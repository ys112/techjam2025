# %% [markdown]
# # Data Pipeline for South Dakota Reviews
#
# This notebook processes and cleans review and business metadata for South Dakota.

# %%
# Import Libraries
import gzip, json
import pandas as pd

# %%
def parse(path):
    with gzip.open(path, "rt", encoding="utf-8") as g:
        for line in g:
            yield json.loads(line)

# %% [markdown]
# ## Load Data
#
# Load review and business metadata from gzipped JSON files.

# %%
reviews_data = pd.read_json(
    "../data/review_South_Dakota.json.gz", lines=True, compression="gzip"
)
reviews_data["user_id"] = reviews_data["user_id"].apply(
    lambda x: str(int(x)) if isinstance(x, float) and not pd.isnull(x) else str(x)
)
biz_meta = pd.read_json(
    "../data/meta_South_Dakota.json.gz", lines=True, compression="gzip"
)

# standardize columns
biz_meta.columns = biz_meta.columns.str.lower().str.strip()
reviews_data.columns = reviews_data.columns.str.lower().str.strip()

# %%
print(reviews_data.isnull().sum())
print(biz_meta.isnull().sum())
print(biz_meta["state"].unique())
len(reviews_data)
# Out:
# user_id         0
# name            0
# time            0
# rating          0
# text       325966
# pics       657233
# resp       589840
# gmap_id         0
# dtype: int64
# name                    0
# address               153
# gmap_id                 0
# description         12149
# latitude                0
# longitude               0
# category               62
# avg_rating              0
# num_of_reviews          0
# price               12021
# hours                4080
# misc                 2740
# state                4602
# relative_results     1463
# url                     0
# dtype: int64
# ['Opens soon ⋅ 8AM' None 'Closed ⋅ Opens 8:30AM' 'Closed ⋅ Opens 9AM'
#  'Open ⋅ Closes 11PM' 'Closed ⋅ Opens 9:30AM' 'Closed ⋅ Opens 10AM'
#  'Open 24 hours' 'Closed ⋅ Opens 7AM Thu' 'Closed ⋅ Opens 8AM Thu'
#  'Closed ⋅ Opens 10AM Thu' 'Closed ⋅ Opens 7:30AM Thu'
#  'Closed ⋅ Opens 4PM' 'Open ⋅ Closes 5:30PM'
#  'Closes soon ⋅ 4PM ⋅ Opens 10AM Thu' 'Open ⋅ Closes 5PM' 'Open now'
#  'Open ⋅ Closes 4:30PM' 'Open ⋅ Closes 8PM' 'Open ⋅ Closes 4PM'
#  'Open ⋅ Closes 7PM' 'Closed ⋅ Opens 7:30AM' 'Closed ⋅ Opens 8AM'
#  'Permanently closed' 'Closed ⋅ Opens 7AM' 'Closed ⋅ Opens 6AM'
#  'Closed ⋅ Opens 8:30AM Wed' 'Open ⋅ Closes 12AM' 'Open ⋅ Closes 6PM'
#  'Open ⋅ Closes 9PM' 'Temporarily closed' 'Closed ⋅ Opens 11AM'
#  'Closed ⋅ Opens 8AM Tue' 'Closed ⋅ Opens 10AM Tue'
#  'Closed ⋅ Opens 7:30AM Tue' 'Open ⋅ Closes 11:30PM'
#  'Closed ⋅ Opens 10:30AM Sun' 'Closed ⋅ Opens 1PM' 'Open ⋅ Closes 3PM'
#  'Open ⋅ Closes 10PM' 'Closed ⋅ Opens 8:25AM' 'Closed ⋅ Opens 7AM Tue'
#  'Closed ⋅ Opens 12PM Tue' 'Closed ⋅ Opens 8AM Mon'
#  'Closed ⋅ Opens 6PM Mon' 'Closed ⋅ Opens 5:30AM Mon'
#  'Closed ⋅ Opens 7:45AM Mon' 'Closed ⋅ Opens 10AM Mon'
#  'Closed ⋅ Opens 9AM Mon' 'Closes soon ⋅ 5PM ⋅ Opens 10AM Mon'
#  'Closed ⋅ Opens 2PM' 'Opens soon ⋅ 9AM' 'Closed ⋅ Opens 9AM Tue'
#  'Closed ⋅ Opens 7AM Mon' 'Closed ⋅ Opens 8:30AM Mon'
#  'Closed ⋅ Opens 10AM Wed' 'Closed ⋅ Opens 12PM'
#  'Closed ⋅ Opens 7:30AM Mon' 'Closed ⋅ Opens 12AM Mon'
#  'Closed ⋅ Opens 4PM Wed' 'Closed ⋅ Opens 11AM Sun'
#  'Closes soon ⋅ 10PM ⋅ Opens 9AM Sun' 'Closes soon ⋅ 10AM ⋅ Opens 9AM Mon'
#  'Closed ⋅ Opens 11AM Sat' 'Closed ⋅ Opens 9AM Sat'
#  'Closed ⋅ Opens 8:30AM Sat' 'Closed ⋅ Opens 6AM Sat'
#  'Closed ⋅ Opens 8AM Sat' 'Closed ⋅ Opens 10AM Sat'
#  'Closes soon ⋅ 9PM ⋅ Opens 9AM Sat' 'Closed ⋅ Opens 10AM Sun'
#  'Open ⋅ Closes 2PM ⋅ Reopens 4PM' 'Closed ⋅ Opens 5:30AM'
#  'Closed ⋅ Opens 9AM Thu' 'Closed ⋅ Opens 9:30AM Thu'
#  'Closes soon ⋅ 4:30PM ⋅ Opens 9:30AM Thu' 'Closed ⋅ Opens 5PM'
#  'Closed ⋅ Opens 5PM Wed' 'Closed ⋅ Opens 7AM Wed'
#  'Closed ⋅ Opens 8AM Wed' 'Open ⋅ Closes 2AM' 'Closed ⋅ Opens 7:30AM Wed'
#  'Closed ⋅ Opens 9AM Wed' 'Closed ⋅ Opens 9:30AM Wed'
#  'Closes soon ⋅ 7PM ⋅ Opens 7AM Wed'
#  'Closes soon ⋅ 6PM ⋅ Opens 7:30AM Wed' 'Open ⋅ Closes 1AM'
#  'Open ⋅ Closes 5AM Wed' 'Closed ⋅ Opens 4PM Thu'
#  'Closes soon ⋅ 2PM ⋅ Opens 7AM Wed' 'Closes soon ⋅ 12PM ⋅ Opens 6AM Wed'
#  'Opens soon ⋅ 11AM' 'Closed ⋅ Opens 8:30AM Tue' 'Open ⋅ Closes 7:30PM'
#  'Open ⋅ Closes 3:30PM' 'Closed ⋅ Opens 5PM Tue' 'Closed ⋅ Opens 5AM'
#  'Closed ⋅ Opens 9:30AM Mon' 'Closed ⋅ Opens 5PM Mon'
#  'Closed ⋅ Opens 11AM Mon' 'Closed ⋅ Opens 6:30AM Mon'
#  'Closed ⋅ Opens 11:30AM' 'Closed ⋅ Opens 3PM Mon'
#  'Open ⋅ Closes 2AM ⋅ Reopens 11AM' 'Closed ⋅ Opens 12PM Sun'
#  'Closed ⋅ Opens 6AM Sun' 'Closed ⋅ Opens 8:30AM Sun' 'Closed ⋅ Opens 3PM'
#  'Opens soon ⋅ 7AM' 'Closed ⋅ Opens 8PM' 'Closed ⋅ Opens 6AM Mon'
#  'Closed ⋅ Opens 9AM Sun' 'Open ⋅ Closes 9:30PM' 'Closed ⋅ Opens 2:30PM'
#  'Closed ⋅ Opens 8AM Fri' 'Closed ⋅ Opens 10AM Fri'
#  'Closed ⋅ Opens 6:30AM' 'Closes soon ⋅ 6PM ⋅ Opens 9AM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 8:30AM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 8AM Thu' 'Closed ⋅ Opens 6:45PM Fri'
#  'Closed ⋅ Opens 3:30PM' 'Opens soon ⋅ 7:30AM' 'Closed ⋅ Opens 6AM Tue'
#  'Closed ⋅ Opens 9:30AM Tue' 'Closes soon ⋅ 5PM ⋅ Opens 7:30AM Tue'
#  'Closes soon ⋅ 5PM ⋅ Opens 8AM Tue' 'Open ⋅ Closes 12PM ⋅ Reopens 1:30PM'
#  'Open ⋅ Closes 10:30PM' 'Closed ⋅ Opens 6:30AM Tue'
#  'Closed ⋅ Opens 12PM Mon' 'Closes soon ⋅ 5PM ⋅ Opens 9AM Mon'
#  'Open ⋅ Closes 5AM' 'Closed ⋅ Opens 7AM Sat'
#  'Closes soon ⋅ 7PM ⋅ Opens 7AM Sat' 'Closes soon ⋅ 5PM ⋅ Opens 7AM Mon'
#  'Closes soon ⋅ 5PM ⋅ Opens 8AM Sat' 'Closes soon ⋅ 5PM ⋅ Opens 8AM Mon'
#  'Open ⋅ Closes 1:30PM ⋅ Reopens 2PM' 'Closed ⋅ Opens 8:15AM'
#  'Closed ⋅ Opens 9AM Fri' 'Closed ⋅ Opens 7:30AM Fri'
#  'Closes soon ⋅ 4:30PM ⋅ Opens 8AM Fri' 'Closed ⋅ Opens 7:45AM Sun'
#  'Closed ⋅ Opens 8:30AM Thu' 'Closes soon ⋅ 5PM ⋅ Opens 7AM Thu'
#  'Open ⋅ Closes 6:30PM' 'Open ⋅ Closes 12:30PM ⋅ Reopens 1:30PM'
#  'Closed ⋅ Opens 12AM Sun' 'Closed ⋅ Opens 6AM Wed'
#  'Closed ⋅ Opens 11AM Wed' 'Closes soon ⋅ 11PM ⋅ Opens 6AM Wed'
#  'Closed ⋅ Opens 5AM Wed' 'Open ⋅ Closes 11:45PM'
#  'Closes soon ⋅ 5PM ⋅ Opens 9AM Wed' 'Closed ⋅ Opens 12PM Wed'
#  'Closed ⋅ Opens 12AM Fri' 'Closes soon ⋅ 7PM ⋅ Opens 8AM Tue'
#  'Open ⋅ Closes 1:30PM' 'Closes soon ⋅ 8PM ⋅ Opens 9AM Mon'
#  'Closed ⋅ Opens 4:30PM' 'Open ⋅ Closes 3:15AM ⋅ Reopens 6AM'
#  'Closed ⋅ Opens 7:15AM' 'Closed ⋅ Opens 8AM Sun'
#  'Closed ⋅ Opens 11AM Fri' 'Closes soon ⋅ 6PM ⋅ Opens 9AM Fri'
#  'Open ⋅ Closes 2:30AM' 'Closed ⋅ Opens 6:30PM'
#  'Closes soon ⋅ 4:30PM ⋅ Opens 8:30AM Fri' 'Closed'
#  'Closed ⋅ Opens 6AM Thu' 'Closed ⋅ Opens 11AM Thu'
#  'Closes soon ⋅ 6PM ⋅ Opens 8AM Thu' 'Closed ⋅ Opens 5:30PM'
#  'Closed ⋅ Opens 4:15AM Wed' 'Open ⋅ Closes 2AM ⋅ Reopens 9AM'
#  'Closes soon ⋅ 11PM ⋅ Opens 5AM Wed' 'Closed ⋅ Opens 5PM Fri'
#  'Closes soon ⋅ 4:30PM ⋅ Opens 8AM Tue' 'Opens soon ⋅ 8:30AM'
#  'Closed ⋅ Opens 9PM' 'Closed ⋅ Opens 7AM Sun' 'Closed ⋅ Opens 2PM Sun'
#  'Open ⋅ Closes 8:30PM' 'Closes soon ⋅ 12PM ⋅ Reopens 1PM'
#  'Opens soon ⋅ 5AM' 'Closed ⋅ Opens 7AM Fri' 'Closed ⋅ Opens 1PM Fri'
#  'Closed ⋅ Opens 8:30AM Fri' 'Closes soon ⋅ 5PM ⋅ Opens 8AM Fri'
#  'Closed ⋅ Opens 2PM Fri' 'Closes soon ⋅ 3PM ⋅ Opens 9AM Tue'
#  'Closed ⋅ Opens 5AM Thu' 'Closed ⋅ Opens 5PM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 9AM Thu' 'Opens soon ⋅ 10AM'
#  'Closed ⋅ Opens 10:30AM Thu' 'Closed ⋅ Opens 1PM Wed'
#  'Closes soon ⋅ 8PM ⋅ Opens 7:30AM Wed' 'Open ⋅ Closes 1PM'
#  'Opens soon ⋅ 6AM' 'Closed ⋅ Opens 5:30PM Tue' 'Closed ⋅ Opens 5AM Tue'
#  'Closed ⋅ Opens 1PM Tue' 'Closes soon ⋅ 8PM ⋅ Opens 9AM Tue'
#  'Closes soon ⋅ 5PM ⋅ Opens 9AM Tue' 'Closed ⋅ Opens 11AM Tue'
#  'Closes soon ⋅ 9PM ⋅ Opens 10AM Mon' 'Closed ⋅ Opens 6PM Wed'
#  'Closes soon ⋅ 6PM ⋅ Opens 10AM Mon' 'Closes soon ⋅ 4PM ⋅ Opens 7AM Mon'
#  'Closes soon ⋅ 2PM ⋅ Opens 9AM Tue' 'Closed ⋅ Opens 6PM Fri'
#  'Closed ⋅ Opens 7PM' 'Open ⋅ Closes 6AM Sat' 'Closed ⋅ Opens 6:11AM Mon'
#  'Closed ⋅ Opens 6:13AM Mon' 'Closed ⋅ Opens 6:12AM Mon'
#  'Closed ⋅ Opens 6:10AM Mon' 'Closes soon ⋅ 7PM ⋅ Opens 10AM Sat'
#  'Closes soon ⋅ 7PM ⋅ Opens 9AM Sat' 'Closed ⋅ Opens 9:30AM Sun'
#  'Closes soon ⋅ 12AM ⋅ Opens 9AM Tue' 'Closed ⋅ Opens 5:30AM Tue'
#  'Closed ⋅ Opens 2:45PM' 'Closed ⋅ Opens 6:45AM' 'Opens soon ⋅ 12PM'
#  'Closed ⋅ Opens 7:45AM' 'Closed ⋅ Opens 2PM Thu'
#  'Closes soon ⋅ 11:30PM ⋅ Opens 5:30AM Mon' 'Closed ⋅ Opens 4PM Mon'
#  'Closes soon ⋅ 12PM ⋅ Opens 9AM Mon' 'Closes soon ⋅ 2AM ⋅ Opens 3PM Mon'
#  'Closed ⋅ Opens 8:15AM Tue' 'Closed ⋅ Opens 4:15PM'
#  'Closed ⋅ Opens 10:30AM' 'Closed ⋅ Opens 5:45AM'
#  'Closes soon ⋅ 10PM ⋅ Opens 6:30AM Fri'
#  'Closes soon ⋅ 10PM ⋅ Opens 8AM Fri'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 7:30AM Fri'
#  'Closes soon ⋅ 6PM ⋅ Opens 10AM Fri' 'Closes soon ⋅ 5PM ⋅ Opens 7AM Fri'
#  'Open ⋅ Closes 12:30AM' 'Open ⋅ Closes 11:59PM'
#  'Closes soon ⋅ 12AM ⋅ Opens 10:30AM Thu'
#  'Closes soon ⋅ 9PM ⋅ Opens 8AM Thu' 'Closes soon ⋅ 7PM ⋅ Opens 7AM Thu'
#  'Closed ⋅ Opens 12PM Thu' 'Closed ⋅ Opens 6:30PM Wed'
#  'Closed ⋅ Opens 10:30AM Wed' 'Closes soon ⋅ 5:30PM ⋅ Opens 7AM Wed'
#  'Open ⋅ Closes 12PM ⋅ Reopens 1PM' 'Closed ⋅ Opens 4:30PM Mon'
#  'Opens soon ⋅ 10:30AM' 'Closes soon ⋅ 11PM ⋅ Opens 6AM Sun'
#  'Closed ⋅ Opens 10:30AM Mon' 'Closed ⋅ Opens 10:45AM Mon'
#  'Closes soon ⋅ 3PM ⋅ Opens 8AM Mon' 'Closes soon ⋅ 1PM ⋅ Opens 8AM Mon'
#  'Open ⋅ Closes 12PM' 'Closed ⋅ Opens 12PM Sat' 'Open ⋅ Closes 2PM'
#  'Closed ⋅ Opens 8:45AM' 'Open ⋅ Closes 2AM ⋅ Reopens 6AM'
#  'Open ⋅ Closes 12PM Thu' 'Closed ⋅ Opens 4PM Fri'
#  'Closed ⋅ Opens 6:30AM Thu' 'Closes soon ⋅ 8PM ⋅ Opens 10AM Wed'
#  'Closes soon ⋅ 7PM ⋅ Opens 10AM Wed' 'Closes soon ⋅ 7PM ⋅ Opens 9AM Wed'
#  'Closes soon ⋅ 5PM ⋅ Opens 10AM Wed' 'Closed ⋅ Opens 12:30PM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 8AM Wed' 'Closed ⋅ Opens 7:45AM Tue'
#  'Closes soon ⋅ 8PM ⋅ Opens 9:30AM Tue'
#  'Closes soon ⋅ 6PM ⋅ Opens 9AM Tue'
#  'Closes soon ⋅ 6PM ⋅ Opens 7:30AM Tue'
#  'Closes soon ⋅ 6PM ⋅ Opens 8AM Tue' 'Open ⋅ Closes 3:45PM'
#  'Closed ⋅ Opens 12:15PM' 'Closed ⋅ Opens 4AM' 'Closed ⋅ Opens 4PM Tue'
#  'Closed ⋅ Opens 5AM Mon' 'Closes soon ⋅ 2AM ⋅ Opens 10AM Mon'
#  'Closed ⋅ Opens 6:30AM Sun' 'Closed ⋅ Opens 8:25AM Mon'
#  'Closes soon ⋅ 11:59PM ⋅ Opens 10AM Sun'
#  'Closes soon ⋅ 12AM ⋅ Opens 8AM Sun' 'Closed ⋅ Opens 7:30AM Sun'
#  'Opens soon ⋅ 1PM' 'Closes soon ⋅ 9PM ⋅ Opens 11AM Sat'
#  'Closed ⋅ Opens 6AM Fri' 'Closes soon ⋅ 11PM ⋅ Opens 1PM Fri'
#  'Closes soon ⋅ 7PM ⋅ Opens 7AM Fri' 'Closes soon ⋅ 7PM ⋅ Opens 10AM Fri'
#  'Closes soon ⋅ 8PM ⋅ Opens 10AM Thu' 'Closed ⋅ Opens 7:15AM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 7:30AM Thu' 'Closed ⋅ Opens 12AM Sat'
#  'Open ⋅ Closes 2AM ⋅ Reopens 10AM' 'Closes soon ⋅ 9PM ⋅ Opens 8AM Wed'
#  'Closes soon ⋅ 8:30PM ⋅ Opens 1PM Wed' 'Closed ⋅ Opens 2PM Wed'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 7:30AM Tue'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 8AM Tue'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 8:30AM Tue'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 9AM Tue'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 7AM Tue'
#  'Closes soon ⋅ 9PM ⋅ Opens 9AM Mon' 'Closes soon ⋅ 7PM ⋅ Opens 9AM Mon'
#  'Closed ⋅ Opens 1PM Mon' 'Closed ⋅ Opens 12:30PM'
#  'Open ⋅ Closes 12PM ⋅ Reopens 7:30PM' 'Closed ⋅ Opens 1PM Sat'
#  'Closed ⋅ Opens 1PM Sun' 'Closes soon ⋅ 9PM ⋅ Opens 9AM Sun'
#  'Closed ⋅ Opens 7PM Wed' 'Closes soon ⋅ 9PM ⋅ Opens 10AM Tue'
#  'Closed ⋅ Opens 8:20AM Tue' 'Closes soon ⋅ 8PM ⋅ Opens 11AM Tue'
#  'Open ⋅ Closes 10:45PM' 'Closes soon ⋅ 1:45AM ⋅ Reopens 12PM'
#  'Closes soon ⋅ 9PM ⋅ Opens 11AM Mon' 'Closes soon ⋅ 8PM ⋅ Opens 11AM Mon'
#  'Closed ⋅ Opens 4:30AM Mon' 'Closes soon ⋅ 6PM ⋅ Opens 7:30AM Mon'
#  'Closed ⋅ Opens 8:45AM Sat' 'Closes soon ⋅ 8PM ⋅ Opens 10AM Sun'
#  'Closes soon ⋅ 6PM ⋅ Opens 9AM Mon' 'Open ⋅ Closes 1:30AM'
#  'Closes soon ⋅ 12PM ⋅ Opens 8AM Mon' 'Closes soon ⋅ 10AM ⋅ Opens 8AM Mon'
#  'Closes soon ⋅ 8PM ⋅ Opens 7AM Sat' 'Closes soon ⋅ 6PM ⋅ Opens 9AM Sat'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 9AM Sat' 'Open ⋅ Closes 2AM ⋅ Reopens 1PM'
#  'Closed ⋅ Opens 6:30AM Fri' 'Closes soon ⋅ 10PM ⋅ Opens 11AM Fri'
#  'Closes soon ⋅ 9PM ⋅ Opens 8AM Fri' 'Closes soon ⋅ 9PM ⋅ Opens 11AM Fri'
#  'Closes soon ⋅ 9PM ⋅ Opens 9AM Fri' 'Closes soon ⋅ 9PM ⋅ Opens 7AM Fri'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 8AM Fri'
#  'Closes soon ⋅ 5PM ⋅ Opens 9AM Fri'
#  'Closes soon ⋅ 5PM ⋅ Opens 8:30AM Fri'
#  'Open ⋅ Closes 1:30PM ⋅ Reopens 5PM' 'Opens soon ⋅ 6:45AM'
#  'Closed ⋅ Opens 10:45AM Sun' 'Closes soon ⋅ 5PM ⋅ Opens 1PM Thu'
#  'Opens soon ⋅ 3PM' 'Closes soon ⋅ 3PM ⋅ Opens 6:30AM Thu'
#  'Closes soon ⋅ 2PM ⋅ Opens 8AM Thu' 'Open ⋅ Closes 12PM ⋅ Reopens 2:30PM'
#  'Closes soon ⋅ 2AM ⋅ Reopens 7AM' 'Closes soon ⋅ 2AM ⋅ Reopens 11AM'
#  'Closed ⋅ Opens 6:30AM Wed' 'Closes soon ⋅ 10PM ⋅ Opens 11AM Wed'
#  'Open ⋅ Closes 10:01PM' 'Closes soon ⋅ 5:30PM ⋅ Opens 8AM Wed'
#  'Closes soon ⋅ 5PM ⋅ Opens 7AM Wed'
#  'Closes soon ⋅ 5PM ⋅ Opens 7:30AM Wed' 'Opens soon ⋅ 2PM'
#  'Closed ⋅ Opens 7PM Fri' 'Closed ⋅ Opens 10:45AM' 'Opens soon ⋅ 4AM'
#  'Closed ⋅ Opens 10:30AM Tue' 'Closes soon ⋅ 9PM ⋅ Opens 11AM Tue'
#  'Closed ⋅ Opens 12AM Thu' 'Closes soon ⋅ 8PM ⋅ Opens 8AM Tue'
#  'Closes soon ⋅ 8PM ⋅ Opens 1PM Tue' 'Closes soon ⋅ 7PM ⋅ Opens 11AM Tue'
#  'Closed ⋅ Opens 12AM Tue' 'Closed ⋅ Opens 3PM Tue'
#  'Closes soon ⋅ 9PM ⋅ Opens 10:30AM Mon'
#  'Closes soon ⋅ 4PM ⋅ Opens 8AM Tue' 'Closed ⋅ Opens 8PM Sat'
#  'Closed ⋅ Opens 8:10AM Mon' 'Closes soon ⋅ 10PM ⋅ Opens 11AM Sun'
#  'Closed ⋅ Opens 8:45AM Sun' 'Closes soon ⋅ 9PM ⋅ Opens 8AM Sun'
#  'Open ⋅ Closes 5PM Sun' 'Closes soon ⋅ 7PM ⋅ Opens 11AM Sun'
#  'Closes soon ⋅ 7PM ⋅ Opens 10AM Sun' 'Closes soon ⋅ 6PM ⋅ Opens 7AM Mon'
#  'Closes soon ⋅ 6PM ⋅ Opens 7AM Sun' 'Closes soon ⋅ 5PM ⋅ Opens 9AM Sun'
#  'Open ⋅ Closes 2PM ⋅ Reopens 5PM' 'Opens soon ⋅ 6:30AM'
#  'Closes soon ⋅ 10PM ⋅ Opens 5AM Sat' 'Closes soon ⋅ 10PM ⋅ Opens 8AM Sat'
#  'Closes soon ⋅ 10PM ⋅ Opens 5:30AM Sat'
#  'Closes soon ⋅ 10PM ⋅ Opens 7AM Sat' 'Closes soon ⋅ 8PM ⋅ Opens 10AM Sat'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 8:30AM Sat'
#  'Closes soon ⋅ 5PM ⋅ Opens 8:30AM Mon'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 8AM Sat' 'Opens soon ⋅ 5PM'
#  'Closes soon ⋅ 5PM ⋅ Opens 10AM Sat'
#  'Closes soon ⋅ 5PM ⋅ Opens 7:30AM Mon' 'Closed ⋅ Opens 9:30AM Sat'
#  'Closed ⋅ Opens 4:30AM' 'Closes soon ⋅ 2AM ⋅ Reopens 6AM'
#  'Closed ⋅ Opens 12PM Fri' 'Closed ⋅ Opens 5AM Fri'
#  'Closed ⋅ Opens 10:30AM Fri' 'Closes soon ⋅ 6PM ⋅ Opens 7AM Fri'
#  'Open ⋅ Closes 1PM ⋅ Reopens 4PM' 'Closed ⋅ Opens 10PM'
#  'Opens soon ⋅ 7:45AM' 'Open ⋅ Closes 5AM ⋅ Reopens 8AM'
#  'Closes soon ⋅ 3:30PM ⋅ Opens 8:30AM Wed'
#  'Closes soon ⋅ 12AM ⋅ Opens 4PM Tue' 'Closed ⋅ Opens 5:30PM Thu'
#  'Closed ⋅ Opens 9:45AM' 'Closed ⋅ Opens 2PM Tue'
#  'Closes soon ⋅ 9PM ⋅ Opens 7AM Mon' 'Closes soon ⋅ 3PM ⋅ Reopens 4PM'
#  'Closes soon ⋅ 2PM ⋅ Opens 6AM Tue' 'Closes soon ⋅ 12PM ⋅ Reopens 6PM'
#  'Closes soon ⋅ 12:30PM ⋅ Opens 9AM Mon' 'Closed ⋅ Opens 5:40AM Mon'
#  'Closed ⋅ Opens 5:30PM Mon' 'Open ⋅ Closes 3AM ⋅ Reopens 6AM'
#  'Closes soon ⋅ 12AM ⋅ Opens 11AM Tue'
#  'Closes soon ⋅ 10:30PM ⋅ Opens 6AM Sun'
#  'Closes soon ⋅ 6PM ⋅ Opens 6AM Sun' 'Closed ⋅ Opens 11:30AM Tue'
#  'Closed ⋅ Opens 6:30AM Sat' 'Closed ⋅ Opens 2PM Sat'
#  'Closes soon ⋅ 7PM ⋅ Opens 7:30AM Sat'
#  'Closes soon ⋅ 6:30PM ⋅ Opens 11AM Sat'
#  'Closes soon ⋅ 7PM ⋅ Opens 6AM Sat' 'Open ⋅ Closes 4AM'
#  'Closed ⋅ Opens 3:30PM Sat' 'Opens soon ⋅ 5:30AM'
#  'Closes soon ⋅ 10PM ⋅ Opens 3PM Fri'
#  'Closes soon ⋅ 10PM ⋅ Opens 10:30AM Fri' 'Open ⋅ Closes 10AM Fri'
#  'Closes soon ⋅ 7PM ⋅ Opens 9AM Fri' 'Closes soon ⋅ 6PM ⋅ Opens 11AM Fri'
#  'Closes soon ⋅ 7PM ⋅ Opens 8:30AM Thu'
#  'Closes soon ⋅ 5PM ⋅ Opens 10AM Thu'
#  'Closes soon ⋅ 5:30PM ⋅ Opens 7:30AM Thu'
#  'Closes soon ⋅ 9PM ⋅ Opens 11AM Wed'
#  'Closes soon ⋅ 11:30PM ⋅ Opens 5:30AM Tue'
#  'Closes soon ⋅ 8PM ⋅ Opens 11:30AM Tue'
#  'Closes soon ⋅ 8PM ⋅ Opens 11AM Sun' 'Closes soon ⋅ 6PM ⋅ Opens 10AM Sun'
#  'Opens soon ⋅ 4PM' 'Open ⋅ Closes 3AM'
#  'Closes soon ⋅ 9PM ⋅ Opens 7:30AM Fri'
#  'Closes soon ⋅ 9PM ⋅ Opens 10AM Wed' 'Closes soon ⋅ 10PM ⋅ Opens 6AM Tue'
#  'Closes soon ⋅ 7PM ⋅ Opens 9AM Tue' 'Closes soon ⋅ 2AM ⋅ Reopens 10AM'
#  'Closes soon ⋅ 11:30PM ⋅ Opens 6AM Sun'
#  'Closes soon ⋅ 12AM ⋅ Opens 10AM Sun' 'Closed ⋅ Opens 5AM Sun'
#  'Closes soon ⋅ 12AM ⋅ Opens 6AM Sat'
#  'Closes soon ⋅ 9PM ⋅ Opens 10:30AM Sat'
#  'Closes soon ⋅ 10PM ⋅ Opens 11AM Sat'
#  'Closes soon ⋅ 10PM ⋅ Opens 10AM Sat' 'Opens soon ⋅ 5:15AM'
#  'Closes soon ⋅ 9PM ⋅ Opens 11:30AM Fri'
#  'Closes soon ⋅ 9PM ⋅ Opens 11AM Thu' 'Closes soon ⋅ 9PM ⋅ Opens 6AM Thu'
#  'Closes soon ⋅ 9PM ⋅ Opens 10:30AM Thu'
#  'Closes soon ⋅ 9PM ⋅ Opens 9AM Thu' 'Closes soon ⋅ 9PM ⋅ Opens 10AM Thu'
#  'Closes soon ⋅ 9PM ⋅ Opens 4PM Thu' 'Closed ⋅ Opens 5:30AM Thu'
#  'Closes soon ⋅ 9:30PM ⋅ Opens 9:30AM Thu' 'Closed ⋅ Opens 11:30AM Thu'
#  'Closed ⋅ Opens 1PM Thu' 'Closes soon ⋅ 2PM ⋅ Opens 11AM Thu'
#  'Open ⋅ Closes 2:30PM ⋅ Reopens 5PM' 'Closes soon ⋅ 11PM ⋅ Opens 7AM Wed'
#  nan]
# 673048

# %%
print(reviews_data)
print(biz_meta)
# Out:
#                       user_id               name           time  rating  \
# 0       103563353519118155776          Peri Gray  1516122675780       5
# 1       101824980797027237888        Suzy Berndt  1532922350314       5
# 2       108711640480272777216  Rosemary Red Legs  1530969093932       5
# 3       101852294221648461824         Brown Wolf  1537085635922       2
# 4       108987444312280645632      C J Blue Coat  1474922375491       5
# ...                       ...                ...            ...     ...
# 673043  106349677749985591296            Peggy M  1541553943539       5
# 673044  111132439775161876480  Gabrielle Strouse  1465971016069       2
# 673045  112599289864006172672   Where's The 10mm  1439839859315       5
# 673046  104289624746481025024         A J Rausch  1534031130311       5
# 673047  111259369481710452736                D B  1542421998790       5
#
#                                          text  pics  resp  \
# 0       Great place to care for our children.  None  None
# 1                         Th sw y are so nice  None  None
# 2                       Went with my daughter  None  None
# 3                                        None  None  None
# 4                                        None  None  None
# ...                                       ...   ...   ...
# 673043                                   None  None  None
# 673044                                   None  None  None
# 673045                                   None  None  None
# 673046                                   None  None  None
# 673047                                   None  None  None
#
#                                       gmap_id
# 0       0x532af45db8f30779:0xd9be9359f1e56178
# 1       0x532af45db8f30779:0xd9be9359f1e56178
# 2       0x532af45db8f30779:0xd9be9359f1e56178
# 3       0x532af45db8f30779:0xd9be9359f1e56178
# 4       0x532af45db8f30779:0xd9be9359f1e56178
# ...                                       ...
# 673043  0x877d4b3beecb809d:0xc8750c627d73a316
# 673044  0x877d4b3beecb809d:0xc8750c627d73a316
# 673045  0x877d4b3beecb809d:0xc8750c627d73a316
# 673046  0x877d4b3beecb809d:0xc8750c627d73a316
# 673047  0x877d4b3beecb809d:0xc8750c627d73a316
#
# [673048 rows x 8 columns]
#                                        name  \
# 0      Rapid City Obstetrics and Gynecology
# 1                                Jerde Hall
# 2                           CRST WIC Office
# 3                       Valley Implement Co
# 4              United States Postal Service
# ...                                     ...
# 14252                                  IHOP
# 14253           The City of Presidents Walk
# 14254                 Super Tunnel Car Wash
# 14255           Rushmore Tramway Adventures
# 14256                         Naughti Wines
#
#                                                  address  \
# 0      Rapid City Obstetrics and Gynecology, 7236 Jor...
# 1             Jerde Hall, S Lloyd St, Aberdeen, SD 57401
# 2      CRST WIC Office, 16618 243rd Avenue, Eagle But...
# 3      Valley Implement Co, 13045 SD-34, Sturgis, SD ...
# 4      United States Postal Service, 121 Main St, Eag...
# ...                                                  ...
# 14252            IHOP, 550 Disk Dr, Rapid City, SD 57701
# 14253  The City of Presidents Walk, 631 SD-79, Rapid ...
# 14254  Super Tunnel Car Wash, 3491 SD-44, Rapid City,...
# 14255  Rushmore Tramway Adventures, 203 Cemetery Rd, ...
# 14256  Naughti Wines, 6544 23851, US-385, Hill City, ...
#
#                                      gmap_id  \
# 0      0x877d43e8e4fba5e7:0x6b14a31fe037c3e1
# 1      0x52d244db89b809f5:0xa34e35f587826cdb
# 2      0x532af45db8f30779:0xd9be9359f1e56178
# 3      0x532d44ba713277c1:0x474c2d2edc8fff43
# 4      0x532af4f62ba8fbd7:0x948c4a91047d66db
# ...                                      ...
# 14252  0x877d5ce2d998fe23:0xa9a99dcfae6290f0
# 14253  0x877d5cd32120934d:0xabf63acba97ce080
# 14254   0x877d69573e85415b:0x2168e2c7299d689
# 14255  0x877d3645c6ae373f:0x752c61e8e68d8ac2
# 14256  0x877d4b3beecb809d:0xc8750c627d73a316
#
#                                              description   latitude  \
# 0                                                   None  44.014617
# 1                                                   None  45.451496
# 2                                                   None  44.990878
# 3                                                   None  44.415567
# 4                                                   None  44.996746
# ...                                                  ...        ...
# 14252  Long-standing chain serving a wide variety of ...  44.108143
# 14253                                               None  44.081193
# 14254                                               None  44.062044
# 14255  Adventure park with chairlift, zip-line & tree...  43.887400
# 14256                                               None  43.945784
#
#         longitude                                           category  \
# 0     -103.247181  [Medical clinic, Fertility physician, Obstetri...
# 1      -98.478632                                       [University]
# 2     -101.239919                                               None
# 3     -103.438498                                   [Tractor dealer]
# 4     -101.234442  [Post office, Logistics service, Money order s...
# ...           ...                                                ...
# 14252 -103.222842  [Restaurant, American restaurant, Breakfast re...
# 14253 -103.228651                       [Museum, Tourist attraction]
# 14254 -103.158892                                         [Car wash]
# 14255 -103.426300             [Tourist attraction, Adventure sports]
# 14256 -103.527289  [Winery, Brewery, Restaurant, Tourist attraction]
#
#        avg_rating  num_of_reviews price  \
# 0             3.9               8  None
# 1             3.0               1  None
# 2             4.7               8  None
# 3             4.4               7  None
# 4             3.6               5  None
# ...           ...             ...   ...
# 14252         3.7            1204     $
# 14253         4.7              66  None
# 14254         4.4              46  None
# 14255         4.6             618  None
# 14256         4.5             118  None
#
#                                                    hours  \
# 0      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 1                                                   None
# 2                                                   None
# 3      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 4      [[Thursday, 8:30–9:15AM], [Friday, 8:30–9:15AM...
# ...                                                  ...
# 14252  [[Thursday, 6AM–10PM], [Friday, 6AM–10PM], [Sa...
# 14253  [[Thursday, Open 24 hours], [Friday, Open 24 h...
# 14254  [[Thursday, 7AM–8PM], [Friday, 7AM–8PM], [Satu...
# 14255                                               None
# 14256  [[Wednesday, Closed], [Thursday, 11AM–7PM], [F...
#
#                                                     misc  \
# 0      {'Accessibility': ['Wheelchair accessible entr...
# 1                                                   None
# 2                                                   None
# 3             {'Service options': ['In-store shopping']}
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 14252  {'Service options': ['Delivery', 'Takeout', 'D...
# 14253  {'Accessibility': ['Wheelchair accessible entr...
# 14254                                               None
# 14255  {'Accessibility': ['Wheelchair accessible entr...
# 14256  {'Service options': ['Delivery'], 'Accessibili...
#
#                        state  \
# 0           Opens soon ⋅ 8AM
# 1                       None
# 2                       None
# 3           Opens soon ⋅ 8AM
# 4      Closed ⋅ Opens 8:30AM
# ...                      ...
# 14252                    NaN
# 14253                    NaN
# 14254                    NaN
# 14255                    NaN
# 14256                    NaN
#
#                                         relative_results  \
# 0      [0x877d43184d2553df:0x1be151787a3bf2c0, 0x877d...
# 1                                                   None
# 2      [0x532af4588c5f80b1:0x30071640ecb03b5, 0x532af...
# 3      [0x53329969baf9acf1:0x7075536a6208dca8, 0x5332...
# 4      [0x532af4fbbb05470d:0x4b9b34c8113c9856, 0x532a...
# ...                                                  ...
# 14252  [0x877d5d1622a76549:0x647f4cd515b7fef1, 0x877d...
# 14253  [0x877d5cd16c70b045:0xd54a5fc971915b4d, 0x877d...
# 14254  [0x877d43ad529c2507:0xc1449cebbafbe2ce, 0x877d...
# 14255  [0x877d39b6dccd802f:0xe6a268920e71ab6f, 0x877d...
# 14256  [0x877d4b3beecb809d:0xd69d57aa28babd93, 0x877d...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 14252  https://www.google.com/maps/place//data=!4m2!3...
# 14253  https://www.google.com/maps/place//data=!4m2!3...
# 14254  https://www.google.com/maps/place//data=!4m2!3...
# 14255  https://www.google.com/maps/place//data=!4m2!3...
# 14256  https://www.google.com/maps/place//data=!4m2!3...
#
# [14257 rows x 15 columns]

# %% [markdown]
# ## Data Cleaning
#
# Clean review and business metadata.

# %%
# 1. cleaning of review data

# these columns are IMPT
reviews_data = reviews_data.dropna(subset=["rating", "time", "gmap_id", "user_id"])

# Convert selected columns to string dtype
for col in ["user_name", "user_id", "text", "gmap_id"]:
    if col in reviews_data.columns:
        reviews_data[col] = reviews_data[col].astype(str)

reviews_data["time"] = pd.to_datetime(reviews_data["time"], unit="ms", utc=True)

is_dict = reviews_data["resp"].map(lambda x: isinstance(x, dict))
reviews_data["has_resp"] = is_dict.fillna(False)
reviews_data["resp_text"] = (
    reviews_data["resp"]
    .where(is_dict)
    .map(lambda d: d.get("text") if isinstance(d, dict) else None)
    .astype("string")
)
reviews_data["resp_time"] = pd.to_datetime(
    reviews_data["resp"]
    .where(is_dict)
    .map(lambda d: d.get("time") if isinstance(d, dict) else None),
    unit="ms",
    utc=True,
    errors="coerce",
)

# Presence-only (True if not null, False if null)
reviews_data["pics"] = reviews_data["pics"].notna()

reviews_data = reviews_data.rename(
    columns={"name": "user_name", "time": "review_time", "text": "review_text"}
)

# %%
# Check for user_id precision loss due to float conversion
float_ids = reviews_data["user_id"].apply(
    lambda x: isinstance(x, float) and ("." in str(x) or "e" in str(x))
)
if float_ids.any():
    print(
        "Warning: Some user_id values may have lost precision due to float conversion:"
    )
    print(reviews_data[float_ids]["user_id"])
else:
    print("No user_id precision loss detected.")
# Out:
# No user_id precision loss detected.

# %%
reviews_data
# Out:
#                       user_id          user_name  \
# 0       103563353519118155776          Peri Gray
# 1       101824980797027237888        Suzy Berndt
# 2       108711640480272777216  Rosemary Red Legs
# 3       101852294221648461824         Brown Wolf
# 4       108987444312280645632      C J Blue Coat
# ...                       ...                ...
# 673043  106349677749985591296            Peggy M
# 673044  111132439775161876480  Gabrielle Strouse
# 673045  112599289864006172672   Where's The 10mm
# 673046  104289624746481025024         A J Rausch
# 673047  111259369481710452736                D B
#
#                             review_time  rating  \
# 0      2018-01-16 17:11:15.780000+00:00       5
# 1      2018-07-30 03:45:50.314000+00:00       5
# 2      2018-07-07 13:11:33.932000+00:00       5
# 3      2018-09-16 08:13:55.922000+00:00       2
# 4      2016-09-26 20:39:35.491000+00:00       5
# ...                                 ...     ...
# 673043 2018-11-07 01:25:43.539000+00:00       5
# 673044 2016-06-15 06:10:16.069000+00:00       2
# 673045 2015-08-17 19:30:59.315000+00:00       5
# 673046 2018-08-11 23:45:30.311000+00:00       5
# 673047 2018-11-17 02:33:18.790000+00:00       5
#
#                                   review_text   pics  resp  \
# 0       Great place to care for our children.  False  None
# 1                         Th sw y are so nice  False  None
# 2                       Went with my daughter  False  None
# 3                                        None  False  None
# 4                                        None  False  None
# ...                                       ...    ...   ...
# 673043                                   None  False  None
# 673044                                   None  False  None
# 673045                                   None  False  None
# 673046                                   None  False  None
# 673047                                   None  False  None
#
#                                       gmap_id  has_resp resp_text resp_time
# 0       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 1       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 2       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 3       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 4       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# ...                                       ...       ...       ...       ...
# 673043  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673044  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673045  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673046  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673047  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
#
# [673048 rows x 11 columns]

# %%
print(reviews_data.dtypes)
# Out:
# user_id                     object
# user_name                   object
# review_time    datetime64[ns, UTC]
# rating                       int64
# review_text                 object
# pics                          bool
# resp                        object
# gmap_id                     object
# has_resp                      bool
# resp_text           string[python]
# resp_time      datetime64[ns, UTC]
# dtype: object

# %%
# 2. cleaning of biz meta data
biz_meta = biz_meta.dropna(subset=["gmap_id"])

# Convert selected columns to string dtype
for col in ["name", "description", "category", "user_id", "text", "gmap_id"]:
    if col in reviews_data.columns:
        reviews_data[col] = reviews_data[col].astype(str)


# Convert $ → 1, $$ → 2, etc.
biz_meta["price_level"] = biz_meta["price"].str.len()
# Fill missing with 0 = unknown
biz_meta["price_level"] = biz_meta["price_level"].fillna(0).astype("int8")
biz_meta = biz_meta.rename(columns={"name": "biz_name"})

# %% [markdown]
# ## Data Merging
#
# Merge relevant columns from business metadata into reviews.

# %%
keep_cols = [
    "gmap_id",  # join key
    "biz_name",
    "description",
    "category",
    "avg_rating",
    "num_of_reviews",
    "price_level",
]

keep_cols = [c for c in keep_cols if c in biz_meta.columns]
biz_meta = biz_meta[keep_cols].drop_duplicates(subset=["gmap_id"])

merged_reviews_data = reviews_data.merge(biz_meta, on="gmap_id", how="left")

merged_reviews_data
# Out:
#                       user_id          user_name  \
# 0       103563353519118155776          Peri Gray
# 1       101824980797027237888        Suzy Berndt
# 2       108711640480272777216  Rosemary Red Legs
# 3       101852294221648461824         Brown Wolf
# 4       108987444312280645632      C J Blue Coat
# ...                       ...                ...
# 673043  106349677749985591296            Peggy M
# 673044  111132439775161876480  Gabrielle Strouse
# 673045  112599289864006172672   Where's The 10mm
# 673046  104289624746481025024         A J Rausch
# 673047  111259369481710452736                D B
#
#                             review_time  rating  \
# 0      2018-01-16 17:11:15.780000+00:00       5
# 1      2018-07-30 03:45:50.314000+00:00       5
# 2      2018-07-07 13:11:33.932000+00:00       5
# 3      2018-09-16 08:13:55.922000+00:00       2
# 4      2016-09-26 20:39:35.491000+00:00       5
# ...                                 ...     ...
# 673043 2018-11-07 01:25:43.539000+00:00       5
# 673044 2016-06-15 06:10:16.069000+00:00       2
# 673045 2015-08-17 19:30:59.315000+00:00       5
# 673046 2018-08-11 23:45:30.311000+00:00       5
# 673047 2018-11-17 02:33:18.790000+00:00       5
#
#                                   review_text   pics  resp  \
# 0       Great place to care for our children.  False  None
# 1                         Th sw y are so nice  False  None
# 2                       Went with my daughter  False  None
# 3                                        None  False  None
# 4                                        None  False  None
# ...                                       ...    ...   ...
# 673043                                   None  False  None
# 673044                                   None  False  None
# 673045                                   None  False  None
# 673046                                   None  False  None
# 673047                                   None  False  None
#
#                                       gmap_id  has_resp resp_text resp_time  \
# 0       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 1       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 2       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 3       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# 4       0x532af45db8f30779:0xd9be9359f1e56178     False      <NA>       NaT
# ...                                       ...       ...       ...       ...
# 673043  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673044  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673045  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673046  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
# 673047  0x877d4b3beecb809d:0xc8750c627d73a316     False      <NA>       NaT
#
#                biz_name description  \
# 0       CRST WIC Office        None
# 1       CRST WIC Office        None
# 2       CRST WIC Office        None
# 3       CRST WIC Office        None
# 4       CRST WIC Office        None
# ...                 ...         ...
# 673043    Naughti Wines        None
# 673044    Naughti Wines        None
# 673045    Naughti Wines        None
# 673046    Naughti Wines        None
# 673047    Naughti Wines        None
#
#                                                  category  avg_rating  \
# 0                                                    None         4.7
# 1                                                    None         4.7
# 2                                                    None         4.7
# 3                                                    None         4.7
# 4                                                    None         4.7
# ...                                                   ...         ...
# 673043  [Winery, Brewery, Restaurant, Tourist attraction]         4.5
# 673044  [Winery, Brewery, Restaurant, Tourist attraction]         4.5
# 673045  [Winery, Brewery, Restaurant, Tourist attraction]         4.5
# 673046  [Winery, Brewery, Restaurant, Tourist attraction]         4.5
# 673047  [Winery, Brewery, Restaurant, Tourist attraction]         4.5
#
#         num_of_reviews  price_level
# 0                    8            0
# 1                    8            0
# 2                    8            0
# 3                    8            0
# 4                    8            0
# ...                ...          ...
# 673043             118            0
# 673044             118            0
# 673045             118            0
# 673046             118            0
# 673047             118            0
#
# [673048 rows x 17 columns]

# %%
print(merged_reviews_data.dtypes)
# Out:
# user_id                        object
# user_name                      object
# review_time       datetime64[ns, UTC]
# rating                          int64
# review_text                    object
# pics                             bool
# resp                           object
# gmap_id                        object
# has_resp                         bool
# resp_text              string[python]
# resp_time         datetime64[ns, UTC]
# biz_name                       object
# description                    object
# category                       object
# avg_rating                    float64
# num_of_reviews                  int64
# price_level                      int8
# dtype: object

# %%
merged_reviews_data.to_csv("../data/cleaned_google_reviews.csv", index=False)
