# %% [markdown]
# # Data Pipeline - South Dakota Business Reviews Analysis
#
# This notebook processes South Dakota business review data and metadata, performing data cleaning and preparation for analysis.

# %% [markdown]
# ## 1. Import Required Libraries
#
# Import the necessary libraries for data processing and analysis.

# %%
import gzip, json
import pandas as pd
from tabulate import tabulate
from typing import Dict, List
from pydantic import BaseModel
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import gzip, json
#       2 import pandas as pd
# ----> 3 from tabulate import tabulate
#       4 from typing import Dict, List
#       5 from pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'tabulate'

# %% [markdown]
# ## 2. Helper Functions
#
# Define utility functions for parsing compressed JSON data.

# %%
def parse(path):
    """Parse gzipped JSON lines file and yield JSON objects."""
    with gzip.open(path, "rt", encoding="utf-8") as g:
        for line in g:
            yield json.loads(line)

# %% [markdown]
# ## 3. Data Loading
#
# Load the review data and business metadata from compressed JSON files.

# %%
# Load data from compressed JSON files
reviews_data = pd.read_json(
    "../data/review_South_Dakota.json.gz", lines=True, compression="gzip"
)  # or .json/.parquet
biz_meta = pd.read_json(
    "../data/meta_South_Dakota.json.gz", lines=True, compression="gzip"
)

print(f"Reviews data shape: {reviews_data.shape}")
print(f"Business metadata shape: {biz_meta.shape}")
# Out:
# Reviews data shape: (673048, 8)
# Business metadata shape: (14257, 15)

# %% [markdown]
# ## 4. Data Standardization
#
# Standardize column names for consistency.

# %%
# Standardize column names
biz_meta.columns = biz_meta.columns.str.lower().str.strip()
reviews_data.columns = reviews_data.columns.str.lower().str.strip()

print("Reviews data columns:", list(reviews_data.columns))
print("Business metadata columns:", list(biz_meta.columns))
# Out:
# Reviews data columns: ['user_id', 'name', 'time', 'rating', 'text', 'pics', 'resp', 'gmap_id']
# Business metadata columns: ['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude', 'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'misc', 'state', 'relative_results', 'url']

# %% [markdown]
# ## 5. Data Preview
#
# Display the first few rows of both datasets to understand the data structure.

# %%
print("\nBusiness Metadata Sample:")
print(tabulate(biz_meta.head(20), headers="keys", tablefmt="psql"))
# Out:
# Business Metadata Sample:
# +----+--------------------------------------+--------------------------------------------------------------------------------------------+---------------------------------------+---------------+------------+-------------+--------------------------------------------------------------------------------------------------------------------------------+--------------+------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+
# |    | name                                 | address                                                                                    | gmap_id                               | description   |   latitude |   longitude | category                                                                                                                       |   avg_rating |   num_of_reviews | price   | hours                                                                                                                                                                                                               | misc                                                                                                                                                                                                                                                                                    | state                  | relative_results                                                                                                                                                                                              | url                                                                                                              |
# |----+--------------------------------------+--------------------------------------------------------------------------------------------+---------------------------------------+---------------+------------+-------------+--------------------------------------------------------------------------------------------------------------------------------+--------------+------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------|
# |  0 | Rapid City Obstetrics and Gynecology | Rapid City Obstetrics and Gynecology, 7236 Jordan Dr #100A, Rapid City, SD 57702           | 0x877d43e8e4fba5e7:0x6b14a31fe037c3e1 |               |    44.0146 |   -103.247  | ['Medical clinic', 'Fertility physician', 'Obstetrician-gynecologist', 'Surgeon']                                              |          3.9 |                8 |         | [['Thursday', '8AM–5PM'], ['Friday', '8AM–5PM'], ['Saturday', 'Closed'], ['Sunday', 'Closed'], ['Monday', '8AM–5PM'], ['Tuesday', '8AM–5PM'], ['Wednesday', '8AM–5PM']]                                             | {'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Appointments recommended']}                                                                                                                                                                                         | Opens soon ⋅ 8AM       | ['0x877d43184d2553df:0x1be151787a3bf2c0', '0x877d4351c0afb8e1:0xe3df8bc5938c87e1', '0x877d4319e335a195:0x2d96fbec1e681e2e', '0x877d4345d1d4f3f1:0x2675b1bae07e7715']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x877d43e8e4fba5e7:0x6b14a31fe037c3e1?authuser=-1&hl=en&gl=us |
# |  1 | Jerde Hall                           | Jerde Hall, S Lloyd St, Aberdeen, SD 57401                                                 | 0x52d244db89b809f5:0xa34e35f587826cdb |               |    45.4515 |    -98.4786 | ['University']                                                                                                                 |          3   |                1 |         |                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                                         |                        |                                                                                                                                                                                                               | https://www.google.com/maps/place//data=!4m2!3m1!1s0x52d244db89b809f5:0xa34e35f587826cdb?authuser=-1&hl=en&gl=us |
# |  2 | CRST WIC Office                      | CRST WIC Office, 16618 243rd Avenue, Eagle Butte, SD, Eagle Butte, SD 57625                | 0x532af45db8f30779:0xd9be9359f1e56178 |               |    44.9909 |   -101.24   |                                                                                                                                |          4.7 |                8 |         |                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                                         |                        | ['0x532af4588c5f80b1:0x30071640ecb03b5', '0x532af4588c5f80b1:0x321a759730d12039', '0x532af4f81756f2a1:0x12cefb53ed5d68b8']                                                                                    | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af45db8f30779:0xd9be9359f1e56178?authuser=-1&hl=en&gl=us |
# |  3 | Valley Implement Co                  | Valley Implement Co, 13045 SD-34, Sturgis, SD 57785                                        | 0x532d44ba713277c1:0x474c2d2edc8fff43 |               |    44.4156 |   -103.438  | ['Tractor dealer']                                                                                                             |          4.4 |                7 |         | [['Thursday', '8AM–5PM'], ['Friday', '8AM–5PM'], ['Saturday', 'Closed'], ['Sunday', 'Closed'], ['Monday', '8AM–5PM'], ['Tuesday', '8AM–5PM'], ['Wednesday', '8AM–5PM']]                                             | {'Service options': ['In-store shopping']}                                                                                                                                                                                                                                              | Opens soon ⋅ 8AM       | ['0x53329969baf9acf1:0x7075536a6208dca8', '0x533290aab1406e51:0x7878c6415d78828e', '0x532d5c0610341c73:0xeecc082077acbc61', '0x533283ce70d615b5:0x892bbbcb7d554a80', '0x877d5b816838de1b:0xcebb5d910a16850d'] | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532d44ba713277c1:0x474c2d2edc8fff43?authuser=-1&hl=en&gl=us |
# |  4 | United States Postal Service         | United States Postal Service, 121 Main St, Eagle Butte, SD 57625                           | 0x532af4f62ba8fbd7:0x948c4a91047d66db |               |    44.9967 |   -101.234  | ['Post office', 'Logistics service', 'Money order service', 'Shipping and mailing service']                                    |          3.6 |                5 |         | [['Thursday', '8:30–9:15AM'], ['Friday', '8:30–9:15AM'], ['Saturday', '11AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8:30–9:15AM'], ['Tuesday', '8:30–9:15AM'], ['Wednesday', '8:30–9:15AM']]                      | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   | Closed ⋅ Opens 8:30AM  | ['0x532af4fbbb05470d:0x4b9b34c8113c9856', '0x532af4f81756f2a1:0x12cefb53ed5d68b8', '0x532af4ff298c620b:0xae53d2845b4d337e', '0x532af4f81756f2a1:0x46faa792fa6a7bb6']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af4f62ba8fbd7:0x948c4a91047d66db?authuser=-1&hl=en&gl=us |
# |  5 | Rushmore Ambulatory Surgery Center   | Rushmore Ambulatory Surgery Center, 2490, 620 Sheridan Lake Rd # 101, Rapid City, SD 57702 | 0x877d5cabe8a919ad:0x350a26ff6e0873ee |               |    44.0804 |   -103.262  | ['Surgical center']                                                                                                            |          4   |                1 |         |                                                                                                                                                                                                                     | {'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Appointments recommended']}                                                                                                                                                                                         |                        | ['0x877d431901df27ab:0x19acf85e6212b911', '0x877d430365ed4cdb:0x8f866be59c8f5a44', '0x877d43010e463a51:0x89280fe234a9333f', '0x877d43293141fde7:0x99bb7bd1b8597e5', '0x877d43ec0420f89d:0x4cc0364f7848a5ff']  | https://www.google.com/maps/place//data=!4m2!3m1!1s0x877d5cabe8a919ad:0x350a26ff6e0873ee?authuser=-1&hl=en&gl=us |
# |  6 | Cheyenne River Health Center         | Cheyenne River Health Center, 24276 Airport Rd, Eagle Butte, SD 57625                      | 0x532af45cc1f6c30d:0x4313135505a6529e |               |    44.9918 |   -101.244  | ['Government']                                                                                                                 |          4.2 |                8 |         | [['Thursday', '8AM–5AM'], ['Friday', '8AM–6PM'], ['Saturday', 'Closed'], ['Sunday', '11AM–6PM'], ['Monday', '8AM–5AM'], ['Tuesday', '8AM–5AM'], ['Wednesday', '8AM–5AM']]                                           | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   | Opens soon ⋅ 8AM       | ['0x532af4f8747cb31f:0x4e6c66bb52376307', '0x532af4588c5f80b1:0x2ae2ac36f948de22', '0x532af4f81756f2a1:0xf7d109f6fa0c4fe', '0x532af4f81756f2a1:0x830d3cff35bf0a6f']                                           | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af45cc1f6c30d:0x4313135505a6529e?authuser=-1&hl=en&gl=us |
# |  7 | The Cheyenne River Episcopal Mission | The Cheyenne River Episcopal Mission, 500 Main St, Eagle Butte, SD 57625                   | 0x532af4588c5f80b1:0x1a2fac65a081154b |               |    45.0038 |   -101.234  | ['Religious organization', 'Episcopal church', 'Mission']                                                                      |          4.6 |                1 |         |                                                                                                                                                                                                                     | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   |                        | ['0x532af4f81756f2a1:0x62881eccc70c3378', '0x532af459b8fd6fcd:0xbde5bfc3624ce57b', '0x52d58206b7420203:0x745c682150234b33', '0x532af4f78f66b4df:0x5d432f9dce1222e8', '0x532af45892aea4ab:0x37a42d1b24cf8f2c'] | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af4588c5f80b1:0x1a2fac65a081154b?authuser=-1&hl=en&gl=us |
# |  8 | Cheyenne River Youth Project         | Cheyenne River Youth Project, 702 4th St, Eagle Butte, SD 57625                            | 0x532af4588c5f80b1:0x19574964b8ecd9a0 |               |    45.0048 |   -101.23   | ['Youth social services organization']                                                                                         |          4.5 |               35 |         | [['Thursday', '9AM–6PM'], ['Friday', '9AM–6PM'], ['Saturday', '9AM–6PM'], ['Sunday', '9AM–6PM'], ['Monday', '9AM–6PM'], ['Tuesday', '9AM–6PM'], ['Wednesday', '9AM–6PM']]                                           | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   | Closed ⋅ Opens 9AM     | ['0x532af4591ab43429:0xf80336b3927c5738', '0x532af4f900000001:0x50d1040f32f376e4', '0x532af4fc532cbdf1:0xb5b91bbd2f766874', '0x532af4588c5f80b1:0xbab48907d58a41e6']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af4588c5f80b1:0x19574964b8ecd9a0?authuser=-1&hl=en&gl=us |
# |  9 | On The Tree Church                   | On The Tree Church, Eagle Butte, SD 57625                                                  | 0x532a652e84352411:0x368586d0e7b82e7c |               |    45.1825 |   -101.075  | ['Church']                                                                                                                     |          5   |                1 |         |                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                                         |                        | ['0x532af4f81756f2a1:0x62881eccc70c3378', '0x532af4f78f66b4df:0x5d432f9dce1222e8', '0x532af45892aea4ab:0x37a42d1b24cf8f2c', '0x532af4588c5f80b1:0x1a2fac65a081154b']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532a652e84352411:0x368586d0e7b82e7c?authuser=-1&hl=en&gl=us |
# | 10 | Mni Mart Inc                         | Mni Mart Inc, Willow St, Eagle Butte, SD 57625                                             | 0x532af459b8fd6fcd:0x8799181e419ce6f1 |               |    45.0062 |   -101.239  | ['Convenience store']                                                                                                          |          3.4 |                5 |         | [['Thursday', '7AM–11PM'], ['Friday', '7AM–11PM'], ['Saturday', '7AM–12AM'], ['Sunday', 'Closed'], ['Monday', '7AM–11PM'], ['Tuesday', '7AM–11PM'], ['Wednesday', '7AM–11PM']]                                      | {'Service options': ['In-store shopping', 'Delivery'], 'Planning': ['Quick visit']}                                                                                                                                                                                                     | Open ⋅ Closes 11PM     | ['0x532af457ac014015:0x46d58a0055c9c83c', '0x532af4fe1b337eb1:0x758e7463580298bb', '0x532af4fe22d48317:0xc3d84504cc177495', '0x532af4587ff2f41f:0x813a7f503a66500c']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x532af459b8fd6fcd:0x8799181e419ce6f1?authuser=-1&hl=en&gl=us |
# | 11 | Whistlestop Pack Ship Mail           | Whistlestop Pack Ship Mail, 314 S Central Ave, Pierre, SD 57501                            | 0x878011014014942d:0x5671d35bcc499726 |               |    44.368  |   -100.356  | ['Shipping service']                                                                                                           |          4.5 |                4 |         | [['Thursday', '9:30AM–5:30PM'], ['Friday', '9:30AM–5:30PM'], ['Saturday', 'Closed'], ['Sunday', 'Closed'], ['Monday', '9:30AM–5:30PM'], ['Tuesday', '9:30AM–5:30PM'], ['Wednesday', '9:30AM–5:30PM']]               |                                                                                                                                                                                                                                                                                         | Closed ⋅ Opens 9:30AM  | ['0x878011f128a7daef:0x94eadb6b1b479609', '0x878011f13d59a7c7:0xfe3543a077e47a89', '0x878012e440fd8969:0x819b511fcd90cdd9', '0x8780123c9017b5a9:0xfdc4c26c3efdb09f']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x878011014014942d:0x5671d35bcc499726?authuser=-1&hl=en&gl=us |
# | 12 | Layered Elements Boutique            | Layered Elements Boutique, 701 N Phillips Ave Suite 135, Sioux Falls, SD 57104             | 0x878eb5a9ed2cf649:0x9021f191e27b0882 |               |    43.5557 |    -96.7271 | ["Women's clothing store", 'Boutique', 'Furniture accessories', 'Home goods store', 'Interior Decorator', 'Interior designer'] |          5   |                1 |         | [['Thursday', '10AM–6PM'], ['Friday', '10AM–6PM'], ['Saturday', '10AM–6PM'], ['Sunday', 'Closed'], ['Monday', '10AM–6PM'], ['Tuesday', '10AM–6PM'], ['Wednesday', '10AM–6PM']]                                      | {'From the business': ['Identifies as women-led'], 'Service options': ['Curbside pickup', 'Delivery', 'In-store pickup', 'In-store shopping'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit'], 'Payments': ['Checks', 'Debit cards', 'Credit cards']} | Closed ⋅ Opens 10AM    |                                                                                                                                                                                                               | https://www.google.com/maps/place//data=!4m2!3m1!1s0x878eb5a9ed2cf649:0x9021f191e27b0882?authuser=-1&hl=en&gl=us |
# | 13 | Christensen Radiator & Repair        | Christensen Radiator & Repair, 1918 Locust St, Yankton, SD 57078                           | 0x878fa1a8af01e4ef:0xc805e761b68be72c |               |    42.8883 |    -97.3995 | ['Auto repair shop']                                                                                                           |          4.7 |               18 |         | [['Thursday', '9AM–5:30PM'], ['Friday', '9AM–5:30PM'], ['Saturday', 'Closed'], ['Sunday', 'Closed'], ['Monday', '9AM–5:30PM'], ['Tuesday', '9AM–5:30PM'], ['Wednesday', '9AM–5:30PM']]                              | {'Accessibility': ['Wheelchair accessible entrance'], 'Offerings': ['Oil change'], 'Amenities': ['Mechanic'], 'Planning': ['Appointments recommended']}                                                                                                                                 | Closed ⋅ Opens 9AM     | ['0x878fa1a7d9a138cb:0x8fe444e847c04c1d', '0x878fa17281d3eba7:0x86d08a565053008d', '0x878fa0468382e52b:0x93ad57388e949776', '0x878fa1a8d1b02731:0xd9bb03d3776555bf', '0x878fa03f70d19c11:0xecfc87ad585915ef'] | https://www.google.com/maps/place//data=!4m2!3m1!1s0x878fa1a8af01e4ef:0xc805e761b68be72c?authuser=-1&hl=en&gl=us |
# | 14 | Knight Towing & Truck Repair         | Knight Towing & Truck Repair, 1810 U.S. 281 Frontage Rd, Aberdeen, SD 57401                | 0x52d245a4cd1c0433:0x18226a7470dfce53 |               |    45.4442 |    -98.5166 | ['Truck repair shop', 'Auto body shop', 'Towing service']                                                                      |          2.9 |               28 |         | [['Thursday', 'Open 24 hours'], ['Friday', 'Open 24 hours'], ['Saturday', 'Open 24 hours'], ['Sunday', 'Open 24 hours'], ['Monday', 'Open 24 hours'], ['Tuesday', 'Open 24 hours'], ['Wednesday', 'Open 24 hours']] | {'Accessibility': ['Wheelchair accessible entrance'], 'Offerings': ['Oil change'], 'Amenities': ['Mechanic']}                                                                                                                                                                           | Open 24 hours          | ['0x52d2435e26db24c1:0x3590644c18475025', '0x52d244fd87f940ff:0x5f3917d38878db72', '0x52d24486ea575071:0x22576af3b3bdd2e0', '0x52d24503bc461151:0x9a9fc5366034e50a']                                          | https://www.google.com/maps/place//data=!4m2!3m1!1s0x52d245a4cd1c0433:0x18226a7470dfce53?authuser=-1&hl=en&gl=us |
# | 15 | Eureka Kuchen Factory                | Eureka Kuchen Factory, 1407 J Ave, Eureka, SD 57437                                        | 0x52d401a6d6a2299d:0xf335ec250e371a0c |               |    45.767  |    -99.6302 | ['Bakery']                                                                                                                     |          4.4 |                8 |         |                                                                                                                                                                                                                     | {'Service options': ['Takeout', 'Delivery']}                                                                                                                                                                                                                                            |                        | ['0x52d401abe2735d95:0x81f49c494d66c54f', '0x52d401a961479373:0x25b14bce1bc1c25']                                                                                                                             | https://www.google.com/maps/place//data=!4m2!3m1!1s0x52d401a6d6a2299d:0xf335ec250e371a0c?authuser=-1&hl=en&gl=us |
# | 16 | Meadows North Apartments             | Meadows North Apartments, 717 11th St, Brookings, SD 57006                                 | 0x8789a302abe01e07:0xa8974f761e822ac6 |               |    44.3199 |    -96.7925 | ['Student dormitory']                                                                                                          |          3.3 |                3 |         |                                                                                                                                                                                                                     | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   |                        | ['0x8789a302bdb5a2d1:0xbbc3f9cfb3f74360', '0x8789a28ba641c20b:0xe917d22f33939c1', '0x8789a2fa230738dd:0xb42f2c4840914c48', '0x8789a2fdaa52521b:0x58d38e236b4d7fc0', '0x8789a2f754b97d45:0x313ca375314d02fa']  | https://www.google.com/maps/place//data=!4m2!3m1!1s0x8789a302abe01e07:0xa8974f761e822ac6?authuser=-1&hl=en&gl=us |
# | 17 | Solberg Hall                         | Solberg Hall, 907 Campanile Ave, Brookings, SD 57006                                       | 0x8789a3024ba3a451:0x314b5effb7f74038 |               |    44.3155 |    -96.7858 | ['Office']                                                                                                                     |          4   |                4 |         |                                                                                                                                                                                                                     | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   |                        | ['0x8789a2f975719cb7:0xcf001015eb8f88ce', '0x8789a2ff1d55a54f:0xf8545072bc9a384f', '0x8789a2fa230738dd:0xb42f2c4840914c48', '0x8789a2fa1dee688b:0x8f0c4212539dd6af', '0x8789a2f90a38d8eb:0x3f97a2e8642c9d22'] | https://www.google.com/maps/place//data=!4m2!3m1!1s0x8789a3024ba3a451:0x314b5effb7f74038?authuser=-1&hl=en&gl=us |
# | 18 | US Post Office                       | US Post Office, 790 22nd Ave S, Brookings, SD 57006                                        | 0x8789a26a02a2ed91:0xafb218b4f48a675d |               |    44.2979 |    -96.7697 | ['Post office']                                                                                                                |          2.8 |                4 |         | [['Wednesday', '7AM–10PM'], ['Thursday', '7AM–10PM'], ['Friday', '7AM–10PM'], ['Saturday', '7AM–10PM'], ['Sunday', '7AM–10PM'], ['Monday', '7AM–10PM'], ['Tuesday', '7AM–10PM']]                                    | {'Accessibility': ['Wheelchair accessible entrance']}                                                                                                                                                                                                                                   | Closed ⋅ Opens 7AM Thu | ['0x8789a307578f0e35:0xfbdfa98750d936d', '0x8789a26701933ead:0x81eb12991782e3c2', '0x8789a350835d43a9:0x70ff9bc815f93525', '0x8789a3a99fd44ff9:0x15e5c8c6f8f887be']                                           | https://www.google.com/maps/place//data=!4m2!3m1!1s0x8789a26a02a2ed91:0xafb218b4f48a675d?authuser=-1&hl=en&gl=us |
# | 19 | Dakota Territory Living              | Dakota Territory Living, 103 W 20th St S, Brookings, SD 57006                              | 0x8789a3c544e776b9:0x98f1aac8edab6320 |               |    44.2822 |    -96.8042 | ['Museum']                                                                                                                     |          3.8 |                5 |         |                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                                                         |                        | ['0x8789a3099218a6cf:0x5e5515103e9df1d4', '0x8789a2fd1bedeb2d:0xd0c36069b7975012', '0x8789aff30669d831:0x743d0cc555677024', '0x8789a24b93ff9789:0x13b6f229a357d3b5', '0x8789a3aa3ebb7f7f:0xc2b1166ec32c8b8f'] | https://www.google.com/maps/place//data=!4m2!3m1!1s0x8789a3c544e776b9:0x98f1aac8edab6320?authuser=-1&hl=en&gl=us |
# +----+--------------------------------------+--------------------------------------------------------------------------------------------+---------------------------------------+---------------+------------+-------------+--------------------------------------------------------------------------------------------------------------------------------+--------------+------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+

# %%
# Count missing per column
counts = reviews_data.isna().sum()
# Percent missing
percent = (reviews_data.isna().mean() * 100).round(2)
summary = pd.concat(
    [counts.rename("missing_count"), percent.rename("missing_pct")], axis=1
)
summary = summary.sort_values("missing_count", ascending=False)
print(f"\nMissing summary for reviews_data (n_rows={len(reviews_data)}):")
display(summary)  # if in notebook


# Remove reviews with missing essential columns
print(f"Reviews before cleaning: {len(reviews_data)}")
reviews_data = reviews_data.dropna(subset=["rating", "time", "gmap_id"])
print(f"Reviews after cleaning: {len(reviews_data)}")


# Create boolean feature for pictures
reviews_data["has_pics"] = reviews_data["pics"].notna()
print(f"Reviews with pictures: {reviews_data['has_pics'].sum()}")
# Out:
# Missing summary for reviews_data (n_rows=673048):
#          missing_count  missing_pct
# pics            657233        97.65
# resp            589840        87.64
# text            325966        48.43
# user_id              0         0.00
# name                 0         0.00
# time                 0         0.00
# rating               0         0.00
# gmap_id              0         0.00
# Reviews before cleaning: 673048
# Reviews after cleaning: 673048
# Reviews with pictures: 15815

# %%
# Remove businesses without gmap_id
print(f"Businesses before cleaning: {len(biz_meta)}")
biz_meta = biz_meta.dropna(subset=["gmap_id"])
print(f"Businesses after cleaning: {len(biz_meta)}")

# Convert price symbols to numeric levels ($ → 1, $$ → 2, etc.)
biz_meta["price_level"] = biz_meta["price"].str.len()
# Fill missing with 0 = unknown
biz_meta["price_level"] = biz_meta["price_level"].fillna(0).astype("int8")

print("Price level distribution:")
print(biz_meta["price_level"].value_counts().sort_index())
# Out:
# Businesses before cleaning: 14257
# Businesses after cleaning: 14257
# Price level distribution:
# price_level
# 0    12021
# 1     1147
# 2     1050
# 3       38
# 4        1
# Name: count, dtype: int64

# %%
# Define columns to keep for merging
keep_cols = [
    "gmap_id",  # join key
    "name",  # business name
    "category",  # type of business
    "avg_rating",  # business-level avg
    "num_of_reviews",  # business popularity
    "latitude",
    "longitude",  # optional
    "state",  # active/closed
]

# Filter to only existing columns
keep_cols = [c for c in keep_cols if c in biz_meta.columns]
print(f"Columns to keep: {keep_cols}")

# Create filtered metadata dataset
meta_small = biz_meta[keep_cols].drop_duplicates(subset=["gmap_id"]).copy()
print(f"Unique businesses in metadata: {len(meta_small)}")
# Out:
# Columns to keep: ['gmap_id', 'name', 'category', 'avg_rating', 'num_of_reviews', 'latitude', 'longitude', 'state']
# Unique businesses in metadata: 14167

# %% [markdown]
# ## Data Summary
#
# Understand the merged data

# %%
print("Final Data Summary:")
print(f"- Reviews data: {reviews_data.shape}")
print(f"- Business metadata: {meta_small.shape}")
print(f"- Unique businesses with reviews: {reviews_data['gmap_id'].nunique()}")
print(f"- Average rating: {reviews_data['rating'].mean():.2f}")
print(
    f"- Reviews with pictures: {reviews_data['has_pics'].sum()} ({reviews_data['has_pics'].mean()*100:.1f}%)"
)

print("\nTable after cleaning:")
print(tabulate(reviews_data.head(20), headers="keys", tablefmt="psql"))
# Out:
# Final Data Summary:
# - Reviews data: (673048, 9)
# - Business metadata: (14167, 8)
# - Unique businesses with reviews: 7255
# - Average rating: 4.33
# - Reviews with pictures: 15815 (2.3%)
#
# Table after cleaning:
# +----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+
# |    |     user_id | name                  |          time |   rating | text                                                                                                                                                                                                                   | pics   | resp   | gmap_id                               | has_pics   |
# |----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------|
# |  0 | 1.03563e+20 | Peri Gray             | 1516122675780 |        5 | Great place to care for our children.                                                                                                                                                                                  |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  1 | 1.01825e+20 | Suzy Berndt           | 1532922350314 |        5 | Th sw y are so nice                                                                                                                                                                                                    |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  2 | 1.08712e+20 | Rosemary Red Legs     | 1530969093932 |        5 | Went with my daughter                                                                                                                                                                                                  |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  3 | 1.01852e+20 | Brown Wolf            | 1537085635922 |        2 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  4 | 1.08987e+20 | C J Blue Coat         | 1474922375491 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  5 | 1.09706e+20 | JoRae Veit            | 1565233314034 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      |
# |  6 | 1.11136e+20 | hypnotherapycw        | 1487462368190 |        5 | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                         |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# |  7 | 1.08987e+20 | C J Blue Coat         | 1456395042607 |        2 | They dont have any activities for youth. If so, they don't promote it well.  No sporting events or camps, no family or community outreach, no kids seen playing in gym or play ground.  Where are the youth projects?? |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# |  8 | 1.15703e+20 | Tracy Finch           | 1564797033060 |        5 | So much done for the youth and community here!                                                                                                                                                                         |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# |  9 | 1.02721e+20 | Scotty Zacher         | 1503593980024 |        5 | Amazing work done here!                                                                                                                                                                                                |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 10 | 1.0539e+20  | RGLB                  | 1533091430745 |        5 | Great place for the children.                                                                                                                                                                                          |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 11 | 1.15716e+20 | Taylor Clinch         | 1469390149060 |        5 | Doing wonderful work.                                                                                                                                                                                                  |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 12 | 1.07464e+20 | sioux federation      | 1519776559550 |        4 | Helpful, and good service.                                                                                                                                                                                             |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 13 | 1.11191e+20 | Alecia Cowins         | 1557025223023 |        5 | Great people                                                                                                                                                                                                           |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 14 | 1.04959e+20 | Jana Jae              | 1560493464244 |        4 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 15 | 1.15705e+20 | LaBree Afraid Of Hawk | 1526098815852 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 16 | 1.16525e+20 | Leilih Smart          | 1543726962594 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 17 | 1.17307e+20 | Pete Ducheneaux       | 1558220022568 |        3 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 18 | 1.08366e+20 | Michon Shaving        | 1503266274834 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# | 19 | 1.09706e+20 | JoRae Veit            | 1565327036654 |        3 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      |
# +----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+

# %%
# Merge reviews with business metadata
merged_data = reviews_data.merge(meta_small, on="gmap_id", how="inner")
print(f"\nMerged data shape: {merged_data.shape}")

print("Merged Data Sample:")
print(tabulate(merged_data.head(20), headers="keys", tablefmt="psql"))
print(merged_data.info())
# Out:
# Merged data shape: (673048, 16)
# Merged Data Sample:
# +----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+------------------------------+----------------------------------------+--------------+------------------+------------+-------------+--------------------+
# |    |     user_id | name_x                |          time |   rating | text                                                                                                                                                                                                                   | pics   | resp   | gmap_id                               | has_pics   | name_y                       | category                               |   avg_rating |   num_of_reviews |   latitude |   longitude | state              |
# |----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+------------------------------+----------------------------------------+--------------+------------------+------------+-------------+--------------------|
# |  0 | 1.03563e+20 | Peri Gray             | 1516122675780 |        5 | Great place to care for our children.                                                                                                                                                                                  |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  1 | 1.01825e+20 | Suzy Berndt           | 1532922350314 |        5 | Th sw y are so nice                                                                                                                                                                                                    |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  2 | 1.08712e+20 | Rosemary Red Legs     | 1530969093932 |        5 | Went with my daughter                                                                                                                                                                                                  |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  3 | 1.01852e+20 | Brown Wolf            | 1537085635922 |        2 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  4 | 1.08987e+20 | C J Blue Coat         | 1474922375491 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  5 | 1.09706e+20 | JoRae Veit            | 1565233314034 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office              |                                        |          4.7 |                8 |    44.9909 |     -101.24 |                    |
# |  6 | 1.11136e+20 | hypnotherapycw        | 1487462368190 |        5 | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                         |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# |  7 | 1.08987e+20 | C J Blue Coat         | 1456395042607 |        2 | They dont have any activities for youth. If so, they don't promote it well.  No sporting events or camps, no family or community outreach, no kids seen playing in gym or play ground.  Where are the youth projects?? |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# |  8 | 1.15703e+20 | Tracy Finch           | 1564797033060 |        5 | So much done for the youth and community here!                                                                                                                                                                         |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# |  9 | 1.02721e+20 | Scotty Zacher         | 1503593980024 |        5 | Amazing work done here!                                                                                                                                                                                                |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 10 | 1.0539e+20  | RGLB                  | 1533091430745 |        5 | Great place for the children.                                                                                                                                                                                          |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 11 | 1.15716e+20 | Taylor Clinch         | 1469390149060 |        5 | Doing wonderful work.                                                                                                                                                                                                  |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 12 | 1.07464e+20 | sioux federation      | 1519776559550 |        4 | Helpful, and good service.                                                                                                                                                                                             |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 13 | 1.11191e+20 | Alecia Cowins         | 1557025223023 |        5 | Great people                                                                                                                                                                                                           |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 14 | 1.04959e+20 | Jana Jae              | 1560493464244 |        4 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 15 | 1.15705e+20 | LaBree Afraid Of Hawk | 1526098815852 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 16 | 1.16525e+20 | Leilih Smart          | 1543726962594 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 17 | 1.17307e+20 | Pete Ducheneaux       | 1558220022568 |        3 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 18 | 1.08366e+20 | Michon Shaving        | 1503266274834 |        5 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# | 19 | 1.09706e+20 | JoRae Veit            | 1565327036654 |        3 |                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project | ['Youth social services organization'] |          4.5 |               35 |    45.0048 |     -101.23 | Closed ⋅ Opens 9AM |
# +----+-------------+-----------------------+---------------+----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+------------------------------+----------------------------------------+--------------+------------------+------------+-------------+--------------------+
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673048 entries, 0 to 673047
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         673048 non-null  float64
#  1   name_x          673048 non-null  object
#  2   time            673048 non-null  int64
#  3   rating          673048 non-null  int64
#  4   text            347082 non-null  object
#  5   pics            15815 non-null   object
#  6   resp            83208 non-null   object
#  7   gmap_id         673048 non-null  object
#  8   has_pics        673048 non-null  bool
#  9   name_y          673048 non-null  object
#  10  category        672891 non-null  object
#  11  avg_rating      673048 non-null  float64
#  12  num_of_reviews  673048 non-null  int64
#  13  latitude        673048 non-null  float64
#  14  longitude       673048 non-null  float64
#  15  state           412307 non-null  object
# dtypes: bool(1), float64(4), int64(3), object(8)
# memory usage: 77.7+ MB
# None

# %% [markdown]
# ## Text classification with LLM (e.g., OpenAI GPT-4)
#
# Will remove non text rows from dataset and classify reviews into categories such as complaint, praise, suggestion, etc.

# %%
# Remove reviews with no text

print(f"Reviews before removing non-text: {len(merged_data)}")

# Soft filter: keep rows where 'text' is not null/empty after stripping whitespace
merged_data_og = merged_data.copy()
md_wtext = merged_data[merged_data["text"].str.strip().astype(bool)]

print(f"Reviews after removing non-text: {len(md_wtext)}")

print(md_wtext.info())

print(tabulate(md_wtext.head(20), headers="keys", tablefmt="psql"))
# print(md_wtext.head(20).index)

md_wtext["token_count"] = md_wtext["text"].apply(lambda x: len(str(x).split()))
total_tokens = md_wtext["token_count"].sum()
print(f"Total tokens in text reviews: {total_tokens}")
# Out:
# Reviews before removing non-text: 673048
# Reviews after removing non-text: 347082
# <class 'pandas.core.frame.DataFrame'>
# Index: 347082 entries, 0 to 673041
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         347082 non-null  float64
#  1   name_x          347082 non-null  object
#  2   time            347082 non-null  int64
#  3   rating          347082 non-null  int64
#  4   text            347082 non-null  object
#  5   pics            14238 non-null   object
#  6   resp            49330 non-null   object
#  7   gmap_id         347082 non-null  object
#  8   has_pics        347082 non-null  bool
#  9   name_y          347082 non-null  object
#  10  category        347002 non-null  object
#  11  avg_rating      347082 non-null  float64
#  12  num_of_reviews  347082 non-null  int64
#  13  latitude        347082 non-null  float64
#  14  longitude       347082 non-null  float64
#  15  state           214448 non-null  object
# dtypes: bool(1), float64(4), int64(3), object(8)
# memory usage: 42.7+ MB
# None
# +----+-------------+-------------------+---------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+-------------------------------+-----------------------------------------------------------+--------------+------------------+------------+-------------+--------------------+
# |    |     user_id | name_x            |          time |   rating | text                                                                                                                                                                                                                                                                                                              | pics   | resp   | gmap_id                               | has_pics   | name_y                        | category                                                  |   avg_rating |   num_of_reviews |   latitude |   longitude | state              |
# |----+-------------+-------------------+---------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+-------------------------------+-----------------------------------------------------------+--------------+------------------+------------+-------------+--------------------|
# |  0 | 1.03563e+20 | Peri Gray         | 1516122675780 |        5 | Great place to care for our children.                                                                                                                                                                                                                                                                             |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office               |                                                           |          4.7 |                8 |    44.9909 |   -101.24   |                    |
# |  1 | 1.01825e+20 | Suzy Berndt       | 1532922350314 |        5 | Th sw y are so nice                                                                                                                                                                                                                                                                                               |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office               |                                                           |          4.7 |                8 |    44.9909 |   -101.24   |                    |
# |  2 | 1.08712e+20 | Rosemary Red Legs | 1530969093932 |        5 | Went with my daughter                                                                                                                                                                                                                                                                                             |        |        | 0x532af45db8f30779:0xd9be9359f1e56178 | False      | CRST WIC Office               |                                                           |          4.7 |                8 |    44.9909 |   -101.24   |                    |
# |  6 | 1.11136e+20 | hypnotherapycw    | 1487462368190 |        5 | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                                                                                                                    |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# |  7 | 1.08987e+20 | C J Blue Coat     | 1456395042607 |        2 | They dont have any activities for youth. If so, they don't promote it well.  No sporting events or camps, no family or community outreach, no kids seen playing in gym or play ground.  Where are the youth projects??                                                                                            |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# |  8 | 1.15703e+20 | Tracy Finch       | 1564797033060 |        5 | So much done for the youth and community here!                                                                                                                                                                                                                                                                    |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# |  9 | 1.02721e+20 | Scotty Zacher     | 1503593980024 |        5 | Amazing work done here!                                                                                                                                                                                                                                                                                           |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# | 10 | 1.0539e+20  | RGLB              | 1533091430745 |        5 | Great place for the children.                                                                                                                                                                                                                                                                                     |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# | 11 | 1.15716e+20 | Taylor Clinch     | 1469390149060 |        5 | Doing wonderful work.                                                                                                                                                                                                                                                                                             |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# | 12 | 1.07464e+20 | sioux federation  | 1519776559550 |        4 | Helpful, and good service.                                                                                                                                                                                                                                                                                        |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# | 13 | 1.11191e+20 | Alecia Cowins     | 1557025223023 |        5 | Great people                                                                                                                                                                                                                                                                                                      |        |        | 0x532af4588c5f80b1:0x19574964b8ecd9a0 | False      | Cheyenne River Youth Project  | ['Youth social services organization']                    |          4.5 |               35 |    45.0048 |   -101.23   | Closed ⋅ Opens 9AM |
# | 24 | 1.13307e+20 | William Payer Sr  | 1628990813772 |        1 | Not what they say n don't get back to on time.. if u say u will call on Monday then I would l to hear what's what on Monday.. waisted my time n I have more than one work truck, I asked to get fixed/looked at..                                                                                                 |        |        | 0x878fa1a8af01e4ef:0xc805e761b68be72c | False      | Christensen Radiator & Repair | ['Auto repair shop']                                      |          4.7 |               18 |    42.8883 |    -97.3995 | Closed ⋅ Opens 9AM |
# | 25 | 1.11235e+20 | Cindy Mead        | 1515968072464 |        5 | Very good to me will go back and I tell every one about them                                                                                                                                                                                                                                                      |        |        | 0x878fa1a8af01e4ef:0xc805e761b68be72c | False      | Christensen Radiator & Repair | ['Auto repair shop']                                      |          4.7 |               18 |    42.8883 |    -97.3995 | Closed ⋅ Opens 9AM |
# | 26 | 1.16933e+20 | LaVern Story      | 1533855513032 |        4 | awesome work done on vehicles                                                                                                                                                                                                                                                                                     |        |        | 0x878fa1a8af01e4ef:0xc805e761b68be72c | False      | Christensen Radiator & Repair | ['Auto repair shop']                                      |          4.7 |               18 |    42.8883 |    -97.3995 | Closed ⋅ Opens 9AM |
# | 27 | 1.17965e+20 | Kary Gregoire     | 1538448667734 |        5 | Excellent battery sales and service!                                                                                                                                                                                                                                                                              |        |        | 0x878fa1a8af01e4ef:0xc805e761b68be72c | False      | Christensen Radiator & Repair | ['Auto repair shop']                                      |          4.7 |               18 |    42.8883 |    -97.3995 | Closed ⋅ Opens 9AM |
# | 28 | 1.14317e+20 | Sara Hawk         | 1486841744009 |        5 | Service on my van                                                                                                                                                                                                                                                                                                 |        |        | 0x878fa1a8af01e4ef:0xc805e761b68be72c | False      | Christensen Radiator & Repair | ['Auto repair shop']                                      |          4.7 |               18 |    42.8883 |    -97.3995 | Closed ⋅ Opens 9AM |
# | 31 | 1.04346e+20 | Lance Kolb        | 1602276649878 |        5 | Great service. Very friendly staff.                                                                                                                                                                                                                                                                               |        |        | 0x52d245a4cd1c0433:0x18226a7470dfce53 | False      | Knight Towing & Truck Repair  | ['Truck repair shop', 'Auto body shop', 'Towing service'] |          2.9 |               28 |    45.4442 |    -98.5166 | Open 24 hours      |
# | 32 | 1.18273e+20 | Wade Christiansen | 1569090890038 |        1 | Truck broke down and I had them tow the truck to their shop. They were able to repair right away and the charge was not bad. One month later had to make the same repair and then we realized that the previous repair was done less than professional. Never again. There are other places to have repairs done. |        |        | 0x52d245a4cd1c0433:0x18226a7470dfce53 | False      | Knight Towing & Truck Repair  | ['Truck repair shop', 'Auto body shop', 'Towing service'] |          2.9 |               28 |    45.4442 |    -98.5166 | Open 24 hours      |
# | 33 | 1.15577e+20 | Mackenzie Brandon | 1610910352362 |        1 | Don't use.                                                                                                                                                                                                                                                                                                        |        |        | 0x52d245a4cd1c0433:0x18226a7470dfce53 | False      | Knight Towing & Truck Repair  | ['Truck repair shop', 'Auto body shop', 'Towing service'] |          2.9 |               28 |    45.4442 |    -98.5166 | Open 24 hours      |
# | 34 | 1.14628e+20 | Mike Andsandrad   | 1452014673658 |        5 | Knight Towing came out and towed our Tractor Trailer ASAP !!! Remember this is South Dakota ;)                                                                                                                                                                                                                    |        |        | 0x52d245a4cd1c0433:0x18226a7470dfce53 | False      | Knight Towing & Truck Repair  | ['Truck repair shop', 'Auto body shop', 'Towing service'] |          2.9 |               28 |    45.4442 |    -98.5166 | Open 24 hours      |
# +----+-------------+-------------------+---------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+--------+---------------------------------------+------------+-------------------------------+-----------------------------------------------------------+--------------+------------------+------------+-------------+--------------------+
# Total tokens in text reviews: 6175290
# /var/folders/71/ljlh3xcn18gbcvg1hb44wqdh0000gn/T/ipykernel_32224/2013198431.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   md_wtext["token_count"] = md_wtext["text"].apply(lambda x: len(str(x).split()))

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import openai

load_dotenv()  # take environment variables from .env file
# Out:
# False

# %% [markdown]
# Create ReviewClassifier class to handle classification using LLM.

# %%
class ReviewSchema(BaseModel):
    advertisement: bool
    advertisement_confidence_score: float
    irrelevant: bool
    irrelevant_confidence_score: float
    fake_rant: bool
    fake_rant_confidence_score: float


class ReviewClassifier:
    def __init__(self, api_key, isLocalLLM, model_name):
        self.api_key = api_key
        self.isLocalLLM = isLocalLLM
        self.modelName = model_name
        if isLocalLLM:
            self.client = OpenAI(
                api_key="lm_studio", base_url="http://localhost:1234/v1"
            )  # Placeholder for local LLM client
        else:
            self.client = OpenAI(api_key=api_key)

    def getModelName(self):
        return self.modelName

    def classify_review(self, review_text, business_name, business_category) -> dict:
        """
        Classify a single review for policy violations using OpenAI API
        """

        prompt = f"""
                    You are a review moderator. Analyze this review for policy violations:

                    Review given by user: "{review_text}"
                    For Business name: "{business_name}"
                    Under Business category: "{business_category}"

                    Check for these violations strictly:
                    1. ADVERTISEMENT: Contains promotional content, links, phone numbers, or marketing
                    Positive Example: "Check out our website for more info!"
                    Negative Example: "Great food and service!"

                    2. IRRELEVANT: Not about the business (talks about personal life, politics, etc.) / off-topic / illegible texts
                    Positive Example: "I love hiking in the nearby mountains." / "sds fsdaf as"
                    Negative Example: "The pizza here is fantastic!"

                    3. FAKE_RANT: Negative review from someone who clearly never visited
                    Positive Example: "This place is a disaster, I would never go back!" (when evidence shows they never visited)
                    Negative Example: "I had a bad experience, but I might give it another try."

                    For each violation type, respond with true/false and a confidence score (0.0-1.0).
                    0.0: Very unlikely
                    1.0: Very sure it's true

                    Respond in JSON format like this:
                    {{
                        "advertisement": true/false,
                        "advertisement_confidence_score": float (0.0-1.0),
                        "irrelevant": true/false,
                        "irrelevant_confidence_score": float (0.0-1.0),
                        "fake_rant": true/false,
                        "fake_rant_confidence_score": float (0.0-1.0)
                    }}
                    Only respond with the JSON object, no extra text.
                    """

        review_schema = {
            "type": "json_schema",
            "json_schema": {
                "name": "classify_review",
                "schema": {
                    "type": "object",
                    "properties": {
                        "advertisement": {
                            "type": "boolean",
                            "description": "True if the review is an advertisement",
                        },
                        "advertisement_confidence_score": {
                            "type": "number",
                            "description": "Confidence level for advertisement classification (0-1)",
                        },
                        "irrelevant": {
                            "type": "boolean",
                            "description": "True if the review is irrelevant",
                        },
                        "irrelevant_confidence_score": {
                            "type": "number",
                            "description": "Confidence level for irrelevant classification (0-1)",
                        },
                        "fake_rant": {
                            "type": "boolean",
                            "description": "True if the review is a fake rant",
                        },
                        "fake_rant_confidence_score": {
                            "type": "number",
                            "description": "Confidence level for fake rant classification (0-1)",
                        },
                    },
                    "required": [
                        "advertisement",
                        "advertisement_confidence_score",
                        "irrelevant",
                        "irrelevant_confidence_score",
                        "fake_rant",
                        "fake_rant_confidence_score",
                    ],
                },
            },
        }

        try:
            if not self.isLocalLLM:
                print("Using ChatGPT model for classification")
                response = self.client.beta.chat.completions.parse(
                    model=self.modelName,
                    messages=[{"role": "user", "content": prompt}],
                    # temperature=0.1,
                    max_completion_tokens=1000,
                    tools=[openai.pydantic_function_tool(ReviewSchema)],
                    response_format=ReviewSchema,
                    # tools=[{
                    #     "type": "function",
                    #     "function": {
                    #         "name": "classify_review",
                    #         "description": "Classify review for policy violations",
                    #         "parameters": {
                    #             "type": "object",
                    #             "properties": {
                    #                 "advertisement": {"type": "boolean", "description": "True if the review is an advertisement"},
                    #                 "advertisement_confidence": {"type": "number", "description": "Confidence level for advertisement classification (0-1)"},
                    #                 "irrelevant": {"type": "boolean", "description": "True if the review is irrelevant"},
                    #                 "irrelevant_confidence": {"type": "number", "description": "Confidence level for irrelevant classification (0-1)"},
                    #                 "fake_rant": {"type": "boolean", "description": "True if the review is a fake rant"},
                    #                 "fake_rant_confidence": {"type": "number", "description": "Confidence level for fake rant classification (0-1)"}
                    #             },
                    #             "required": ["advertisement", "advertisement_confidence", "irrelevant", "irrelevant_confidence", "fake_rant", "fake_rant_confidence"]
                    #         }
                    #     }
                    # }]
                )

            else:
                print("Using local model for classification")

                response = self.client.chat.completions.create(
                    model=self.modelName,
                    messages=[{"role": "user", "content": prompt}],
                    temperature=0.1,
                    max_tokens=500,
                    response_format=review_schema,  # type: ignore
                )

            # Parse the JSON response
            print(f"response: ", response)
            result_text = response.choices[0].message.content
            result = json.loads(result_text) if result_text else {}

            return {
                "advertisement": result.get("advertisement", False),
                "advertisement_confidence_score": result.get(
                    "advertisement_confidence_score", 0.0
                ),
                "irrelevant": result.get("irrelevant", False),
                "irrelevant_confidence_score": result.get(
                    "irrelevant_confidence_score", 0.0
                ),
                "fake_rant": result.get("fake_rant", False),
                "fake_rant_confidence_score": result.get(
                    "fake_rant_confidence_score", 0.0
                ),
            }

        except Exception as e:
            print(f"Error classifying review: {e}")
            return {"advertisement": False, "irrelevant": False, "fake_rant": False}


classifier = ReviewClassifier(
    api_key=os.getenv("OPENAI_API_KEY") or "", isLocalLLM=False, model_name="gpt-5-nano"
)

# %% [markdown]
# qwen14b: 2 min 40 sec for 100 reviews
# qwen4b: 1 min 5 sec for 100 reviews
# minimax: 1 min 45 sec for 100 reviews

# %%
# Test the function on a few reviews
print("🧪 Testing classification function...")

# Get some sample reviews from your data
selected_data = md_wtext.head(2)

result_list = []

start_time = time.time()
for i, review in enumerate(selected_data["text"]):
    print(f"\n--- Review {i+1} ---")
    print(f"Text: {review[:200]}...")

    result = classifier.classify_review(
        review_text=review,
        business_name=selected_data["name_y"].values[i],
        business_category=selected_data["category"].values[i],
    )
    print(result)
    result_list.append(result)

    print(f"\nClassification Result {i+1}:")
    print(f"Advertisement: {'❌ YES' if result['advertisement'] else '✅ NO'}")
    print(
        f"Advertisement Confidence: {result.get('advertisement_confidence_score', 0.0):.2f}"
    )
    print(f"Irrelevant: {'❌ YES' if result['irrelevant'] else '✅ NO'}")
    print(
        f"Irrelevant Confidence: {result.get('irrelevant_confidence_score', 0.0):.2f}"
    )
    print(f"Fake Rant: {'❌ YES' if result['fake_rant'] else '✅ NO'}")
    print(f"Fake Rant Confidence: {result.get('fake_rant_confidence_score', 0.0):.2f}")

end_time = time.time()
time_taken = end_time - start_time

# Convert results to DataFrame
results_df = pd.DataFrame(result_list)

# Save results to CSV
results_df.to_csv(
    f"classification_results_{classifier.getModelName().replace('/', '-')}_{time_taken:2f}_{len(sample_reviews)}_{time.time()}.csv"
)
# Out:
# 🧪 Testing classification function...
#
# --- Review 1 ---
# Text: Great place to care for our children....
# Using ChatGPT model for classification
# Error classifying review: Error code: 401 - {'error': {'message': "You didn't provide an API key. You need to provide your API key in an Authorization header using Bearer auth (i.e. Authorization: Bearer YOUR_KEY), or as the password field (with blank username) if you're accessing the API from your browser and are prompted for a username and password. You can obtain an API key from https://platform.openai.com/account/api-keys.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# {'advertisement': False, 'irrelevant': False, 'fake_rant': False}
#
# Classification Result 1:
# Advertisement: ✅ NO
# Advertisement Confidence: 0.00
# Irrelevant: ✅ NO
# Irrelevant Confidence: 0.00
# Fake Rant: ✅ NO
# Fake Rant Confidence: 0.00
#
# --- Review 2 ---
# Text: Th sw y are so nice...
# Using ChatGPT model for classification
# Error classifying review: Error code: 401 - {'error': {'message': "You didn't provide an API key. You need to provide your API key in an Authorization header using Bearer auth (i.e. Authorization: Bearer YOUR_KEY), or as the password field (with blank username) if you're accessing the API from your browser and are prompted for a username and password. You can obtain an API key from https://platform.openai.com/account/api-keys.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# {'advertisement': False, 'irrelevant': False, 'fake_rant': False}
#
# Classification Result 2:
# Advertisement: ✅ NO
# Advertisement Confidence: 0.00
# Irrelevant: ✅ NO
# Irrelevant Confidence: 0.00
# Fake Rant: ✅ NO
# Fake Rant Confidence: 0.00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 42
#      38 results_df = pd.DataFrame(result_list)
#      40 # Save results to CSV
#      41 results_df.to_csv(
# ---> 42     f"classification_results_{classifier.getModelName().replace('/', '-')}_{time_taken:2f}_{len(sample_reviews)}_{time.time()}.csv"
#      43 )
#
# NameError: name 'sample_reviews' is not defined

# %%
# --- Cell: Batch Classification Setup ---
import os, math, json, time
from pathlib import Path
from openai import OpenAI
from typing import Literal


class ReviewSchema(BaseModel):
    advertisement: bool
    advertisement_confidence_score: float
    irrelevant: bool
    irrelevant_confidence_score: float
    fake_rant: bool
    fake_rant_confidence_score: float


class BatchReviewClassifier:
    def __init__(self, api_key, model_name="gpt-5-nano", output_dir="batch_runs"):
        self.client = OpenAI(api_key=api_key)
        self.model_name = model_name
        self.output_dir = Path(output_dir)
        self.output_dir.mkdir(exist_ok=True)

    def build_prompt(
        self, review_text: str, business_name: str, business_category: str
    ) -> str:
        return f"""
            You are a strict review moderator. 
            
            Classify the following user review for policy violations based on the following context:
            Review:
            \"\"\"{review_text}\"\"\"
            Business Name: {business_name}
            Category: {business_category}

            Classify for:
            1. advertisement (promotional / link / phone / self-promo)
            2. irrelevant (off-topic, personal life, politics, gibberish, not related to business name / category)
            3. fake_rant (appears fabricated / unlikely real visit)

            Respond in JSON format like this:
            {{
            "advertisement": true/false,
            "advertisement_confidence_score": float (0-1),
            "irrelevant": true/false,
            "irrelevant_confidence_score": float (0-1),
            "fake_rant": true/false,
            "fake_rant_confidence_score": float (0-1)
            }}

            Rules:
            - No extra keys.
            - All confidence scores must be valid numbers 0–1.
            - If unsure -> choose false and confidence <= 0.4.
            - Never include commentary outside JSON.
            """.strip()

    def prepare_batch_file(
        self, df_source, max_rows_per_batch=50000, batch_prefix="batch"
    ):
        """Prepare JSONL batch input files from DataFrame"""
        # Calculate batches needed
        total_rows = len(df_source)
        num_batches = math.ceil(total_rows / max_rows_per_batch)

        print(f"Preparing {total_rows} rows in {num_batches} batch file(s)")
        print(f"Max rows per batch: {max_rows_per_batch}")

        batch_files = []

        for batch_idx in range(num_batches):
            start_idx = batch_idx * max_rows_per_batch
            end_idx = min(start_idx + max_rows_per_batch, total_rows)
            chunk = df_source.iloc[start_idx:end_idx].copy()

            # Create batch input file
            timestamp = int(time.time())
            input_path = (
                self.output_dir / f"{batch_prefix}_{batch_idx:03d}_{timestamp}.jsonl"
            )

            with input_path.open("w", encoding="utf-8") as f:
                for idx, (orig_idx, row) in enumerate(chunk.iterrows()):
                    custom_id = f"review_{orig_idx}"  # Use original DataFrame index

                    prompt_text = self.build_prompt(
                        review_text=str(row["text"]).strip()[:500],
                        business_name=str(row.get("name_y", "") or row.get("name", ""))[
                            :50
                        ],
                        business_category=str(row.get("category", ""))[:30],
                    )

                    body = {
                        "model": self.model_name,
                        # "temperature": 0.1,
                        "messages": [
                            # {"role": "system", "content": "You output ONLY valid JSON object per instructions."},
                            {"role": "user", "content": prompt_text}
                        ],
                        "response_format": {
                            "type": "json_schema",
                            "json_schema": {
                                "name": "review_classification",  # Required name field
                                "strict": True,  # Enable strict mode for better compliance
                                "schema": {
                                    "type": "object",
                                    "properties": {
                                        "advertisement": {
                                            "type": "boolean",
                                            "description": "True if the review is an advertisement",
                                        },
                                        "advertisement_confidence_score": {
                                            "type": "number",
                                            "description": "Confidence level for advertisement classification (0-1)",
                                        },
                                        "irrelevant": {
                                            "type": "boolean",
                                            "description": "True if the review is irrelevant",
                                        },
                                        "irrelevant_confidence_score": {
                                            "type": "number",
                                            "description": "Confidence level for irrelevant classification (0-1)",
                                        },
                                        "fake_rant": {
                                            "type": "boolean",
                                            "description": "True if the review is a fake rant",
                                        },
                                        "fake_rant_confidence_score": {
                                            "type": "number",
                                            "description": "Confidence level for fake rant classification (0-1)",
                                        },
                                    },
                                    "required": [
                                        "advertisement",
                                        "advertisement_confidence_score",
                                        "irrelevant",
                                        "irrelevant_confidence_score",
                                        "fake_rant",
                                        "fake_rant_confidence_score",
                                    ],
                                    "additionalProperties": False,
                                },
                            },
                        },
                        "max_completion_tokens": 2500,
                    }

                    line_obj = {
                        "custom_id": custom_id,
                        "method": "POST",
                        "url": "/v1/chat/completions",
                        "body": body,
                    }
                    f.write(json.dumps(line_obj) + "\n")

            batch_files.append(input_path)
            print(
                f"✅ Batch {batch_idx+1}/{num_batches}: {len(chunk)} rows -> {input_path.name}"
            )

        return batch_files

    def submit_batch(self, input_file_path, completion_window: Literal["24h"] = "24h"):
        """Submit a single batch file to OpenAI"""
        print(f"📤 Uploading {input_file_path.name}...")

        with input_file_path.open("rb") as f:
            uploaded_file = self.client.files.create(file=f, purpose="batch")

        print(f"✅ File uploaded: {uploaded_file.id}")

        # Create batch job
        batch = self.client.batches.create(
            input_file_id=uploaded_file.id,
            endpoint="/v1/chat/completions",
            completion_window=completion_window,
        )

        print(f"🚀 Batch created: {batch.id} (status: {batch.status})")
        return batch

    def submit_all_batches(
        self, batch_files, completion_window: Literal["24h"] = "24h"
    ):
        """Submit batch files sequentially, waiting for each to complete before submitting the next"""
        completed_batches = []

        for i, file_path in enumerate(batch_files):
            try:
                print(
                    f"\n🚀 Submitting batch {i+1}/{len(batch_files)}: {file_path.name}"
                )

                # Submit the batch
                batch = self.submit_batch(file_path, completion_window)

                # Wait for this batch to complete before submitting the next
                print(
                    f"⏳ Waiting for batch {batch.id} to complete before submitting next..."
                )
                completed_batch = self.poll_single_batch(batch.id)
                completed_batches.append(completed_batch)

                print(
                    f"✅ Batch {i+1}/{len(batch_files)} completed with status: {completed_batch.status}"
                )

                # Small delay between batches
                time.sleep(2)

            except Exception as e:
                print(f"❌ Error with batch {file_path.name}: {e}")
                continue

        return completed_batches

    def poll_single_batch(self, batch_id, poll_interval=30):
        """Poll a single batch until completion"""
        while True:
            batch_status = self.check_batch_status(batch_id)
            print(f"🔄 Batch {batch_id}: {batch_status.status}")

            if batch_status.status in ["completed", "failed", "expired", "cancelled"]:
                return batch_status

            time.sleep(poll_interval)

    def check_batch_status(self, batch_id):
        """Check status of a single batch"""
        return self.client.batches.retrieve(batch_id)

    def poll_all_batches(self, submitted_batches, poll_interval=30):
        """Poll all batches until completion"""
        pending_batches = submitted_batches.copy()
        completed_batches = []

        while pending_batches:
            print(f"\n🔄 Polling {len(pending_batches)} pending batches...")

            for batch_info in pending_batches.copy():
                batch_id = batch_info.id
                latest_batch = self.check_batch_status(batch_id)

                print(f"Batch {batch_id}: {latest_batch.status}")

                if latest_batch.status in [
                    "completed",
                    "failed",
                    "expired",
                    "cancelled",
                ]:
                    completed_batches.append(latest_batch)
                    pending_batches.remove(batch_info)

            if pending_batches:
                print(f"⏳ Waiting {poll_interval}s before next check...")
                time.sleep(poll_interval)

        return completed_batches

    def download_and_parse_results(self, completed_batches):
        """Download and parse all batch results"""
        all_results = []

        for batch_info in completed_batches:
            batch_id = batch_info.id
            final_status = batch_info.status

            if final_status != "completed":
                print(f"⚠️ Skipping batch {batch_id} (status: {final_status.status})")
                continue

            if not batch_info.output_file_id:
                print(f"⚠️ No output file for batch {batch_id}")
                print(
                    f" Error file contents: \n {self.client.files.content(batch_info.error_file_id).text}"
                )
                continue

            # Download results
            print(f"📥 Downloading results for batch {batch_id}...")
            output_content = self.client.files.content(batch_info.output_file_id)
            print(output_content.text)

            # Save locally
            output_path = self.output_dir / f"{batch_id}_results.jsonl"
            with output_path.open("w", encoding="utf-8") as f:
                f.write(output_content.text)

            # Parse results
            batch_results = self.parse_batch_output(output_path)
            all_results.extend(batch_results)
            print(f"✅ Parsed {len(batch_results)} results from {batch_id}")

        return all_results

    def parse_batch_output(self, output_file_path):
        """Parse a single batch output file"""
        results = []

        with output_file_path.open("r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line.strip())
                    custom_id = obj.get("custom_id")
                    error = obj.get("error")

                    if error:
                        # Error case - use defaults
                        result = {
                            "custom_id": custom_id,
                            "advertisement": False,
                            "advertisement_confidence_score": 0.0,
                            "irrelevant": False,
                            "irrelevant_confidence_score": 0.0,
                            "fake_rant": False,
                            "fake_rant_confidence_score": 0.0,
                            "error": str(error),
                        }
                    else:
                        # Success case - parse model response
                        response_body = obj.get("response", {}).get("body", {})
                        choices = response_body.get("choices", [])

                        if choices:
                            content = choices[0]["message"]["content"]
                            parsed_content = self.parse_model_response(content)

                            result = {"custom_id": custom_id, **parsed_content}
                        else:
                            # No choices - use defaults
                            result = {
                                "custom_id": custom_id,
                                "advertisement": False,
                                "advertisement_confidence_score": 0.0,
                                "irrelevant": False,
                                "irrelevant_confidence_score": 0.0,
                                "fake_rant": False,
                                "fake_rant_confidence_score": 0.0,
                                "error": "No choices in response",
                            }

                    results.append(result)

                except Exception as e:
                    print(f"⚠️ Error parsing line: {e}")
                    continue

        return results

    def parse_model_response(self, content):
        """Parse model's JSON response with fallbacks"""
        try:
            # Try direct JSON parse
            data = json.loads(content)
        except:
            # Try extracting JSON from text
            try:
                start = content.find("{")
                end = content.rfind("}") + 1
                if start >= 0 and end > start:
                    data = json.loads(content[start:end])
                else:
                    raise ValueError("No JSON found")
            except:
                # Complete fallback
                data = {}

        # Ensure all required fields with defaults
        return {
            "advertisement": data.get("advertisement", False),
            "advertisement_confidence_score": float(
                data.get("advertisement_confidence_score", 0.0)
            ),
            "irrelevant": data.get("irrelevant", False),
            "irrelevant_confidence_score": float(
                data.get("irrelevant_confidence_score", 0.0)
            ),
            "fake_rant": data.get("fake_rant", False),
            "fake_rant_confidence_score": float(
                data.get("fake_rant_confidence_score", 0.0)
            ),
        }

    def process_full_dataset(self, df_source, max_rows_per_batch=50000, auto_poll=True):
        """Complete end-to-end batch processing with sequential submission"""
        print(f"🚀 Starting batch processing for {len(df_source)} rows")

        # Step 1: Prepare batch files
        batch_files = self.prepare_batch_file(df_source, max_rows_per_batch)

        # Step 2: Submit batches sequentially (each waits for previous to complete)
        print(
            f"📤 Submitting {len(batch_files)} batches sequentially to respect token limits..."
        )
        completed_batches = self.submit_all_batches(batch_files)

        if not completed_batches:
            print("❌ No batches were successfully completed")
            return None

        print(f"✅ All {len(completed_batches)} batches completed!")

        # Step 3: Download and parse all results
        all_results = self.download_and_parse_results(completed_batches)

        # Step 4: Convert to DataFrame and merge
        results_df = pd.DataFrame(all_results)

        if len(results_df) > 0:
            # Extract original index from custom_id
            results_df["orig_index"] = (
                results_df["custom_id"]
                .str.replace("review_", "", regex=False)
                .astype(int)
            )

            # Merge back with original data
            final_df = self.merge_results_with_source(df_source, results_df)

            # Save results
            timestamp = int(time.time())
            output_file = f"classified_reviews_{self.model_name.replace('/', '-')}_{timestamp}.csv"
            final_df.to_csv(output_file, index=True)
            final_df.to_parquet(
                f"classified_reviews_{self.model_name.replace('/', '-')}_{timestamp}.parquet",
                index=True,
            )

            print(f"🎉 Complete! Results saved to: {output_file}")
            print(f"📊 Processed: {len(final_df)} rows")
            print(f"✅ Success rate: {(len(results_df) / len(df_source) * 100):.1f}%")

            return final_df
        else:
            print("❌ No results obtained from batches")
            return None

    def merge_results_with_source(self, df_source, results_df):
        """Merge classification results back with source DataFrame"""
        # df_source already has its original index intact
        # We just need to merge on it directly

        # Ensure results_df has the original index properly extracted
        if "orig_index" not in results_df.columns:
            results_df["orig_index"] = (
                results_df["custom_id"]
                .str.replace("review_", "", regex=False)
                .astype(int)
            )

        # Create a copy of source with index as column for merging
        source_with_index = df_source.copy()
        source_with_index["orig_index"] = source_with_index.index

        # Merge on original index
        merged = source_with_index.merge(
            results_df[
                [
                    "orig_index",
                    "advertisement",
                    "advertisement_confidence_score",
                    "irrelevant",
                    "irrelevant_confidence_score",
                    "fake_rant",
                    "fake_rant_confidence_score",
                ]
            ],
            on="orig_index",
            how="left",
        )

        # Set the index back to the original index
        merged = merged.set_index("orig_index")
        merged.index.name = df_source.index.name  # Preserve original index name

        return merged


# Initialize the batch classifier
batch_classifier = BatchReviewClassifier(
    api_key=os.getenv("OPENAI_API_KEY"),
    model_name="gpt-5-nano",
    output_dir="batch_runs",
)

print("✅ Batch classifier initialized")
print(f"📊 Dataset ready: {len(md_wtext)} rows")
# Out:
# ✅ Batch classifier initialized
# 📊 Dataset ready: 347082 rows

# %% [markdown]
# ## --- Cell: Run Full Batch Processing ---

# %%
# --- Cell: Run Full Batch Processing ---

print("🚀 Processing all rows with automatic batch management...")

final_results = batch_classifier.process_full_dataset(
    df_source=md_wtext.head(10000),
    max_rows_per_batch=2500,  # OpenAI allows up to 50k requests per batch
    auto_poll=True,  # Automatically wait for completion
)

if final_results is not None:
    print("\n📋 Classification Summary:")
    print(f"Total reviews: {len(final_results)}")
    print(f"Advertisements: {final_results['advertisement'].sum()}")
    print(f"Irrelevant: {final_results['irrelevant'].sum()}")
    print(f"Fake rants: {final_results['fake_rant'].sum()}")

    # Show sample results
    print("\n🔍 Sample Results:")
    sample_cols = [
        "text",
        "advertisement",
        "advertisement_confidence_score",
        "irrelevant",
        "irrelevant_confidence_score",
        "fake_rant",
        "fake_rant_confidence_score",
    ]
    print(
        tabulate(final_results[sample_cols].head(10), headers="keys", tablefmt="psql")
    )
# Out:
# 🚀 Processing all rows with automatic batch management...
# 🚀 Starting batch processing for 347082 rows
# Preparing 347082 rows in 139 batch file(s)
# Max rows per batch: 2500
# ✅ Batch 1/139: 2500 rows -> batch_000_1756478012.jsonl
# ✅ Batch 2/139: 2500 rows -> batch_001_1756478012.jsonl
# ✅ Batch 3/139: 2500 rows -> batch_002_1756478012.jsonl
# ✅ Batch 4/139: 2500 rows -> batch_003_1756478012.jsonl
# ✅ Batch 5/139: 2500 rows -> batch_004_1756478013.jsonl
# ✅ Batch 6/139: 2500 rows -> batch_005_1756478013.jsonl
# ✅ Batch 7/139: 2500 rows -> batch_006_1756478013.jsonl
# ✅ Batch 8/139: 2500 rows -> batch_007_1756478013.jsonl
# ✅ Batch 9/139: 2500 rows -> batch_008_1756478013.jsonl
# ✅ Batch 10/139: 2500 rows -> batch_009_1756478013.jsonl
# ✅ Batch 11/139: 2500 rows -> batch_010_1756478013.jsonl
# ✅ Batch 12/139: 2500 rows -> batch_011_1756478013.jsonl
# ✅ Batch 13/139: 2500 rows -> batch_012_1756478013.jsonl
# ✅ Batch 14/139: 2500 rows -> batch_013_1756478014.jsonl
# ✅ Batch 15/139: 2500 rows -> batch_014_1756478014.jsonl
# ✅ Batch 16/139: 2500 rows -> batch_015_1756478014.jsonl
# ✅ Batch 17/139: 2500 rows -> batch_016_1756478014.jsonl
# ✅ Batch 18/139: 2500 rows -> batch_017_1756478014.jsonl
# ✅ Batch 19/139: 2500 rows -> batch_018_1756478014.jsonl
# ✅ Batch 20/139: 2500 rows -> batch_019_1756478014.jsonl
# ✅ Batch 21/139: 2500 rows -> batch_020_1756478014.jsonl
# ✅ Batch 22/139: 2500 rows -> batch_021_1756478015.jsonl
# ✅ Batch 23/139: 2500 rows -> batch_022_1756478015.jsonl
# ✅ Batch 24/139: 2500 rows -> batch_023_1756478015.jsonl
# ✅ Batch 25/139: 2500 rows -> batch_024_1756478015.jsonl
# ✅ Batch 26/139: 2500 rows -> batch_025_1756478015.jsonl
# ✅ Batch 27/139: 2500 rows -> batch_026_1756478015.jsonl
# ✅ Batch 28/139: 2500 rows -> batch_027_1756478015.jsonl
# ✅ Batch 29/139: 2500 rows -> batch_028_1756478015.jsonl
# ✅ Batch 30/139: 2500 rows -> batch_029_1756478015.jsonl
# ✅ Batch 31/139: 2500 rows -> batch_030_1756478016.jsonl
# ✅ Batch 32/139: 2500 rows -> batch_031_1756478016.jsonl
# ✅ Batch 33/139: 2500 rows -> batch_032_1756478016.jsonl
# ✅ Batch 34/139: 2500 rows -> batch_033_1756478016.jsonl
# ✅ Batch 35/139: 2500 rows -> batch_034_1756478016.jsonl
# ✅ Batch 36/139: 2500 rows -> batch_035_1756478016.jsonl
# ✅ Batch 37/139: 2500 rows -> batch_036_1756478016.jsonl
# ✅ Batch 38/139: 2500 rows -> batch_037_1756478016.jsonl
# ✅ Batch 39/139: 2500 rows -> batch_038_1756478016.jsonl
# ✅ Batch 40/139: 2500 rows -> batch_039_1756478016.jsonl
# ✅ Batch 41/139: 2500 rows -> batch_040_1756478017.jsonl
# ✅ Batch 42/139: 2500 rows -> batch_041_1756478017.jsonl
# ✅ Batch 43/139: 2500 rows -> batch_042_1756478017.jsonl
# ✅ Batch 44/139: 2500 rows -> batch_043_1756478017.jsonl
# ✅ Batch 45/139: 2500 rows -> batch_044_1756478017.jsonl
# ✅ Batch 46/139: 2500 rows -> batch_045_1756478017.jsonl
# ✅ Batch 47/139: 2500 rows -> batch_046_1756478017.jsonl
# ✅ Batch 48/139: 2500 rows -> batch_047_1756478017.jsonl
# ✅ Batch 49/139: 2500 rows -> batch_048_1756478017.jsonl
# ✅ Batch 50/139: 2500 rows -> batch_049_1756478018.jsonl
# ✅ Batch 51/139: 2500 rows -> batch_050_1756478018.jsonl
# ✅ Batch 52/139: 2500 rows -> batch_051_1756478018.jsonl
# ✅ Batch 53/139: 2500 rows -> batch_052_1756478018.jsonl
# ✅ Batch 54/139: 2500 rows -> batch_053_1756478018.jsonl
# ✅ Batch 55/139: 2500 rows -> batch_054_1756478018.jsonl
# ✅ Batch 56/139: 2500 rows -> batch_055_1756478018.jsonl
# ✅ Batch 57/139: 2500 rows -> batch_056_1756478018.jsonl
# ✅ Batch 58/139: 2500 rows -> batch_057_1756478018.jsonl
# ✅ Batch 59/139: 2500 rows -> batch_058_1756478019.jsonl
# ✅ Batch 60/139: 2500 rows -> batch_059_1756478019.jsonl
# ✅ Batch 61/139: 2500 rows -> batch_060_1756478019.jsonl
# ✅ Batch 62/139: 2500 rows -> batch_061_1756478019.jsonl
# ✅ Batch 63/139: 2500 rows -> batch_062_1756478019.jsonl
# ✅ Batch 64/139: 2500 rows -> batch_063_1756478019.jsonl
# ✅ Batch 65/139: 2500 rows -> batch_064_1756478019.jsonl
# ✅ Batch 66/139: 2500 rows -> batch_065_1756478019.jsonl
# ✅ Batch 67/139: 2500 rows -> batch_066_1756478019.jsonl
# ✅ Batch 68/139: 2500 rows -> batch_067_1756478019.jsonl
# ✅ Batch 69/139: 2500 rows -> batch_068_1756478020.jsonl
# ✅ Batch 70/139: 2500 rows -> batch_069_1756478020.jsonl
# ✅ Batch 71/139: 2500 rows -> batch_070_1756478020.jsonl
# ✅ Batch 72/139: 2500 rows -> batch_071_1756478020.jsonl
# ✅ Batch 73/139: 2500 rows -> batch_072_1756478020.jsonl
# ✅ Batch 74/139: 2500 rows -> batch_073_1756478020.jsonl
# ✅ Batch 75/139: 2500 rows -> batch_074_1756478020.jsonl
# ✅ Batch 76/139: 2500 rows -> batch_075_1756478020.jsonl
# ✅ Batch 77/139: 2500 rows -> batch_076_1756478020.jsonl
# ✅ Batch 78/139: 2500 rows -> batch_077_1756478021.jsonl
# ✅ Batch 79/139: 2500 rows -> batch_078_1756478021.jsonl
# ✅ Batch 80/139: 2500 rows -> batch_079_1756478021.jsonl
# ✅ Batch 81/139: 2500 rows -> batch_080_1756478021.jsonl
# ✅ Batch 82/139: 2500 rows -> batch_081_1756478021.jsonl
# ✅ Batch 83/139: 2500 rows -> batch_082_1756478021.jsonl
# ✅ Batch 84/139: 2500 rows -> batch_083_1756478021.jsonl
# ✅ Batch 85/139: 2500 rows -> batch_084_1756478021.jsonl
# ✅ Batch 86/139: 2500 rows -> batch_085_1756478022.jsonl
# ✅ Batch 87/139: 2500 rows -> batch_086_1756478022.jsonl
# ✅ Batch 88/139: 2500 rows -> batch_087_1756478022.jsonl
# ✅ Batch 89/139: 2500 rows -> batch_088_1756478022.jsonl
# ✅ Batch 90/139: 2500 rows -> batch_089_1756478022.jsonl
# ✅ Batch 91/139: 2500 rows -> batch_090_1756478022.jsonl
# ✅ Batch 92/139: 2500 rows -> batch_091_1756478022.jsonl
# ✅ Batch 93/139: 2500 rows -> batch_092_1756478022.jsonl
# ✅ Batch 94/139: 2500 rows -> batch_093_1756478022.jsonl
# ✅ Batch 95/139: 2500 rows -> batch_094_1756478022.jsonl
# ✅ Batch 96/139: 2500 rows -> batch_095_1756478023.jsonl
# ✅ Batch 97/139: 2500 rows -> batch_096_1756478023.jsonl
# ✅ Batch 98/139: 2500 rows -> batch_097_1756478023.jsonl
# ✅ Batch 99/139: 2500 rows -> batch_098_1756478023.jsonl
# ✅ Batch 100/139: 2500 rows -> batch_099_1756478023.jsonl
# ✅ Batch 101/139: 2500 rows -> batch_100_1756478023.jsonl
# ✅ Batch 102/139: 2500 rows -> batch_101_1756478023.jsonl
# ✅ Batch 103/139: 2500 rows -> batch_102_1756478023.jsonl
# ✅ Batch 104/139: 2500 rows -> batch_103_1756478023.jsonl
# ✅ Batch 105/139: 2500 rows -> batch_104_1756478024.jsonl
# ✅ Batch 106/139: 2500 rows -> batch_105_1756478024.jsonl
# ✅ Batch 107/139: 2500 rows -> batch_106_1756478024.jsonl
# ✅ Batch 108/139: 2500 rows -> batch_107_1756478024.jsonl
# ✅ Batch 109/139: 2500 rows -> batch_108_1756478024.jsonl
# ✅ Batch 110/139: 2500 rows -> batch_109_1756478024.jsonl
# ✅ Batch 111/139: 2500 rows -> batch_110_1756478024.jsonl
# ✅ Batch 112/139: 2500 rows -> batch_111_1756478024.jsonl
# ✅ Batch 113/139: 2500 rows -> batch_112_1756478024.jsonl
# ✅ Batch 114/139: 2500 rows -> batch_113_1756478025.jsonl
# ✅ Batch 115/139: 2500 rows -> batch_114_1756478025.jsonl
# ✅ Batch 116/139: 2500 rows -> batch_115_1756478025.jsonl
# ✅ Batch 117/139: 2500 rows -> batch_116_1756478025.jsonl
# ✅ Batch 118/139: 2500 rows -> batch_117_1756478025.jsonl
# ✅ Batch 119/139: 2500 rows -> batch_118_1756478025.jsonl
# ✅ Batch 120/139: 2500 rows -> batch_119_1756478025.jsonl
# ✅ Batch 121/139: 2500 rows -> batch_120_1756478025.jsonl
# ✅ Batch 122/139: 2500 rows -> batch_121_1756478025.jsonl
# ✅ Batch 123/139: 2500 rows -> batch_122_1756478026.jsonl
# ✅ Batch 124/139: 2500 rows -> batch_123_1756478026.jsonl
# ✅ Batch 125/139: 2500 rows -> batch_124_1756478026.jsonl
# ✅ Batch 126/139: 2500 rows -> batch_125_1756478026.jsonl
# ✅ Batch 127/139: 2500 rows -> batch_126_1756478026.jsonl
# ✅ Batch 128/139: 2500 rows -> batch_127_1756478026.jsonl
# ✅ Batch 129/139: 2500 rows -> batch_128_1756478026.jsonl
# ✅ Batch 130/139: 2500 rows -> batch_129_1756478026.jsonl
# ✅ Batch 131/139: 2500 rows -> batch_130_1756478026.jsonl
# ✅ Batch 132/139: 2500 rows -> batch_131_1756478027.jsonl
# ✅ Batch 133/139: 2500 rows -> batch_132_1756478027.jsonl
# ✅ Batch 134/139: 2500 rows -> batch_133_1756478027.jsonl
# ✅ Batch 135/139: 2500 rows -> batch_134_1756478027.jsonl
# ✅ Batch 136/139: 2500 rows -> batch_135_1756478027.jsonl
# ✅ Batch 137/139: 2500 rows -> batch_136_1756478027.jsonl
# ✅ Batch 138/139: 2500 rows -> batch_137_1756478027.jsonl
# ✅ Batch 139/139: 2082 rows -> batch_138_1756478027.jsonl
# 📤 Submitting 139 batches sequentially to respect token limits...
#
# 🚀 Submitting batch 1/139: batch_000_1756478012.jsonl
# 📤 Uploading batch_000_1756478012.jsonl...
# ✅ File uploaded: file-Szvz45zFBhUzFSAX9FGVqE
# 🚀 Batch created: batch_68b1ba53a8e881909d4cdafd61b5ae21 (status: validating)
# ⏳ Waiting for batch batch_68b1ba53a8e881909d4cdafd61b5ae21 to complete before submitting next...
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: validating
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: validating
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: validating
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: in_progress
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: finalizing
# 🔄 Batch batch_68b1ba53a8e881909d4cdafd61b5ae21: completed
# ✅ Batch 1/139 completed with status: completed
#
# 🚀 Submitting batch 2/139: batch_001_1756478012.jsonl
# 📤 Uploading batch_001_1756478012.jsonl...
# ❌ Error with batch batch_001_1756478012.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_001_1756478012.jsonl'
#
# 🚀 Submitting batch 3/139: batch_002_1756478012.jsonl
# 📤 Uploading batch_002_1756478012.jsonl...
# ❌ Error with batch batch_002_1756478012.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_002_1756478012.jsonl'
#
# 🚀 Submitting batch 4/139: batch_003_1756478012.jsonl
# 📤 Uploading batch_003_1756478012.jsonl...
# ❌ Error with batch batch_003_1756478012.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_003_1756478012.jsonl'
#
# 🚀 Submitting batch 5/139: batch_004_1756478013.jsonl
# 📤 Uploading batch_004_1756478013.jsonl...
# ❌ Error with batch batch_004_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_004_1756478013.jsonl'
#
# 🚀 Submitting batch 6/139: batch_005_1756478013.jsonl
# 📤 Uploading batch_005_1756478013.jsonl...
# ❌ Error with batch batch_005_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_005_1756478013.jsonl'
#
# 🚀 Submitting batch 7/139: batch_006_1756478013.jsonl
# 📤 Uploading batch_006_1756478013.jsonl...
# ❌ Error with batch batch_006_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_006_1756478013.jsonl'
#
# 🚀 Submitting batch 8/139: batch_007_1756478013.jsonl
# 📤 Uploading batch_007_1756478013.jsonl...
# ❌ Error with batch batch_007_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_007_1756478013.jsonl'
#
# 🚀 Submitting batch 9/139: batch_008_1756478013.jsonl
# 📤 Uploading batch_008_1756478013.jsonl...
# ❌ Error with batch batch_008_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_008_1756478013.jsonl'
#
# 🚀 Submitting batch 10/139: batch_009_1756478013.jsonl
# 📤 Uploading batch_009_1756478013.jsonl...
# ❌ Error with batch batch_009_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_009_1756478013.jsonl'
#
# 🚀 Submitting batch 11/139: batch_010_1756478013.jsonl
# 📤 Uploading batch_010_1756478013.jsonl...
# ❌ Error with batch batch_010_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_010_1756478013.jsonl'
#
# 🚀 Submitting batch 12/139: batch_011_1756478013.jsonl
# 📤 Uploading batch_011_1756478013.jsonl...
# ❌ Error with batch batch_011_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_011_1756478013.jsonl'
#
# 🚀 Submitting batch 13/139: batch_012_1756478013.jsonl
# 📤 Uploading batch_012_1756478013.jsonl...
# ❌ Error with batch batch_012_1756478013.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_012_1756478013.jsonl'
#
# 🚀 Submitting batch 14/139: batch_013_1756478014.jsonl
# 📤 Uploading batch_013_1756478014.jsonl...
# ❌ Error with batch batch_013_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_013_1756478014.jsonl'
#
# 🚀 Submitting batch 15/139: batch_014_1756478014.jsonl
# 📤 Uploading batch_014_1756478014.jsonl...
# ❌ Error with batch batch_014_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_014_1756478014.jsonl'
#
# 🚀 Submitting batch 16/139: batch_015_1756478014.jsonl
# 📤 Uploading batch_015_1756478014.jsonl...
# ❌ Error with batch batch_015_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_015_1756478014.jsonl'
#
# 🚀 Submitting batch 17/139: batch_016_1756478014.jsonl
# 📤 Uploading batch_016_1756478014.jsonl...
# ❌ Error with batch batch_016_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_016_1756478014.jsonl'
#
# 🚀 Submitting batch 18/139: batch_017_1756478014.jsonl
# 📤 Uploading batch_017_1756478014.jsonl...
# ❌ Error with batch batch_017_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_017_1756478014.jsonl'
#
# 🚀 Submitting batch 19/139: batch_018_1756478014.jsonl
# 📤 Uploading batch_018_1756478014.jsonl...
# ❌ Error with batch batch_018_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_018_1756478014.jsonl'
#
# 🚀 Submitting batch 20/139: batch_019_1756478014.jsonl
# 📤 Uploading batch_019_1756478014.jsonl...
# ❌ Error with batch batch_019_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_019_1756478014.jsonl'
#
# 🚀 Submitting batch 21/139: batch_020_1756478014.jsonl
# 📤 Uploading batch_020_1756478014.jsonl...
# ❌ Error with batch batch_020_1756478014.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_020_1756478014.jsonl'
#
# 🚀 Submitting batch 22/139: batch_021_1756478015.jsonl
# 📤 Uploading batch_021_1756478015.jsonl...
# ❌ Error with batch batch_021_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_021_1756478015.jsonl'
#
# 🚀 Submitting batch 23/139: batch_022_1756478015.jsonl
# 📤 Uploading batch_022_1756478015.jsonl...
# ❌ Error with batch batch_022_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_022_1756478015.jsonl'
#
# 🚀 Submitting batch 24/139: batch_023_1756478015.jsonl
# 📤 Uploading batch_023_1756478015.jsonl...
# ❌ Error with batch batch_023_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_023_1756478015.jsonl'
#
# 🚀 Submitting batch 25/139: batch_024_1756478015.jsonl
# 📤 Uploading batch_024_1756478015.jsonl...
# ❌ Error with batch batch_024_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_024_1756478015.jsonl'
#
# 🚀 Submitting batch 26/139: batch_025_1756478015.jsonl
# 📤 Uploading batch_025_1756478015.jsonl...
# ❌ Error with batch batch_025_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_025_1756478015.jsonl'
#
# 🚀 Submitting batch 27/139: batch_026_1756478015.jsonl
# 📤 Uploading batch_026_1756478015.jsonl...
# ❌ Error with batch batch_026_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_026_1756478015.jsonl'
#
# 🚀 Submitting batch 28/139: batch_027_1756478015.jsonl
# 📤 Uploading batch_027_1756478015.jsonl...
# ❌ Error with batch batch_027_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_027_1756478015.jsonl'
#
# 🚀 Submitting batch 29/139: batch_028_1756478015.jsonl
# 📤 Uploading batch_028_1756478015.jsonl...
# ❌ Error with batch batch_028_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_028_1756478015.jsonl'
#
# 🚀 Submitting batch 30/139: batch_029_1756478015.jsonl
# 📤 Uploading batch_029_1756478015.jsonl...
# ❌ Error with batch batch_029_1756478015.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_029_1756478015.jsonl'
#
# 🚀 Submitting batch 31/139: batch_030_1756478016.jsonl
# 📤 Uploading batch_030_1756478016.jsonl...
# ❌ Error with batch batch_030_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_030_1756478016.jsonl'
#
# 🚀 Submitting batch 32/139: batch_031_1756478016.jsonl
# 📤 Uploading batch_031_1756478016.jsonl...
# ❌ Error with batch batch_031_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_031_1756478016.jsonl'
#
# 🚀 Submitting batch 33/139: batch_032_1756478016.jsonl
# 📤 Uploading batch_032_1756478016.jsonl...
# ❌ Error with batch batch_032_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_032_1756478016.jsonl'
#
# 🚀 Submitting batch 34/139: batch_033_1756478016.jsonl
# 📤 Uploading batch_033_1756478016.jsonl...
# ❌ Error with batch batch_033_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_033_1756478016.jsonl'
#
# 🚀 Submitting batch 35/139: batch_034_1756478016.jsonl
# 📤 Uploading batch_034_1756478016.jsonl...
# ❌ Error with batch batch_034_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_034_1756478016.jsonl'
#
# 🚀 Submitting batch 36/139: batch_035_1756478016.jsonl
# 📤 Uploading batch_035_1756478016.jsonl...
# ❌ Error with batch batch_035_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_035_1756478016.jsonl'
#
# 🚀 Submitting batch 37/139: batch_036_1756478016.jsonl
# 📤 Uploading batch_036_1756478016.jsonl...
# ❌ Error with batch batch_036_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_036_1756478016.jsonl'
#
# 🚀 Submitting batch 38/139: batch_037_1756478016.jsonl
# 📤 Uploading batch_037_1756478016.jsonl...
# ❌ Error with batch batch_037_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_037_1756478016.jsonl'
#
# 🚀 Submitting batch 39/139: batch_038_1756478016.jsonl
# 📤 Uploading batch_038_1756478016.jsonl...
# ❌ Error with batch batch_038_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_038_1756478016.jsonl'
#
# 🚀 Submitting batch 40/139: batch_039_1756478016.jsonl
# 📤 Uploading batch_039_1756478016.jsonl...
# ❌ Error with batch batch_039_1756478016.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_039_1756478016.jsonl'
#
# 🚀 Submitting batch 41/139: batch_040_1756478017.jsonl
# 📤 Uploading batch_040_1756478017.jsonl...
# ❌ Error with batch batch_040_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_040_1756478017.jsonl'
#
# 🚀 Submitting batch 42/139: batch_041_1756478017.jsonl
# 📤 Uploading batch_041_1756478017.jsonl...
# ❌ Error with batch batch_041_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_041_1756478017.jsonl'
#
# 🚀 Submitting batch 43/139: batch_042_1756478017.jsonl
# 📤 Uploading batch_042_1756478017.jsonl...
# ❌ Error with batch batch_042_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_042_1756478017.jsonl'
#
# 🚀 Submitting batch 44/139: batch_043_1756478017.jsonl
# 📤 Uploading batch_043_1756478017.jsonl...
# ❌ Error with batch batch_043_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_043_1756478017.jsonl'
#
# 🚀 Submitting batch 45/139: batch_044_1756478017.jsonl
# 📤 Uploading batch_044_1756478017.jsonl...
# ❌ Error with batch batch_044_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_044_1756478017.jsonl'
#
# 🚀 Submitting batch 46/139: batch_045_1756478017.jsonl
# 📤 Uploading batch_045_1756478017.jsonl...
# ❌ Error with batch batch_045_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_045_1756478017.jsonl'
#
# 🚀 Submitting batch 47/139: batch_046_1756478017.jsonl
# 📤 Uploading batch_046_1756478017.jsonl...
# ❌ Error with batch batch_046_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_046_1756478017.jsonl'
#
# 🚀 Submitting batch 48/139: batch_047_1756478017.jsonl
# 📤 Uploading batch_047_1756478017.jsonl...
# ❌ Error with batch batch_047_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_047_1756478017.jsonl'
#
# 🚀 Submitting batch 49/139: batch_048_1756478017.jsonl
# 📤 Uploading batch_048_1756478017.jsonl...
# ❌ Error with batch batch_048_1756478017.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_048_1756478017.jsonl'
#
# 🚀 Submitting batch 50/139: batch_049_1756478018.jsonl
# 📤 Uploading batch_049_1756478018.jsonl...
# ❌ Error with batch batch_049_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_049_1756478018.jsonl'
#
# 🚀 Submitting batch 51/139: batch_050_1756478018.jsonl
# 📤 Uploading batch_050_1756478018.jsonl...
# ❌ Error with batch batch_050_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_050_1756478018.jsonl'
#
# 🚀 Submitting batch 52/139: batch_051_1756478018.jsonl
# 📤 Uploading batch_051_1756478018.jsonl...
# ❌ Error with batch batch_051_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_051_1756478018.jsonl'
#
# 🚀 Submitting batch 53/139: batch_052_1756478018.jsonl
# 📤 Uploading batch_052_1756478018.jsonl...
# ❌ Error with batch batch_052_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_052_1756478018.jsonl'
#
# 🚀 Submitting batch 54/139: batch_053_1756478018.jsonl
# 📤 Uploading batch_053_1756478018.jsonl...
# ❌ Error with batch batch_053_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_053_1756478018.jsonl'
#
# 🚀 Submitting batch 55/139: batch_054_1756478018.jsonl
# 📤 Uploading batch_054_1756478018.jsonl...
# ❌ Error with batch batch_054_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_054_1756478018.jsonl'
#
# 🚀 Submitting batch 56/139: batch_055_1756478018.jsonl
# 📤 Uploading batch_055_1756478018.jsonl...
# ❌ Error with batch batch_055_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_055_1756478018.jsonl'
#
# 🚀 Submitting batch 57/139: batch_056_1756478018.jsonl
# 📤 Uploading batch_056_1756478018.jsonl...
# ❌ Error with batch batch_056_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_056_1756478018.jsonl'
#
# 🚀 Submitting batch 58/139: batch_057_1756478018.jsonl
# 📤 Uploading batch_057_1756478018.jsonl...
# ❌ Error with batch batch_057_1756478018.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_057_1756478018.jsonl'
#
# 🚀 Submitting batch 59/139: batch_058_1756478019.jsonl
# 📤 Uploading batch_058_1756478019.jsonl...
# ❌ Error with batch batch_058_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_058_1756478019.jsonl'
#
# 🚀 Submitting batch 60/139: batch_059_1756478019.jsonl
# 📤 Uploading batch_059_1756478019.jsonl...
# ❌ Error with batch batch_059_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_059_1756478019.jsonl'
#
# 🚀 Submitting batch 61/139: batch_060_1756478019.jsonl
# 📤 Uploading batch_060_1756478019.jsonl...
# ❌ Error with batch batch_060_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_060_1756478019.jsonl'
#
# 🚀 Submitting batch 62/139: batch_061_1756478019.jsonl
# 📤 Uploading batch_061_1756478019.jsonl...
# ❌ Error with batch batch_061_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_061_1756478019.jsonl'
#
# 🚀 Submitting batch 63/139: batch_062_1756478019.jsonl
# 📤 Uploading batch_062_1756478019.jsonl...
# ❌ Error with batch batch_062_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_062_1756478019.jsonl'
#
# 🚀 Submitting batch 64/139: batch_063_1756478019.jsonl
# 📤 Uploading batch_063_1756478019.jsonl...
# ❌ Error with batch batch_063_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_063_1756478019.jsonl'
#
# 🚀 Submitting batch 65/139: batch_064_1756478019.jsonl
# 📤 Uploading batch_064_1756478019.jsonl...
# ❌ Error with batch batch_064_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_064_1756478019.jsonl'
#
# 🚀 Submitting batch 66/139: batch_065_1756478019.jsonl
# 📤 Uploading batch_065_1756478019.jsonl...
# ❌ Error with batch batch_065_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_065_1756478019.jsonl'
#
# 🚀 Submitting batch 67/139: batch_066_1756478019.jsonl
# 📤 Uploading batch_066_1756478019.jsonl...
# ❌ Error with batch batch_066_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_066_1756478019.jsonl'
#
# 🚀 Submitting batch 68/139: batch_067_1756478019.jsonl
# 📤 Uploading batch_067_1756478019.jsonl...
# ❌ Error with batch batch_067_1756478019.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_067_1756478019.jsonl'
#
# 🚀 Submitting batch 69/139: batch_068_1756478020.jsonl
# 📤 Uploading batch_068_1756478020.jsonl...
# ❌ Error with batch batch_068_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_068_1756478020.jsonl'
#
# 🚀 Submitting batch 70/139: batch_069_1756478020.jsonl
# 📤 Uploading batch_069_1756478020.jsonl...
# ❌ Error with batch batch_069_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_069_1756478020.jsonl'
#
# 🚀 Submitting batch 71/139: batch_070_1756478020.jsonl
# 📤 Uploading batch_070_1756478020.jsonl...
# ❌ Error with batch batch_070_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_070_1756478020.jsonl'
#
# 🚀 Submitting batch 72/139: batch_071_1756478020.jsonl
# 📤 Uploading batch_071_1756478020.jsonl...
# ❌ Error with batch batch_071_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_071_1756478020.jsonl'
#
# 🚀 Submitting batch 73/139: batch_072_1756478020.jsonl
# 📤 Uploading batch_072_1756478020.jsonl...
# ❌ Error with batch batch_072_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_072_1756478020.jsonl'
#
# 🚀 Submitting batch 74/139: batch_073_1756478020.jsonl
# 📤 Uploading batch_073_1756478020.jsonl...
# ❌ Error with batch batch_073_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_073_1756478020.jsonl'
#
# 🚀 Submitting batch 75/139: batch_074_1756478020.jsonl
# 📤 Uploading batch_074_1756478020.jsonl...
# ❌ Error with batch batch_074_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_074_1756478020.jsonl'
#
# 🚀 Submitting batch 76/139: batch_075_1756478020.jsonl
# 📤 Uploading batch_075_1756478020.jsonl...
# ❌ Error with batch batch_075_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_075_1756478020.jsonl'
#
# 🚀 Submitting batch 77/139: batch_076_1756478020.jsonl
# 📤 Uploading batch_076_1756478020.jsonl...
# ❌ Error with batch batch_076_1756478020.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_076_1756478020.jsonl'
#
# 🚀 Submitting batch 78/139: batch_077_1756478021.jsonl
# 📤 Uploading batch_077_1756478021.jsonl...
# ❌ Error with batch batch_077_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_077_1756478021.jsonl'
#
# 🚀 Submitting batch 79/139: batch_078_1756478021.jsonl
# 📤 Uploading batch_078_1756478021.jsonl...
# ❌ Error with batch batch_078_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_078_1756478021.jsonl'
#
# 🚀 Submitting batch 80/139: batch_079_1756478021.jsonl
# 📤 Uploading batch_079_1756478021.jsonl...
# ❌ Error with batch batch_079_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_079_1756478021.jsonl'
#
# 🚀 Submitting batch 81/139: batch_080_1756478021.jsonl
# 📤 Uploading batch_080_1756478021.jsonl...
# ❌ Error with batch batch_080_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_080_1756478021.jsonl'
#
# 🚀 Submitting batch 82/139: batch_081_1756478021.jsonl
# 📤 Uploading batch_081_1756478021.jsonl...
# ❌ Error with batch batch_081_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_081_1756478021.jsonl'
#
# 🚀 Submitting batch 83/139: batch_082_1756478021.jsonl
# 📤 Uploading batch_082_1756478021.jsonl...
# ❌ Error with batch batch_082_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_082_1756478021.jsonl'
#
# 🚀 Submitting batch 84/139: batch_083_1756478021.jsonl
# 📤 Uploading batch_083_1756478021.jsonl...
# ❌ Error with batch batch_083_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_083_1756478021.jsonl'
#
# 🚀 Submitting batch 85/139: batch_084_1756478021.jsonl
# 📤 Uploading batch_084_1756478021.jsonl...
# ❌ Error with batch batch_084_1756478021.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_084_1756478021.jsonl'
#
# 🚀 Submitting batch 86/139: batch_085_1756478022.jsonl
# 📤 Uploading batch_085_1756478022.jsonl...
# ❌ Error with batch batch_085_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_085_1756478022.jsonl'
#
# 🚀 Submitting batch 87/139: batch_086_1756478022.jsonl
# 📤 Uploading batch_086_1756478022.jsonl...
# ❌ Error with batch batch_086_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_086_1756478022.jsonl'
#
# 🚀 Submitting batch 88/139: batch_087_1756478022.jsonl
# 📤 Uploading batch_087_1756478022.jsonl...
# ❌ Error with batch batch_087_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_087_1756478022.jsonl'
#
# 🚀 Submitting batch 89/139: batch_088_1756478022.jsonl
# 📤 Uploading batch_088_1756478022.jsonl...
# ❌ Error with batch batch_088_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_088_1756478022.jsonl'
#
# 🚀 Submitting batch 90/139: batch_089_1756478022.jsonl
# 📤 Uploading batch_089_1756478022.jsonl...
# ❌ Error with batch batch_089_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_089_1756478022.jsonl'
#
# 🚀 Submitting batch 91/139: batch_090_1756478022.jsonl
# 📤 Uploading batch_090_1756478022.jsonl...
# ❌ Error with batch batch_090_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_090_1756478022.jsonl'
#
# 🚀 Submitting batch 92/139: batch_091_1756478022.jsonl
# 📤 Uploading batch_091_1756478022.jsonl...
# ❌ Error with batch batch_091_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_091_1756478022.jsonl'
#
# 🚀 Submitting batch 93/139: batch_092_1756478022.jsonl
# 📤 Uploading batch_092_1756478022.jsonl...
# ❌ Error with batch batch_092_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_092_1756478022.jsonl'
#
# 🚀 Submitting batch 94/139: batch_093_1756478022.jsonl
# 📤 Uploading batch_093_1756478022.jsonl...
# ❌ Error with batch batch_093_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_093_1756478022.jsonl'
#
# 🚀 Submitting batch 95/139: batch_094_1756478022.jsonl
# 📤 Uploading batch_094_1756478022.jsonl...
# ❌ Error with batch batch_094_1756478022.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_094_1756478022.jsonl'
#
# 🚀 Submitting batch 96/139: batch_095_1756478023.jsonl
# 📤 Uploading batch_095_1756478023.jsonl...
# ❌ Error with batch batch_095_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_095_1756478023.jsonl'
#
# 🚀 Submitting batch 97/139: batch_096_1756478023.jsonl
# 📤 Uploading batch_096_1756478023.jsonl...
# ❌ Error with batch batch_096_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_096_1756478023.jsonl'
#
# 🚀 Submitting batch 98/139: batch_097_1756478023.jsonl
# 📤 Uploading batch_097_1756478023.jsonl...
# ❌ Error with batch batch_097_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_097_1756478023.jsonl'
#
# 🚀 Submitting batch 99/139: batch_098_1756478023.jsonl
# 📤 Uploading batch_098_1756478023.jsonl...
# ❌ Error with batch batch_098_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_098_1756478023.jsonl'
#
# 🚀 Submitting batch 100/139: batch_099_1756478023.jsonl
# 📤 Uploading batch_099_1756478023.jsonl...
# ❌ Error with batch batch_099_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_099_1756478023.jsonl'
#
# 🚀 Submitting batch 101/139: batch_100_1756478023.jsonl
# 📤 Uploading batch_100_1756478023.jsonl...
# ❌ Error with batch batch_100_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_100_1756478023.jsonl'
#
# 🚀 Submitting batch 102/139: batch_101_1756478023.jsonl
# 📤 Uploading batch_101_1756478023.jsonl...
# ❌ Error with batch batch_101_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_101_1756478023.jsonl'
#
# 🚀 Submitting batch 103/139: batch_102_1756478023.jsonl
# 📤 Uploading batch_102_1756478023.jsonl...
# ❌ Error with batch batch_102_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_102_1756478023.jsonl'
#
# 🚀 Submitting batch 104/139: batch_103_1756478023.jsonl
# 📤 Uploading batch_103_1756478023.jsonl...
# ❌ Error with batch batch_103_1756478023.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_103_1756478023.jsonl'
#
# 🚀 Submitting batch 105/139: batch_104_1756478024.jsonl
# 📤 Uploading batch_104_1756478024.jsonl...
# ❌ Error with batch batch_104_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_104_1756478024.jsonl'
#
# 🚀 Submitting batch 106/139: batch_105_1756478024.jsonl
# 📤 Uploading batch_105_1756478024.jsonl...
# ❌ Error with batch batch_105_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_105_1756478024.jsonl'
#
# 🚀 Submitting batch 107/139: batch_106_1756478024.jsonl
# 📤 Uploading batch_106_1756478024.jsonl...
# ❌ Error with batch batch_106_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_106_1756478024.jsonl'
#
# 🚀 Submitting batch 108/139: batch_107_1756478024.jsonl
# 📤 Uploading batch_107_1756478024.jsonl...
# ❌ Error with batch batch_107_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_107_1756478024.jsonl'
#
# 🚀 Submitting batch 109/139: batch_108_1756478024.jsonl
# 📤 Uploading batch_108_1756478024.jsonl...
# ❌ Error with batch batch_108_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_108_1756478024.jsonl'
#
# 🚀 Submitting batch 110/139: batch_109_1756478024.jsonl
# 📤 Uploading batch_109_1756478024.jsonl...
# ❌ Error with batch batch_109_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_109_1756478024.jsonl'
#
# 🚀 Submitting batch 111/139: batch_110_1756478024.jsonl
# 📤 Uploading batch_110_1756478024.jsonl...
# ❌ Error with batch batch_110_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_110_1756478024.jsonl'
#
# 🚀 Submitting batch 112/139: batch_111_1756478024.jsonl
# 📤 Uploading batch_111_1756478024.jsonl...
# ❌ Error with batch batch_111_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_111_1756478024.jsonl'
#
# 🚀 Submitting batch 113/139: batch_112_1756478024.jsonl
# 📤 Uploading batch_112_1756478024.jsonl...
# ❌ Error with batch batch_112_1756478024.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_112_1756478024.jsonl'
#
# 🚀 Submitting batch 114/139: batch_113_1756478025.jsonl
# 📤 Uploading batch_113_1756478025.jsonl...
# ❌ Error with batch batch_113_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_113_1756478025.jsonl'
#
# 🚀 Submitting batch 115/139: batch_114_1756478025.jsonl
# 📤 Uploading batch_114_1756478025.jsonl...
# ❌ Error with batch batch_114_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_114_1756478025.jsonl'
#
# 🚀 Submitting batch 116/139: batch_115_1756478025.jsonl
# 📤 Uploading batch_115_1756478025.jsonl...
# ❌ Error with batch batch_115_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_115_1756478025.jsonl'
#
# 🚀 Submitting batch 117/139: batch_116_1756478025.jsonl
# 📤 Uploading batch_116_1756478025.jsonl...
# ❌ Error with batch batch_116_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_116_1756478025.jsonl'
#
# 🚀 Submitting batch 118/139: batch_117_1756478025.jsonl
# 📤 Uploading batch_117_1756478025.jsonl...
# ❌ Error with batch batch_117_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_117_1756478025.jsonl'
#
# 🚀 Submitting batch 119/139: batch_118_1756478025.jsonl
# 📤 Uploading batch_118_1756478025.jsonl...
# ❌ Error with batch batch_118_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_118_1756478025.jsonl'
#
# 🚀 Submitting batch 120/139: batch_119_1756478025.jsonl
# 📤 Uploading batch_119_1756478025.jsonl...
# ❌ Error with batch batch_119_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_119_1756478025.jsonl'
#
# 🚀 Submitting batch 121/139: batch_120_1756478025.jsonl
# 📤 Uploading batch_120_1756478025.jsonl...
# ❌ Error with batch batch_120_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_120_1756478025.jsonl'
#
# 🚀 Submitting batch 122/139: batch_121_1756478025.jsonl
# 📤 Uploading batch_121_1756478025.jsonl...
# ❌ Error with batch batch_121_1756478025.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_121_1756478025.jsonl'
#
# 🚀 Submitting batch 123/139: batch_122_1756478026.jsonl
# 📤 Uploading batch_122_1756478026.jsonl...
# ❌ Error with batch batch_122_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_122_1756478026.jsonl'
#
# 🚀 Submitting batch 124/139: batch_123_1756478026.jsonl
# 📤 Uploading batch_123_1756478026.jsonl...
# ❌ Error with batch batch_123_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_123_1756478026.jsonl'
#
# 🚀 Submitting batch 125/139: batch_124_1756478026.jsonl
# 📤 Uploading batch_124_1756478026.jsonl...
# ❌ Error with batch batch_124_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_124_1756478026.jsonl'
#
# 🚀 Submitting batch 126/139: batch_125_1756478026.jsonl
# 📤 Uploading batch_125_1756478026.jsonl...
# ❌ Error with batch batch_125_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_125_1756478026.jsonl'
#
# 🚀 Submitting batch 127/139: batch_126_1756478026.jsonl
# 📤 Uploading batch_126_1756478026.jsonl...
# ❌ Error with batch batch_126_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_126_1756478026.jsonl'
#
# 🚀 Submitting batch 128/139: batch_127_1756478026.jsonl
# 📤 Uploading batch_127_1756478026.jsonl...
# ❌ Error with batch batch_127_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_127_1756478026.jsonl'
#
# 🚀 Submitting batch 129/139: batch_128_1756478026.jsonl
# 📤 Uploading batch_128_1756478026.jsonl...
# ❌ Error with batch batch_128_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_128_1756478026.jsonl'
#
# 🚀 Submitting batch 130/139: batch_129_1756478026.jsonl
# 📤 Uploading batch_129_1756478026.jsonl...
# ❌ Error with batch batch_129_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_129_1756478026.jsonl'
#
# 🚀 Submitting batch 131/139: batch_130_1756478026.jsonl
# 📤 Uploading batch_130_1756478026.jsonl...
# ❌ Error with batch batch_130_1756478026.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_130_1756478026.jsonl'
#
# 🚀 Submitting batch 132/139: batch_131_1756478027.jsonl
# 📤 Uploading batch_131_1756478027.jsonl...
# ❌ Error with batch batch_131_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_131_1756478027.jsonl'
#
# 🚀 Submitting batch 133/139: batch_132_1756478027.jsonl
# 📤 Uploading batch_132_1756478027.jsonl...
# ❌ Error with batch batch_132_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_132_1756478027.jsonl'
#
# 🚀 Submitting batch 134/139: batch_133_1756478027.jsonl
# 📤 Uploading batch_133_1756478027.jsonl...
# ❌ Error with batch batch_133_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_133_1756478027.jsonl'
#
# 🚀 Submitting batch 135/139: batch_134_1756478027.jsonl
# 📤 Uploading batch_134_1756478027.jsonl...
# ❌ Error with batch batch_134_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_134_1756478027.jsonl'
#
# 🚀 Submitting batch 136/139: batch_135_1756478027.jsonl
# 📤 Uploading batch_135_1756478027.jsonl...
# ❌ Error with batch batch_135_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_135_1756478027.jsonl'
#
# 🚀 Submitting batch 137/139: batch_136_1756478027.jsonl
# 📤 Uploading batch_136_1756478027.jsonl...
# ❌ Error with batch batch_136_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_136_1756478027.jsonl'
#
# 🚀 Submitting batch 138/139: batch_137_1756478027.jsonl
# 📤 Uploading batch_137_1756478027.jsonl...
# ❌ Error with batch batch_137_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_137_1756478027.jsonl'
#
# 🚀 Submitting batch 139/139: batch_138_1756478027.jsonl
# 📤 Uploading batch_138_1756478027.jsonl...
# ❌ Error with batch batch_138_1756478027.jsonl: [Errno 2] No such file or directory: 'batch_runs\\batch_138_1756478027.jsonl'
# ✅ All 1 batches completed!
# 📥 Downloading results for batch batch_68b1ba53a8e881909d4cdafd61b5ae21...
# {"id": "batch_req_68b1bf8fa55481909f8779850cfc60ad", "custom_id": "review_0", "response": {"status_code": 200, "request_id": "026a20f59c773fcf529cb3a1fddeaecc", "body": {"id": "chatcmpl-C9uUdFWUrF5xsBgeARfRO4dWtZ23B", "object": "chat.completion", "created": 1756478147, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.9, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.9, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.9}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 401, "completion_tokens": 646, "total_tokens": 1047, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 576, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1bf8f9f0081908abbd97a9cb8dfaa", "custom_id": "review_1", "response": {"status_code": 200, "request_id": "7d8d4f407b7d37356c6200160eb4510f", "body": {"id": "chatcmpl-C9uY31fIJY9LxXxsta9HQqrkIiE4k", "object": "chat.completion", "created": 1756478359, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.15, \"irrelevant\": true, \"irrelevant_confidence_score\": 0.78, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.14}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 400, "completion_tokens": 774, "total_tokens": 1174, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 704, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1bf8fd610819089031d769fcaf386", "custom_id": "review_2", "response": {"status_code": 200, "request_id": "63b2b6099d61b95b151ae2fde950caa8", "body": {"id": "chatcmpl-C9uX4mOUGtRrToD48R2WjZPUcfau2", "object": "chat.completion", "created": 1756478298, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.25, \"irrelevant\": true, \"irrelevant_confidence_score\": 0.75, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.25}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 398, "completion_tokens": 710, "total_tokens": 1108, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 640, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1bf8fcc748190945ccb068293f199", "custom_id": "review_6", "response": {"status_code": 200, "request_id": "f603969c2ea406bad11e2ceadc1e43e0", "body": {"id": "chatcmpl-C9uXAu5Jgz220fR3hbss9qNrJWZmx", "object": "chat.completion", "created": 1756478304, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": true, \"advertisement_confidence_score\": 0.85, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.15, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.05}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 434, "completion_tokens": 838, "total_tokens": 1272, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 768, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1bf8fb12081908128dd32252c1027", "custom_id": "review_7", "response": {"status_code": 200, "request_id": "81b39f49eaf1a1ef306f05d58628d59a", "body": {"id": "chatcmpl-C9uUd1gHFLlBfGilQnWPf7oXMNZab", "object": "chat.completion", "created": 1756478147, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\n  \"advertisement\": false,\n  \"advertisement_confidence_score\": 0.92,\n  \"irrelevant\": false,\n  \"irrelevant_confidence_score\": 0.84,\n  \"fake_rant\": false,\n  \"fake_rant_confidence_score\": 0.78\n}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 446, "completion_tokens": 1102, "total_tokens": 1548, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 1024, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# ...
# {"id": "batch_req_68b1c09a59588190adb6b346b9c44cbb", "custom_id": "review_4608", "response": {"status_code": 200, "request_id": "c59d0b462e59df7ba4a923c8db03c680", "body": {"id": "chatcmpl-C9uZxlBe5rbVbQzhzesv20JGBmiOC", "object": "chat.completion", "created": 1756478477, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.22, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.18, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.15}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 406, "completion_tokens": 582, "total_tokens": 988, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 512, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09a6138819096b4e7acb2177fc8", "custom_id": "review_4613", "response": {"status_code": 200, "request_id": "944e9323fc8e52b58837a7561eca6b3f", "body": {"id": "chatcmpl-C9uZN4EZfqApygcQwdRotqRX3lbpW", "object": "chat.completion", "created": 1756478441, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.15, \"irrelevant\": true, \"irrelevant_confidence_score\": 0.8, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.1}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 397, "completion_tokens": 966, "total_tokens": 1363, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 896, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09ab18081909ade97eaf8f4e3e4", "custom_id": "review_4614", "response": {"status_code": 200, "request_id": "75889b0f58717243fbf9ef49de27912e", "body": {"id": "chatcmpl-C9uYSXPMivU7vBEliuoJiSv7aRQ5V", "object": "chat.completion", "created": 1756478384, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\":false,\"advertisement_confidence_score\":0.75,\"irrelevant\":false,\"irrelevant_confidence_score\":0.85,\"fake_rant\":false,\"fake_rant_confidence_score\":0.8}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 407, "completion_tokens": 1151, "total_tokens": 1558, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 1088, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09ac1d48190b85521d6eef6298e", "custom_id": "review_4615", "response": {"status_code": 200, "request_id": "74dfa36c22303c2a9cb9648f0191f10b", "body": {"id": "chatcmpl-C9ua3EHQ1Fg32FXwQsMIEWVWLbUSQ", "object": "chat.completion", "created": 1756478483, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.3, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.3, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.3}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 395, "completion_tokens": 646, "total_tokens": 1041, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 576, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09acb788190a17f45df62bb9719", "custom_id": "review_4616", "response": {"status_code": 200, "request_id": "fa082ed46b6f76d221977c0a70b52954", "body": {"id": "chatcmpl-C9uZUdbZOrnFznjloSYi1tgiR2bas", "object": "chat.completion", "created": 1756478448, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\n  \"advertisement\": false,\n  \"advertisement_confidence_score\": 0.2,\n  \"irrelevant\": false,\n  \"irrelevant_confidence_score\": 0.2,\n  \"fake_rant\": false,\n  \"fake_rant_confidence_score\": 0.2\n}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 404, "completion_tokens": 398, "total_tokens": 802, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 320, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09ae16c8190a572750c96a31639", "custom_id": "review_4617", "response": {"status_code": 200, "request_id": "68b16ef419d416db117de06e322ebeec", "body": {"id": "chatcmpl-C9uYbDtQ4f0lib82R3PQIU2phNTaV", "object": "chat.completion", "created": 1756478393, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.25, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.25, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.25}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 404, "completion_tokens": 582, "total_tokens": 986, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 512, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09afaf0819085bf46e7b1183740", "custom_id": "review_4618", "response": {"status_code": 200, "request_id": "ef6e3056bf5729f30c7f74b09f8dbfc5", "body": {"id": "chatcmpl-C9uZZrcxHm3ZKWZ2epSDrQoo6qpYk", "object": "chat.completion", "created": 1756478453, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\":false,\"advertisement_confidence_score\":0.25,\"irrelevant\":false,\"irrelevant_confidence_score\":0.25,\"fake_rant\":false,\"fake_rant_confidence_score\":0.20}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 411, "completion_tokens": 702, "total_tokens": 1113, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 640, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09b0b708190ac229e5b6f9d7cc0", "custom_id": "review_4619", "response": {"status_code": 200, "request_id": "116bb8cb08cc316ec51b0312935dfbbf", "body": {"id": "chatcmpl-C9ua9ysSRJgtXGd0kh5qgiT50AySU", "object": "chat.completion", "created": 1756478489, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.2, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.2, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.2}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 397, "completion_tokens": 390, "total_tokens": 787, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 320, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09b65a481909459fafc319b110b", "custom_id": "review_4620", "response": {"status_code": 200, "request_id": "366fe32b5ad0bec644f5ac4807ec30c9", "body": {"id": "chatcmpl-C9uYgIEyALxAbzrgiTk9a26OZVfg6", "object": "chat.completion", "created": 1756478398, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.8, \"irrelevant\": false, \"irrelevant_confidence_score\": 0.8, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.8}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 396, "completion_tokens": 1478, "total_tokens": 1874, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 1408, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
# {"id": "batch_req_68b1c09b4ee481908fd6e9d621ca60c6", "custom_id": "review_4621", "response": {"status_code": 200, "request_id": "169e5d3b55aad0edf1e186dfa561069e", "body": {"id": "chatcmpl-C9uaErwSMmXE0xJrKU04LzLEtN7yi", "object": "chat.completion", "created": 1756478494, "model": "gpt-5-nano-2025-08-07", "choices": [{"index": 0, "message": {"role": "assistant", "content": "{\"advertisement\": false, \"advertisement_confidence_score\": 0.25, \"irrelevant\": true, \"irrelevant_confidence_score\": 0.35, \"fake_rant\": false, \"fake_rant_confidence_score\": 0.15}", "refusal": null, "annotations": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 396, "completion_tokens": 966, "total_tokens": 1362, "prompt_tokens_details": {"cached_tokens": 0, "audio_tokens": 0}, "completion_tokens_details": {"reasoning_tokens": 896, "audio_tokens": 0, "accepted_prediction_tokens": 0, "rejected_prediction_tokens": 0}}, "service_tier": "default", "system_fingerprint": null}}, "error": null}
#
# ✅ Parsed 2500 results from batch_68b1ba53a8e881909d4cdafd61b5ae21
# 🎉 Complete! Results saved to: classified_reviews_gpt-5-nano_1756479652.csv
# 📊 Processed: 347082 rows
# ✅ Success rate: 0.7%
#
# 📋 Classification Summary:
# Total reviews: 347082
# Advertisements: 217
# Irrelevant: 72
# Fake rants: 3
#
# 🔍 Sample Results:
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+
# |    | text                                                                                                                                                                                                                   | advertisement   |   advertisement_confidence_score | irrelevant   |   irrelevant_confidence_score | fake_rant   |   fake_rant_confidence_score |
# |----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------|
# |  0 | Great place to care for our children.                                                                                                                                                                                  | False           |                             0.9  | False        |                          0.9  | False       |                         0.9  |
# |  1 | Th sw y are so nice                                                                                                                                                                                                    | False           |                             0.15 | True         |                          0.78 | False       |                         0.14 |
# |  2 | Went with my daughter                                                                                                                                                                                                  | False           |                             0.25 | True         |                          0.75 | False       |                         0.25 |
# |  6 | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                         | True            |                             0.85 | False        |                          0.15 | False       |                         0.05 |
# |  7 | They dont have any activities for youth. If so, they don't promote it well.  No sporting events or camps, no family or community outreach, no kids seen playing in gym or play ground.  Where are the youth projects?? | False           |                             0.92 | False        |                          0.84 | False       |                         0.78 |
# |  8 | So much done for the youth and community here!                                                                                                                                                                         | False           |                             0.15 | False        |                          0.15 | False       |                         0.1  |
# |  9 | Amazing work done here!                                                                                                                                                                                                | False           |                             0.85 | False        |                          0.9  | False       |                         0.9  |
# | 10 | Great place for the children.                                                                                                                                                                                          | False           |                             0.92 | False        |                          0.92 | False       |                         0.92 |
# | 11 | Doing wonderful work.                                                                                                                                                                                                  | False           |                             0.9  | False        |                          0.9  | False       |                         0.9  |
# | 12 | Helpful, and good service.                                                                                                                                                                                             | False           |                             0.3  | False        |                          0.3  | False       |                         0.3  |
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+

# %% [markdown]
# ## EDA of flagged reviews
#
# #### Advertisements

# %%
print("\n🔍 Advertisements:")

cols = [
    "name_y",
    "category",
    "text",
    "advertisement",
    "advertisement_confidence_score",
    "irrelevant",
    "irrelevant_confidence_score",
    "fake_rant",
    "fake_rant_confidence_score",
]
advertisement_df = final_results[final_results["advertisement"] == True]
print(tabulate(advertisement_df[cols].head(50), headers="keys", tablefmt="psql"))
# Out:
# 🔍 Advertisements:
# +------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+
# |      | name_y                                          | category                                                                                                                                                                                                         | text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | advertisement   |   advertisement_confidence_score | irrelevant   |   irrelevant_confidence_score | fake_rant   |   fake_rant_confidence_score |
# |------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------|
# |    6 | Cheyenne River Youth Project                    | ['Youth social services organization']                                                                                                                                                                           | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                                                                                                                                                                                                                                                                                               | True            |                             0.85 | False        |                          0.15 | False       |                         0.05 |
# |  104 | Hubbard Feeds                                   | ['Animal feed store']                                                                                                                                                                                            | Best price for chicken feed                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.78 | False        |                          0.22 | False       |                         0.24 |
# |  170 | Sparkle Uniforms                                | ['Uniform store']                                                                                                                                                                                                | You can't get better customer service than this small business.  Not only do they have a large selection, but if they don't have what you need they order it QUICKLY.  Also, if you need more scrubs and you like the ones you just bought, save yourself a trip and call them.  They have it on file.  Thank you, Angie!!!                                                                                                                                                                  | True            |                             0.82 | False        |                          0.25 | False       |                         0.3  |
# |  171 | Sparkle Uniforms                                | ['Uniform store']                                                                                                                                                                                                | Incredibly friendly and fantastic location to find your medical professional attire!  Lots of variety and many brands!  They provide a wonderful personal service to make sure you have the right style and fit!!                                                                                                                                                                                                                                                                            | True            |                             0.85 | False        |                          0.95 | False       |                         0.95 |
# |  211 | Discount Joe's                                  | ['Motorcycle dealer']                                                                                                                                                                                            | Super fast, friendly, and knowledgeable service! I was treated very, very well, and what I thought was going to easily be a $50.00+ repair was less than $30.00! I will definitely be back, and highly recommend them!                                                                                                                                                                                                                                                                       | True            |                             0.9  | False        |                          0.2  | False       |                         0.1  |
# |  268 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | I'm kind of biased on this one as I work there. We offer full-service truck shop as well as a truck wash. We have fair pricing and are open six days a week.                                                                                                                                                                                                                                                                                                                                 | True            |                             0.85 | False        |                          0.25 | False       |                         0.15 |
# |  269 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | Great place to get work done on your tractor or trailer washouts full meal deal great place                                                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.62 | False        |                          0.32 | False       |                         0.2  |
# |  270 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | They have the best drivers in town. Can handle all you bulk hauling needs.                                                                                                                                                                                                                                                                                                                                                                                                                   | True            |                             0.75 | False        |                          0.2  | False       |                         0.2  |
# |  280 | Nutrishop Rapid City                            | ['Vitamin & supplements store', 'Sports nutrition store', 'Weight loss service']                                                                                                                                 | Great atmosphere, Gunnar and the staff are knowledgeable, very approachable. You feel like your talking to your gym buddy not a salesman. There is a wide range of supplements for healthy living or the avid bodybuilder. I have bought snacks, drinks, protein, pre workout you name it is available. Plenty of motivational challenges and competition to keep you motivated. Great place to get your supplements, motivation, or friendly knowledgeable tips for diet and fitness goals. | True            |                             0.74 | False        |                          0.23 | False       |                         0.1  |
# |  281 | Nutrishop Rapid City                            | ['Vitamin & supplements store', 'Sports nutrition store', 'Weight loss service']                                                                                                                                 | Nutrishop is the best supplement shop in town. If you want products that work and an affordable price this is the place for you.                                                                                                                                                                                                                                                                                                                                                             | True            |                             0.92 | False        |                          0.12 | False       |                         0.12 |
# |  296 | Cheyenne River Youth Project                    | ['Youth social services organization']                                                                                                                                                                           | Julie and the crew are AMAZING. DONATE DONATE DONATE. this is one of the MOST worthy non-profits you can find. WOPILA TANKA!!!                                                                                                                                                                                                                                                                                                                                                               | True            |                             0.92 | False        |                          0.08 | False       |                         0.04 |
# |  373 | Simply Charming                                 | ['Coffee shop', 'Gift shop']                                                                                                                                                                                     | I purchased smoothies for the ladies in the office as a surprise. The gals at Simply Charming knew what the ladies liked. As a result I had some very happy secretaries!                                                                                                                                                                                                                                                                                                                     | True            |                             0.75 | False        |                          0.2  | False       |                         0.15 |
# |  394 | Hubbard Feeds                                   | ['Animal feed store']                                                                                                                                                                                            | Best price for chicken feed                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.8  | False        |                          0.9  | False       |                         0.65 |
# |  460 | Sparkle Uniforms                                | ['Uniform store']                                                                                                                                                                                                | You can't get better customer service than this small business.  Not only do they have a large selection, but if they don't have what you need they order it QUICKLY.  Also, if you need more scrubs and you like the ones you just bought, save yourself a trip and call them.  They have it on file.  Thank you, Angie!!!                                                                                                                                                                  | True            |                             0.82 | False        |                          0.18 | False       |                         0.12 |
# |  529 | CosmoProf                                       | ['Beauty supply store']                                                                                                                                                                                          | Amazing prices and sales on hair and nails stuff, and amazing service. All the girls there are really nice and friendly. 😁                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.82 | False        |                          0.78 | False       |                         0.25 |
# |  549 | B J's Food Center                               | ['Grocery store']                                                                                                                                                                                                | This is a small town grocery store, but it has most everything you could want. Lots of great produce, fresh cut meat, hundreds of freezer items, and also sells a variety of beer. The has live bait and a friendly staff!                                                                                                                                                                                                                                                                   | True            |                             0.78 | False        |                          0.92 | False       |                         0.57 |
# |  558 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | I'm kind of biased on this one as I work there. We offer full-service truck shop as well as a truck wash. We have fair pricing and are open six days a week.                                                                                                                                                                                                                                                                                                                                 | True            |                             0.93 | False        |                          0.15 | False       |                         0.2  |
# |  560 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | They have the best drivers in town. Can handle all you bulk hauling needs.                                                                                                                                                                                                                                                                                                                                                                                                                   | True            |                             0.92 | False        |                          0.82 | False       |                         0.88 |
# |  571 | Nutrishop Rapid City                            | ['Vitamin & supplements store', 'Sports nutrition store', 'Weight loss service']                                                                                                                                 | Nutrishop is the best supplement shop in town. If you want products that work and an affordable price this is the place for you.                                                                                                                                                                                                                                                                                                                                                             | True            |                             0.92 | False        |                          0.08 | False       |                         0.04 |
# |  583 | Dave Hahler Automotive Inc                      | ['Car dealer', 'Auto body shop', 'Auto glass shop', 'Auto parts store', 'Auto repair shop', 'Chevrolet dealer']                                                                                                  | If you're looking into getting into a different vehicle i would highly recommend hahlers as the place to shop. They have provided me and my family with nothing but good honest service on multiple vehicle purchases.                                                                                                                                                                                                                                                                       | True            |                             0.82 | False        |                          0.28 | False       |                         0.28 |
# |  604 | Highland Conference Center                      | ['Conference center', 'Banquet hall']                                                                                                                                                                            | Highland Conference Center in Mitchell, South Dakota IS very, " High Class."                                                                                                                                                                                                                                                                                                                                                                                                                 | True            |                             0.9  | False        |                          0.9  | False       |                         0.2  |
# |      |                                                 |                                                                                                                                                                                                                  | Call to reserve a Conference Room for any Occasion.                                                                                                                                                                                                                                                                                                                                                                                                                                          |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | Pirogues Catering serves the food at the Highland Conference Center in Mitchell, South Dakota. 😍 💖                                                                                                                                                                                                                                                                                                                                                                                         |                 |                                  |              |                               |             |                              |
# |  650 | Total Beauty                                    | ['Clothing store']                                                                                                                                                                                               | Awesome shop! Super nice people!! Stop in and check this place out!!                                                                                                                                                                                                                                                                                                                                                                                                                         | True            |                             0.92 | False        |                          0.15 | False       |                         0.1  |
# |  670 | NAPA Auto Parts - Auto Parts Of Philip          | ['Auto parts store', 'Trailer supply store', 'Truck accessories store']                                                                                                                                          | Whatcha need? They have it!                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.65 | False        |                          0.25 | False       |                         0.25 |
# |  767 | Quality Transmissions Inc                       | ['Car repair and maintenance']                                                                                                                                                                                   | Willie is the best there is. If anyone is looking for an honest mechanic with a smile ask for Willie!                                                                                                                                                                                                                                                                                                                                                                                        | True            |                             0.92 | False        |                          0.15 | False       |                         0.05 |
# |  769 | Quality Transmissions Inc                       | ['Car repair and maintenance']                                                                                                                                                                                   | Wouldn't go anywhere else in Rapid City.                                                                                                                                                                                                                                                                                                                                                                                                                                                     | True            |                             0.8  | False        |                          0.3  | False       |                         0.3  |
# |  771 | Quality Transmissions Inc                       | ['Car repair and maintenance']                                                                                                                                                                                   | Wouldn't go anywhere else in Rapid City.                                                                                                                                                                                                                                                                                                                                                                                                                                                     | True            |                             0.65 | False        |                          0.25 | False       |                         0.25 |
# |  780 | The Church of Jesus Christ of Latter-day Saints | ['Church of Jesus Christ of Latter-day Saints', 'Christian church', 'Church', 'Church of Christ', 'Genealogist', 'Mission', 'Non-profit organization', 'Place of worship', 'Religious organization', 'Seminary'] | I know this is a church and for some it brings up a lot of emotions, positive and negative. You just have to come and see for yourself. Please join us!                                                                                                                                                                                                                                                                                                                                      | True            |                             0.85 | False        |                          0.2  | False       |                         0.2  |
# |  791 | Overclock Lounge                                | ['Lounge']                                                                                                                                                                                                       | This place is something wonderful and new for Rapid City. They serve beer and wine and even coffee. The service is always friendly and once youve been a few times, they remember your name. Everything is fairly priced and they have a room for people to bring board games and tabletop games to. This was the big draw for my gaming group as we all don't have big enough houses to play a 7 person game weekly. Dan has been our bartender the past few weeks and he is very friendly. | True            |                             0.65 | False        |                          0.75 | False       |                         0.25 |
# |  813 | Simply Sleep Better                             | ['Mattress store']                                                                                                                                                                                               | It was a wonderful experience! Mark was very attentive and a wonderful salesman! We really felt comfortable and secure with his expertise and knowledge! I highly recommend going to see him if you are in need of a mattress!                                                                                                                                                                                                                                                               | True            |                             0.85 | False        |                          0.25 | False       |                         0.2  |
# |  814 | Simply Sleep Better                             | ['Mattress store']                                                                                                                                                                                               | I had a great experience working with Mark when purchasing my Sealy mattress.  He was up front about the supply chain challenges during the pandemic, but still worked diligently to make sure the mattress would be on the next truck.  I highly recommend Simply Sleep Better!                                                                                                                                                                                                             | True            |                             0.93 | False        |                          0.07 | False       |                         0.04 |
# |  816 | Simply Sleep Better                             | ['Mattress store']                                                                                                                                                                                               | Mark was so helpful. I am so excited with my new tempurpedic bed. I highly recommend going to check out all the great beds.                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.78 | False        |                          0.22 | False       |                         0.15 |
# |  818 | Simply Sleep Better                             | ['Mattress store']                                                                                                                                                                                               | We had not shopped for a new mattress in a long time and thanks to Bob we had a great experience. He was very polite and patient with us as we had a lot of questions. If you are looking for a new mattress or bed I recommend you see Bob at Simply Sleep Better on MT Rushmore Road.                                                                                                                                                                                                      | True            |                             0.92 | False        |                          0.78 | False       |                         0.72 |
# |  846 | Jackrabbit Tire & Services                      | ['Tire shop']                                                                                                                                                                                                    | Hard-working, honest guys.  They don't try to scam you, and they genuinely want you to get the best deal.  Best car repair in Brookings.                                                                                                                                                                                                                                                                                                                                                     | True            |                             0.85 | False        |                          0.2  | False       |                         0.15 |
# |  867 | Rapid City Landfill                             | ['Garbage dump']                                                                                                                                                                                                 | A great place to throw away trash.                                                                                                                                                                                                                                                                                                                                                                                                                                                           | True            |                             0.85 | False        |                          0.25 | False       |                         0.15 |
# |  870 | Rapid City Landfill                             | ['Garbage dump']                                                                                                                                                                                                 | Free yard waste dump and reasonable priced composted yard waste, it doesn't make it worthwhile to compost your own, unless you want some high test stuff!                                                                                                                                                                                                                                                                                                                                    | True            |                             0.78 | False        |                          0.22 | False       |                         0.15 |
# |  874 | Rapid City Landfill                             | ['Garbage dump']                                                                                                                                                                                                 | One free pickup load with your city water/sewer/garbage bill per calender year.                                                                                                                                                                                                                                                                                                                                                                                                              | True            |                             0.92 | False        |                          0.85 | False       |                         0.1  |
# |  878 | Rapid City Landfill                             | ['Garbage dump']                                                                                                                                                                                                 | One free pickup load with your city water/sewer/garbage bill per calender year.                                                                                                                                                                                                                                                                                                                                                                                                              | True            |                             0.92 | False        |                          0.08 | False       |                         0.05 |
# |  925 | Box Elder Vet Clinic                            | ['Veterinarian']                                                                                                                                                                                                 | The clinic is very clean everyone soo nice the Dr helped my baby she is doing much better and the cost was better then most clinic's in RC would go back and I would send my friends and family to him also                                                                                                                                                                                                                                                                                  | True            |                             0.92 | False        |                          0.12 | False       |                         0.14 |
# |  979 | Savvy Storage                                   | ['Self-storage facility']                                                                                                                                                                                        | Great place to store your stuff. Never had a problem with the management. Never had to worry about security. Never had to worry about anything. Military gets a great discount on the units, and they'll even give you a lot of leeway on the move in/move out time frame/prorated bill. Would store my stuff here again!                                                                                                                                                                    | True            |                             0.92 | False        |                          0.12 | False       |                         0.16 |
# | 1046 | Wyshbone Market                                 | ['Grocery store', 'Wholesale food store']                                                                                                                                                                        | The prices can't be beat. My roommates and I love to stop in and stock up before we drive home.                                                                                                                                                                                                                                                                                                                                                                                              | True            |                             0.75 | False        |                          0.65 | False       |                         0.25 |
# | 1048 | Wyshbone Market                                 | ['Grocery store', 'Wholesale food store']                                                                                                                                                                        | Good prices and excellent quality                                                                                                                                                                                                                                                                                                                                                                                                                                                            | True            |                             0.68 | False        |                          0.32 | False       |                         0.12 |
# | 1054 | Wyshbone Market                                 | ['Grocery store', 'Wholesale food store']                                                                                                                                                                        | Nice meat markets with good quality products at a very good value and they carry Hillcrest Meats products everyone should try them.                                                                                                                                                                                                                                                                                                                                                          | True            |                             0.85 | False        |                          0.15 | False       |                         0.15 |
# | 1056 | Wyshbone Market                                 | ['Grocery store', 'Wholesale food store']                                                                                                                                                                        | Amazing how many choices you have for 1 bird, low prices!!                                                                                                                                                                                                                                                                                                                                                                                                                                   | True            |                             0.82 | False        |                          0.18 | False       |                         0.12 |
# | 1057 | Wyshbone Market                                 | ['Grocery store', 'Wholesale food store']                                                                                                                                                                        | Great deals on some delicious meats.                                                                                                                                                                                                                                                                                                                                                                                                                                                         | True            |                             0.9  | False        |                          0.1  | False       |                         0.1  |
# | 1088 | The Atrium at Blue Haven                        | ['Wedding venue']                                                                                                                                                                                                | Top notch venue in the Sioux Falls area. As wedding DJ, I thankfully get the opportunity to see so many venues. I get to experience their layout, design, and very importantly...their staff.                                                                                                                                                                                                                                                                                                | True            |                             0.85 | False        |                          0.25 | False       |                         0.25 |
# |      |                                                 |                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | I always look forward to working with the Blue Haven & Atrium teams. They are so accommodating and serve their clients well.                                                                                                                                                                                                                                                                                                                                                                 |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | Why are you still reading this? You should be reaching out to the Atrium and seeing what I'm talking about.                                                                                                                                                                                                                                                                                                                                                                                  |                 |                                  |              |                               |             |                              |
# | 1106 | Brookings Fireworks, Inc                        | ['Fireworks store']                                                                                                                                                                                              | Best place to get fireworks! Staff knows their product and doesn't try to pressure sell, prices are comparable, and selection is very good!!!                                                                                                                                                                                                                                                                                                                                                | True            |                             0.92 | False        |                          0.08 | False       |                         0.05 |
# | 1109 | Brookings Fireworks, Inc                        | ['Fireworks store']                                                                                                                                                                                              | Best place to buy fireworks in Brookings. One of the biggest selections in the south east side of the state.                                                                                                                                                                                                                                                                                                                                                                                 | True            |                             0.8  | False        |                          0.3  | False       |                         0.2  |
# | 1111 | Brookings Fireworks, Inc                        | ['Fireworks store']                                                                                                                                                                                              | Always go here for the big boom                                                                                                                                                                                                                                                                                                                                                                                                                                                              | True            |                             0.65 | False        |                          0.35 | False       |                         0.25 |
# | 1112 | Brookings Fireworks, Inc                        | ['Fireworks store']                                                                                                                                                                                              | Best selection in the area!                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | True            |                             0.75 | False        |                          0.2  | False       |                         0.2  |
# | 1113 | Brookings Fireworks, Inc                        | ['Fireworks store']                                                                                                                                                                                              | Biggest selection around.                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | True            |                             0.85 | False        |                          0.25 | False       |                         0.15 |
# +------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+

# %% [markdown]
# #### Irrelevant

# %%
flagged_df = final_results[final_results["irrelevant"] == True]
print(tabulate(flagged_df[cols].head(50), headers="keys", tablefmt="psql"))
# Out:
# +------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+
# |      | name_y                                          | category                                                                                                                                                                                                         | text                                                                                                                                                                                                                                                                                           | advertisement   |   advertisement_confidence_score | irrelevant   |   irrelevant_confidence_score | fake_rant   |   fake_rant_confidence_score |
# |------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------|
# |    1 | CRST WIC Office                                 |                                                                                                                                                                                                                  | Th sw y are so nice                                                                                                                                                                                                                                                                            | False           |                             0.15 | True         |                          0.78 | False       |                         0.14 |
# |    2 | CRST WIC Office                                 |                                                                                                                                                                                                                  | Went with my daughter                                                                                                                                                                                                                                                                          | False           |                             0.25 | True         |                          0.75 | False       |                         0.25 |
# |   33 | Knight Towing & Truck Repair                    | ['Truck repair shop', 'Auto body shop', 'Towing service']                                                                                                                                                        | Don't use.                                                                                                                                                                                                                                                                                     | False           |                             0.2  | True         |                          0.6  | False       |                         0.2  |
# |  177 | Prairie Trails Park                             | ['Park']                                                                                                                                                                                                         | Helpful to find what you really need.                                                                                                                                                                                                                                                          | False           |                             0.15 | True         |                          0.6  | False       |                         0.2  |
# |  291 | CRST WIC Office                                 |                                                                                                                                                                                                                  | Th sw y are so nice                                                                                                                                                                                                                                                                            | False           |                             0    | True         |                          0.85 | False       |                         0.25 |
# |  292 | CRST WIC Office                                 |                                                                                                                                                                                                                  | Went with my daughter                                                                                                                                                                                                                                                                          | False           |                             0.2  | True         |                          0.65 | False       |                         0.2  |
# |  479 | Redline Tavern                                  | ['Bar']                                                                                                                                                                                                          | The New Red Zone is awesome!                                                                                                                                                                                                                                                                   | False           |                             0.25 | True         |                          0.75 | False       |                         0.2  |
# |  561 | Trimac Transportation                           | ['Truck repair shop', 'Transportation service']                                                                                                                                                                  | I am a Truck Driver here so I love it.                                                                                                                                                                                                                                                         | False           |                             0.25 | True         |                          0.6  | False       |                         0.2  |
# |  585 | Dave Hahler Automotive Inc                      | ['Car dealer', 'Auto body shop', 'Auto glass shop', 'Auto parts store', 'Auto repair shop', 'Chevrolet dealer']                                                                                                  | Owner is ass                                                                                                                                                                                                                                                                                   | False           |                             0.15 | True         |                          0.9  | False       |                         0.2  |
# |  607 | Highland Conference Center                      | ['Conference center', 'Banquet hall']                                                                                                                                                                            | Great little mall. Has jewelry store, nail salon, hair salon, restaurant, and a few shopping places! Very clean and friendly over all.                                                                                                                                                         | False           |                             0.2  | True         |                          0.8  | False       |                         0.2  |
# |  608 | Highland Conference Center                      | ['Conference center', 'Banquet hall']                                                                                                                                                                            | The ball I won from blarneys got stuck >:(                                                                                                                                                                                                                                                     | False           |                             0.2  | True         |                          0.85 | False       |                         0.65 |
# |  636 | Weiland Marine                                  | ['Boat dealer']                                                                                                                                                                                                  | Awesome day with my fellow veterans!                                                                                                                                                                                                                                                           | False           |                             0.85 | True         |                          0.75 | False       |                         0.25 |
# |  652 | Total Beauty                                    | ['Clothing store']                                                                                                                                                                                               | Best laundromat around. Know nothing of the attached boutique.                                                                                                                                                                                                                                 | False           |                             0.9  | True         |                          0.9  | False       |                         0.9  |
# |  654 | Total Beauty                                    | ['Clothing store']                                                                                                                                                                                               | (Translated by Google) American laundry;) washed clean neat.                                                                                                                                                                                                                                   | False           |                             0.25 | True         |                          0.85 | False       |                         0.2  |
# |      |                                                 |                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                                                |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | (Original)                                                                                                                                                                                                                                                                                     |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | Amerykańska pralnia ;) pierze się zadbana czysta.                                                                                                                                                                                                                                              |                 |                                  |              |                               |             |                              |
# |  695 | KFC                                             | ['Fast food restaurant', 'American restaurant', 'Chicken restaurant', 'Chicken wings restaurant']                                                                                                                | I had taco bell food and it was cold. I waited in the drive thru for what seemed like hours for cold food. Yuck                                                                                                                                                                                | False           |                             0.25 | True         |                          0.7  | False       |                         0.3  |
# |  732 | Hot Shots Espresso                              | ['Coffee shop']                                                                                                                                                                                                  | Gorilla. mocha.                                                                                                                                                                                                                                                                                | False           |                             0.05 | True         |                          0.65 | False       |                         0.25 |
# |  740 | Hot Shots Espresso                              | ['Coffee shop']                                                                                                                                                                                                  | Shop local y'all                                                                                                                                                                                                                                                                               | False           |                             0.25 | True         |                          0.65 | False       |                         0.25 |
# |  784 | The Church of Jesus Christ of Latter-day Saints | ['Church of Jesus Christ of Latter-day Saints', 'Christian church', 'Church', 'Church of Christ', 'Genealogist', 'Mission', 'Non-profit organization', 'Place of worship', 'Religious organization', 'Seminary'] | As for what it means                                                                                                                                                                                                                                                                           | False           |                             0.05 | True         |                          0.65 | False       |                         0.1  |
# | 1076 | Butler Machinery Company                        | ['Construction equipment supplier', 'Farm equipment supplier']                                                                                                                                                   | Fun time good food                                                                                                                                                                                                                                                                             | False           |                             0.25 | True         |                          0.9  | False       |                         0.1  |
# | 1078 | Butler Machinery Company                        | ['Construction equipment supplier', 'Farm equipment supplier']                                                                                                                                                   | The parts girl has the greatest blue eyes I have ever seen.....                                                                                                                                                                                                                                | False           |                             0.12 | True         |                          0.78 | False       |                         0.25 |
# | 1091 | The Atrium at Blue Haven                        | ['Wedding venue']                                                                                                                                                                                                | Tyler is the best chef in town.  He is a great guy who pays attention to every detail.                                                                                                                                                                                                         | False           |                             0.25 | True         |                          0.65 | False       |                         0.25 |
# | 1175 | Queen City Tire & Alignment                     | ['Auto repair shop']                                                                                                                                                                                             | I have been using Great Western Tire for a good 10 years now and I would recommend them to anyone looking for a mechanic. They are very thorough and I leave there knowing my vehicle is in the best shape!                                                                                    | False           |                             0.25 | True         |                          0.75 | False       |                         0.2  |
# | 1199 | Morningside Park                                | ['Park', 'Tourist attraction']                                                                                                                                                                                   | To go swimming                                                                                                                                                                                                                                                                                 | False           |                             0.35 | True         |                          0.65 | False       |                         0.25 |
# | 1263 | SDSU University Bookstore                       | ['Book store', 'Sportswear store']                                                                                                                                                                               | The food is good, but a bit greasy.                                                                                                                                                                                                                                                            | False           |                             0.2  | True         |                          0.65 | False       |                         0.2  |
# | 1300 | Black Hills State University                    | ['University', 'College']                                                                                                                                                                                        | I saved 11% on EVERYTHING!                                                                                                                                                                                                                                                                     | False           |                             0.3  | True         |                          0.82 | False       |                         0.3  |
# | 1302 | Black Hills State University                    | ['University', 'College']                                                                                                                                                                                        | Long par three's in the tree's ! 🌳                                                                                                                                                                                                                                                            | False           |                             0.9  | True         |                          0.8  | False       |                         0.8  |
# | 1305 | Black Hills State University                    | ['University', 'College']                                                                                                                                                                                        | (Translated by Google) Hooooiooiiiooooyyaaaaaah                                                                                                                                                                                                                                                | False           |                             0.08 | True         |                          0.78 | False       |                         0.25 |
# |      |                                                 |                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                                                |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | (Original)                                                                                                                                                                                                                                                                                     |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | Hooooiooiiiooooyyaaaaaah                                                                                                                                                                                                                                                                       |                 |                                  |              |                               |             |                              |
# | 1320 | Cimarron Casino                                 | ['Casino']                                                                                                                                                                                                       | It's ok dark like all of them good bear prices                                                                                                                                                                                                                                                 | False           |                             0.25 | True         |                          0.75 | False       |                         0.15 |
# | 1324 | Cimarron Casino                                 | ['Casino']                                                                                                                                                                                                       | Employees smoke pot behind building on an all day basis. The owner should keep a better lock on the beer as it is given away all day long. Have already called SD gaming commission about constant politics and how non supporters of this businesses political party will get you kicked out. | False           |                             0.2  | True         |                          0.78 | False       |                         0.2  |
# | 1355 | Pheasant Bar                                    | ['Bar']                                                                                                                                                                                                          | Fun night homecoming weekend                                                                                                                                                                                                                                                                   | False           |                             0.1  | True         |                          0.75 | False       |                         0.2  |
# | 1356 | Pheasant Bar                                    | ['Bar']                                                                                                                                                                                                          | Throwing darts with my daughter                                                                                                                                                                                                                                                                | False           |                             0.15 | True         |                          0.65 | False       |                         0.2  |
# | 1360 | Pheasant Bar                                    | ['Bar']                                                                                                                                                                                                          | 🍻                                                                                                                                                                                                                                                                                             | False           |                             0.15 | True         |                          0.92 | False       |                         0.05 |
# | 1536 | Brookings Plumbing Heating-AC                   | ['Heating contractor']                                                                                                                                                                                           | Good crispy and juicy chicken                                                                                                                                                                                                                                                                  | False           |                             0.92 | True         |                          0.92 | False       |                         0.2  |
# | 1668 | Uncle Milt's Alignment Services                 | ['Wheel alignment service', 'Brake shop']                                                                                                                                                                        | (Translated by Google) Naligable                                                                                                                                                                                                                                                               | False           |                             0.2  | True         |                          0.65 | False       |                         0.15 |
# |      |                                                 |                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                                                |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | (Original)                                                                                                                                                                                                                                                                                     |                 |                                  |              |                               |             |                              |
# |      |                                                 |                                                                                                                                                                                                                  | Naligable                                                                                                                                                                                                                                                                                      |                 |                                  |              |                               |             |                              |
# | 1921 | Copper Ridge Apartments                         | ['Apartment complex', 'Apartment building']                                                                                                                                                                      | My husband Miguel is  excellent at his job.                                                                                                                                                                                                                                                    | False           |                             0.05 | True         |                          0.85 | False       |                         0.15 |
# | 1947 | Canyon Lake Apartments                          | ['Apartment complex']                                                                                                                                                                                            | Lots of potheads                                                                                                                                                                                                                                                                               | False           |                             0.25 | True         |                          0.65 | False       |                         0.25 |
# | 2261 | The Legendary Red Carpet                        | ['Restaurant']                                                                                                                                                                                                   | Chase the ace Saturday nights until the spade is drawn                                                                                                                                                                                                                                         | False           |                             0.25 | True         |                          0.7  | False       |                         0.15 |
# | 2286 | Shop N Cart Dog Wash                            | ['Pet groomer', 'Car wash']                                                                                                                                                                                      | one of your favorite place                                                                                                                                                                                                                                                                     | False           |                             0.25 | True         |                          0.6  | False       |                         0.3  |
# | 2552 | Avera Sports Institute                          | ['Wellness center', 'Sports medicine clinic']                                                                                                                                                                    | RIP Avera Dome                                                                                                                                                                                                                                                                                 | False           |                             0.15 | True         |                          0.72 | False       |                         0.2  |
# | 2700 | A Perfect 10 Nail and Beauty Bar / Dawley Farms | ['Nail salon', 'Store']                                                                                                                                                                                          | Great way to start the day!                                                                                                                                                                                                                                                                    | False           |                             0.25 | True         |                          0.78 | False       |                         0.35 |
# | 2777 | The Farmer's Daughter                           | ['Gift shop', 'Antique store']                                                                                                                                                                                   | Thought it was a quilt shop                                                                                                                                                                                                                                                                    | False           |                             0.1  | True         |                          0.65 | False       |                         0.2  |
# | 2826 | Cenex                                           | ['Gas station']                                                                                                                                                                                                  | Chuck's                                                                                                                                                                                                                                                                                        | False           |                             0.25 | True         |                          0.65 | False       |                         0.25 |
# | 2847 | NAPA Auto Parts - Auto Parts of Yankton         | ['Auto parts store', 'Trailer supply store', 'Truck accessories store']                                                                                                                                          | Dodge guys really to Darryl                                                                                                                                                                                                                                                                    | False           |                             0.75 | True         |                          0.8  | False       |                         0.55 |
# | 2960 | Harrisburg Baseball Stadium                     | ['Sports complex']                                                                                                                                                                                               | Nice facility, but isn’t open to the public and my son and his friends got kicked off and had to play on the tee ball fields. Isn’t very function for large people. Also the lady that kicked my son off the field was an obvious trump supporter.                                             | False           |                             0.15 | True         |                          0.7  | False       |                         0.25 |
# | 3001 | Subway                                          | ['Sandwich shop', 'Caterer', 'Fast food restaurant', 'Takeout Restaurant', 'Restaurant']                                                                                                                         | People are awesome                                                                                                                                                                                                                                                                             | False           |                             0.2  | True         |                          0.6  | False       |                         0.2  |
# | 3008 | Subway                                          | ['Sandwich shop', 'Caterer', 'Fast food restaurant', 'Takeout Restaurant', 'Restaurant']                                                                                                                         | Just driving by it                                                                                                                                                                                                                                                                             | False           |                             0.15 | True         |                          0.85 | False       |                         0.2  |
# | 3089 | The Carrot Seed Kitchen Co.                     | ['Kitchen supply store', 'Gourmet grocery store']                                                                                                                                                                | No                                                                                                                                                                                                                                                                                             | False           |                             0.25 | True         |                          0.6  | False       |                         0.2  |
# | 3272 | Prairie Club Apartments                         | ['Apartment complex']                                                                                                                                                                                            | If I had the cash I'll back right here in a flash                                                                                                                                                                                                                                              | False           |                             0.25 | True         |                          0.65 | False       |                         0.25 |
# | 3527 | Curlew Lake                                     | ['Lake']                                                                                                                                                                                                         | Rocks                                                                                                                                                                                                                                                                                          | False           |                             0.25 | True         |                          0.78 | False       |                         0.15 |
# | 3686 | Rockin Robin's Casino                           | ['Casino']                                                                                                                                                                                                       | Yeeees                                                                                                                                                                                                                                                                                         | False           |                             0.85 | True         |                          0.65 | False       |                         0.2  |
# +------+-------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+

# %% [markdown]
# #### Fake Rants

# %%
flagged_df = final_results[final_results["fake_rant"] == True]
print(tabulate(flagged_df[cols].head(50), headers="keys", tablefmt="psql"))
# Out:
# +------+----------------------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+
# |      | name_y               | category                                                             | text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | advertisement   |   advertisement_confidence_score | irrelevant   |   irrelevant_confidence_score | fake_rant   |   fake_rant_confidence_score |
# |------+----------------------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------|
# | 3131 | Grand River          | ['River']                                                            | "tell others why you love this place"                                                                                                                                                                                                                                                                                                                                                                                                                                                             | False           |                             0.15 | False        |                          0.25 | True        |                         0.78 |
# |      |                      |                                                                      | Uhm..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |                 |                                  |              |                               |             |                              |
# |      |                      |                                                                      | Ok...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |                 |                                  |              |                               |             |                              |
# |      |                      |                                                                      | Great place to dump the bodies!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |                 |                                  |              |                               |             |                              |
# |      |                      |                                                                      | :P                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                 |                                  |              |                               |             |                              |
# | 3257 | 2nd & Lawler Co.     | ['Frozen yogurt shop', 'Candy store', 'Ice cream shop', 'Toy store'] | Bahaha i didn't even go here but sure...5 stars!                                                                                                                                                                                                                                                                                                                                                                                                                                                  | False           |                             0.25 | False        |                          0.35 | True        |                         0.65 |
# | 3391 | Hospice Thrift Store | ['Thrift store']                                                     | Crowded isles, baskets available to put items in ( no carts). Hard to maneuver ( shop), only one fitting room for whole store. Prices are on the high side. There are lots of items to go through, be prepared to wait at check out. Parking is extremely limited. Front door is pull - push type only and does not have handicap button to assist those who need that type of entrance. Fitting room is not handicap accessible. Shop layout is not designed for wheel chairs (power or manual). | False           |                             0.25 | False        |                          0.25 | True        |                         0.72 |
# +------+----------------------+----------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------------------------------+--------------+-------------------------------+-------------+------------------------------+
